# %% [markdown]
# <a href="https://colab.research.google.com/github/sauddy/DPCNet/blob/main/DPCNet_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DPNNet-RT -- 22 October 2022 (Colab Compatible)
#
# This notebook is created to build a ML model that can Classify and Predict the number of hidden planets and the
# corresponding planet mass for each of the planets from the protoplanetary disk images directly.

# %%
#####    Please note this version of the code is compatible with Google colab  ####
############################################# Mount the drive if running from Colab ##########################################
# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# ### IDEA behind this notebook :
# #### Authors : Sayantan and Subhrat
# #### Created : 3 Feb 2022
# #### This notebook is adopted from the DPNNet-2.0
#
# ##### Updated1: 24 Feb 2022 to include multi-outputs
# ##### Updated2: 22 October 2022 to include the all the date from the 700 FARGO3D calculations
#
# This notebook is developed to train the Model with Radiative Transfer(RT) images:
# We want to perform the following set of tasks
#
# P.S.This is a modular notebook that does the following:
#  1. Import all the customized Modules from Modules_DPNNet
#  2. For data processing we use data_processing_RT.py script
#  3. A functional module to call the different networks independently. (deep_models.py, other_cnn.py)
#  4. On October 2022, we are updating this notebook. We can now acess the complete data but shall choose randomly from the images
#  5. Still only considering the axysymmetric images

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import cv2
import os
import csv

## Modules to check the performance of the code
from time import process_time 
# !pip install memory_profiler ## When running from Google Colab
# import memory_profiler as mem_profile
# print('Memory (Before): {}Mb'.format(mem_profile.memory_usage()))


## Importing the necessary TesnorFLow modules modules
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# from tensorflow.python.compiler.mlcompute import mlcompute
# mlcompute.set_mlc_device(device_name='gpu')

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from sklearn.metrics import r2_score ## form calcualting the r2 score
from sklearn.utils import shuffle
from tensorflow import keras as k
from keras_preprocessing.image import ImageDataGenerator
import tensorflow as tf

## Modules for TrasferLearning

from tensorflow.keras.applications import EfficientNetB0, EfficientNetB1 
from tensorflow.keras.applications import EfficientNetB2, EfficientNetB3
from tensorflow.keras.applications import EfficientNetB4, EfficientNetB5 
from tensorflow.keras.applications import EfficientNetB6, EfficientNetB7
from tensorflow.keras.applications import ResNet50,ResNet50V2


## Checking the availbale number of GPUs
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:",gpu.name,"Type:",gpu.device_type)
print("TensorFlow version used ",tf.__version__)
# Out:
# Num GPUs Available:  1
# Name: /physical_device:GPU:0 Type: GPU
# TensorFlow version used  2.9.0

# %% [markdown]
# #### Folder management

# %%
############ Please provide the path to the code directory if using Colab ################

# Path_gdrive= '/content/drive/MyDrive/DPNNet-RT/' ## Comment out this line if using local computer

## Importing the Modules from Modules_DPNNet
import sys
try: ## tries to find the modules in the local directory first
  current_directory = os.getcwd()
  path = current_directory + '/' # For local computer 
#   path = '' # For local computer  
  sys.path.append(path+'MODULES_DPNNeT')
  import data_processing_RT as dp
  import deep_models as dm
  import other_cnns as ocn

########### Folders to save the processed data, files and figures when using Local computer ##############
  output_folder_list = ['data_folder','figures','saved_model']
  for file in output_folder_list:
    try:
        os.makedirs(file)
    except OSError:
        print ("Creation of the directory %s failed/ not needed as it already exit" % file)
    else:
        print ("Successfully created the directory %s" % file)
  
except ModuleNotFoundError:
  
  # #For Colab use:
  # #Point to the path containing the modules in the above section
  # # data folder are a directory above the directory containing the notebook
  try:
    path = Path_gdrive
    print(path)
    sys.path.append(path+'MODULES_DPNNeT')
    import data_processing_RT as dp
    import deep_models as dm
    import other_cnns as ocn

    ########### Folders to save the processed data, files and figures when using GDRIVE ##############
    import os
    os.chdir(path)
    print("Creating the folders")
    # !mkdir -p data_folder
    # !mkdir -p figures ## to save the figures
    # !mkdir -p figures_paper
    # !mkdir -p saved_model
  except ModuleNotFoundError:
    print("The path to the modules is incorrect-- Provide current path")

print("[INFO] Modules imported")
# Out:
# We are currently using the Modules_DPCNet-RT
# Creation of the directory data_folder failed/ not needed as it already exit
# Creation of the directory figures failed/ not needed as it already exit
# Creation of the directory saved_model failed/ not needed as it already exit
# [INFO] Modules imported

# %% [markdown]
# # Creating a csv with simulations params and path to each RT images

# %%
## Taking a look at the paramter file 
parameter_df = dp.load_parameter_csv(path)
parameter_df
# Out:
#      Planet_Mass1  Planet_Mass2  Planet_Mass3  Epsilon  Alpha    Stokes  \
# 0        0.000322       0.00204      0.001210    0.050  0.001  1.570000
# 1        0.002280       0.00154      0.000963    0.025  0.010  1.570000
# 2        0.002450       0.00262      0.002460    0.025  0.010  1.570000
# 3        0.000917       0.00195      0.001050    0.010  0.001  1.570000
# 4        0.001770       0.00187      0.002210    0.025  0.050  1.570000
# ..            ...           ...           ...      ...    ...       ...
# 695      0.002110       0.00000      0.000000    0.025  0.005  0.000157
# 696      0.002530       0.00000      0.000000    0.025  0.010  0.000157
# 697      0.000577       0.00000      0.000000    0.025  0.001  0.000157
# 698      0.001940       0.00000      0.000000    0.025  0.050  0.000157
# 699      0.002790       0.00000      0.000000    0.050  0.005  0.000157
#
#      Aspect_Ratio  SigmaSlope  Flaring_Index    Rp1   Rp2   Rp3  a_grain_mic
# 0          0.0432         1.0          0.010  1.010  2.19  3.22       3000.0
# 1          0.0561         1.0          0.075  0.943  2.16  3.37       1000.0
# 2          0.0261         1.0          0.075  1.160  1.84  3.15      10000.0
# 3          0.0496         1.0          0.250  1.100  1.82  2.99      10000.0
# 4          0.0625         1.0          0.075  0.863  2.08  3.32       3000.0
# ..            ...         ...            ...    ...   ...   ...          ...
# 695        0.0454         1.0          0.010  1.100  1.94  3.29        100.0
# 696        0.0882         1.0          0.075  0.851  1.99  3.10        100.0
# 697        0.0732         1.0          0.250  1.130  2.00  3.35        100.0
# 698        0.0711         1.0          0.075  0.966  2.02  3.32        100.0
# 699        0.0646         1.0          0.250  1.010  1.87  3.25        100.0
#
# [700 rows x 13 columns]

# %% [markdown]
# ## Move the images from the original folder to the code directory
#
# Only needed initially for moving the images to the working directory--
# Ones the data is moved there is no need for this code block

# %%
############ to move the images from the original folder to the code directory ###################

# # Path to the RT image folder
# RT_Folder_Path = "/Users/sauddy/OneDrive - Iowa State University/images/examples/"
# RT_Folder_Path = "/home/sauddy3/scratch/DPNNet-RT/radmc3d-2.0/examples/"


# list_RT_path = glob.glob(RT_Folder_Path+ 'RT_A*') ## make a list of all the RT folder where each folder is for each sim
# # print(list_RT_path)

# list_sorted_RT_path  = sorted(list_RT_path, key=lambda x: int(x.split('/')[7].split('_')[2])) ## sorting the images folders
# # print(list_sorted_RT_path)

# ############### Moving the images to the code directory for convenience ######
# import shutil
# try:
#     os.mkdir('image_directory_complete')
# except OSError:
#      print ("Creation of the directory %s failed/ not needed as it already exit" % file)
# NEW_IMAGE_PATH = 'image_directory_complete'
# os.chdir(NEW_IMAGE_PATH)
# for index in range(len(list_sorted_RT_path)):
#     try:
#         os.mkdir('RT_A_'+ str(index+1))
#     except OSError:
# #          print ("Creation of the directory %s failed/ not needed as it already exit" % file)
#          pass
    
#     destination_path = 'RT_A_'+ str(index+1)
#     for img in glob.glob(list_sorted_RT_path[index] + "/images/snu/"+ "image_"+"*.png"):
#         shutil.copy(img, destination_path)

# os.chdir('../')

############## END ##############################

# %% [markdown]
# #### Address to the data folder
#
# Genrating the .csv file with the image address to load them later

# %%
############# Address to the data folder ###################

# ## updating the image paths once the transfer is done
list_RT_path = glob.glob(path+ 'image_directory_complete/'+ 'RT_A*') ## make a list of all the RT folder where each folder is for each sim

## When using the local M1
# list_sorted_RT_path  = sorted(list_RT_path, key=lambda x: int(x.split('/')[1].split('_')[2])) ## sorting the images


# ## For google colab this needs to be updated
list_sorted_RT_path  = sorted(list_RT_path, key=lambda x: int(x.split('/')[6].split('_')[2])) ## sorting the images

# The idea is to generate a dataframe with the parameters and the path to the images
data_complete = dp.create_complete_data_csv(list_sorted_RT_path,path)
# data_complete
## Removing the nan if any
data_complete.isna().sum()  # summing the number of na
data_complete= data_complete.dropna()
data_complete

# data_complete['Planet_Count'] = (data_complete.loc[:, ['Planet_Mass1', 'Planet_Mass2', 'Planet_Mass3']] != 0).sum(axis=1)
data_complete = shuffle(data_complete,random_state=42)
data_complete= data_complete[:10000] ## Select less numbers of images for quick results
data_complete
# Out:
# [INFO]: Importing path for all the RT images
# [INFO]: Contatination of the paths of all the RT images are now complete
#        Planet_Mass1  Planet_Mass2  Planet_Mass3  Epsilon   Alpha    Stokes  \
# 79835    673.333333      0.000000      0.000000    0.025  0.0050  0.001570
# 45230    760.000000    706.666667    960.000000    0.025  0.0001  0.005230
# 5464     703.333333     60.000000    516.666667    0.010  0.0050  1.570000
# 40465    476.666667      0.000000      0.000000    0.025  0.0050  0.015700
# 16261    305.666667      0.000000      0.000000    0.010  0.0010  1.570000
# ...             ...           ...           ...      ...     ...       ...
# 74794    107.333333     60.000000    240.000000    0.025  0.0100  0.001570
# 29829    703.333333     60.000000     99.333333    0.050  0.0010  0.015700
# 38925    220.666667      0.000000      0.000000    0.025  0.0050  0.015700
# 43849    503.333333    596.666667    516.666667    0.025  0.0100  0.005230
# 98076    703.333333      0.000000    240.000000    0.050  0.0500  0.000157
#
#        Aspect_Ratio  SigmaSlope  Flaring_Index    Rp1   Rp2   Rp3  \
# 79835        0.0711         1.0          0.075  0.817  1.94  3.39
# 45230        0.0946         1.0          0.075  1.070  1.90  3.01
# 5464         0.0732         1.0          0.250  1.150  2.05  3.06
# 40465        0.0261         1.0          0.250  1.180  1.83  3.13
# 16261        0.0796         1.0          0.075  0.931  1.92  3.41
# ...             ...         ...            ...    ...   ...   ...
# 74794        0.0646         1.0          0.075  0.954  2.02  3.49
# 29829        0.0861         1.0          0.075  0.840  1.87  3.03
# 38925        0.0946         1.0          0.075  0.966  2.17  2.91
# 43849        0.0818         1.0          0.250  0.874  1.87  3.30
# 98076        0.0689         1.0          0.075  0.874  1.87  3.17
#
#        a_grain_mic                                         image_path
# 79835        300.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 45230       1000.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 5464        1000.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 40465       1000.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 16261       3000.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# ...            ...                                                ...
# 74794        300.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 29829        300.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 38925       3000.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 43849       3000.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
# 98076        100.0  /scratch/sauddy3/DPNNet-RT/DPNNet-RT-ML-Code/i...
#
# [10000 rows x 14 columns]

# %% [markdown]
# # Model Selections and Hyperparameters

# %%
#### Desired Image resoltuion  and Batch Size #####
X_res = Y_res = 128


## Select the kind of Traning ## Both can be selected as well
REG = True #True  ## When choosing regression
CLA = False #False #False #True  ## When Choosing Clasiffication


## Select the Network type

# NETWORK = "Vanilla" ## Cannot be uses at the moment
# NETWORK = "ALEXNET"
# NETWORK = "VGG"
# NETWORK = "RESNET50"

                                ########## When using Trasnfer Learning ######################
NETWORK = "TL"
transfer_model=ResNet50
# transfer_model=EfficientNetB3

## Hyper-Parameter to define
batch_size = 32 ## 20 was for regression ## the best was for 200 last run
valid_batch_size = 100
epochs=200 ## best was 100
init_lr = 1e-5 # 1e-5 (works for regression)

# early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.2, patience=20, verbose=1, mode='min',restore_best_weights=True)

# %% [markdown]
# ## Preparing data

# %%
## partition the data csv file into training and testing splits using 85% of
## the data for training and the remaining 15% for testing
split = train_test_split(data_complete, test_size=0.15, random_state=42)
(train, test) = split

## Save the train and the test data for future use as well.
test.to_csv(path+'data_folder/test_dataset.csv')
train.to_csv(path+'data_folder/train_dataset.csv')

## Generate the Normalized data
normed_train_data, normed_test_data, train_labels, test_labels = dp.process_the_disk_attributes(train, test, path,multi_label=True)
# Out:
# [INFO] preparing the normalized data training/testing split...
# Droping the irrelevant columns
# INFO: considering multiple planets as output
# [INFO] Done...

# %% [markdown]
# ### Loading the images or Creating the train, validation and test generators

# %%
import time
start = time.time()

if CLA == True:
        ### Preparing the dataset for the classification problem--- 
        ## For classification we included binary 1 or 0 depending on if the planet is present or not respectively
        train['Planet_Mass1'] = np.where(train['Planet_Mass1']!= 0, 1,0)
        train['Planet_Mass2'] = np.where(train['Planet_Mass2']!= 0, 1,0)
        train['Planet_Mass3'] = np.where(train['Planet_Mass3']!= 0, 1,0)
        # train = train.select_dtypes("string")
        test['Planet_Mass1'] = np.where(test['Planet_Mass1']!= 0, 1, 0)
        test['Planet_Mass2'] = np.where(test['Planet_Mass2']!= 0, 1, 0)
        test['Planet_Mass3'] = np.where(test['Planet_Mass3']!= 0, 1, 0)
        
        Y_train=train[['Planet_Mass1','Planet_Mass2','Planet_Mass3']] ## These are used as label for the non-generator training
        Y_test=test[['Planet_Mass1','Planet_Mass2','Planet_Mass3']]
        
        ###### Generate the training and the test images######
if X_res >= 128:
       # For res < 128 we load the all the images to RAM memeory instead of using the Generators as that is much more efficient
        
    def custom_augmentation(np_tensor):

        '''
        This function is used to crop the images when those are loaded using the 
        ImageDataGenerator Keras function. This custom augmentation function only
        works for three different res as given below. For other resolutions the 
        image needs to the cropped appropiately.

        '''

        # # # dimensions for cropping the image
        if X_res == 128:
          top,left,bottom,right = 20,25,110,90 
        if X_res == 256:          
          top,left,bottom,right = 40,50,220,180          
        if X_res == 512:
          top,left,bottom,right = 60,90,450,380          
                
        image = np.squeeze(np_tensor) 
        crop_image = image[top:bottom, left:right]
        crop_image = cv2.resize(crop_image, (X_res, Y_res)) 
        crop_image = k.preprocessing.image.img_to_array(crop_image)
        return crop_image

    # datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,samplewise_center=True, samplewise_std_normalization=True,rescale=1./255.,validation_split=0.15)
    # datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,featurewise_center=True,featurewise_std_normalization=True,rescale=1./255.,validation_split=0.15)
    datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,rescale=1./255.,validation_split=0.15)

    #### TRAINING GENERATOR #####
    train_generator=datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="image_path",
    y_col=["Planet_Mass1",'Planet_Mass2','Planet_Mass3'],
    subset="training",
    batch_size=batch_size,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(X_res,Y_res))

    #### VALIDATION GENERATOR #####
    validation_generator=datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="image_path",
    y_col=["Planet_Mass1",'Planet_Mass2','Planet_Mass3'],
    subset="validation",
    batch_size=batch_size,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(X_res,Y_res))

    #### TESTING GENERATOR #####
    test_datagen= k.preprocessing.image.ImageDataGenerator(preprocessing_function=custom_augmentation,rescale=1./255.)
    test_generator=test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=None,
    x_col="image_path",
    y_col=["Planet_Mass1",'Planet_Mass2','Planet_Mass3'],
    batch_size=batch_size,
    seed=42,
    shuffle=False,
    class_mode=None,
    target_size=(X_res,Y_res))
    
    
    ## STEP SIZES later used for training using generators
    STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
    STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

 

else:    
    #For res < 128 we load the all the images to RAM memeory instead of using the Generators as that is much more efficient#

    
    print("Uploading directly to RAM as the image resoltuion is manageble")
    trainImagesX = dp.load_disk_images(train, X_res, Y_res, Type = "Train")
    testImagesX = dp.load_disk_images(test, X_res, Y_res, Type = "Test")

Validation_split = 0.15 # 15 percent of the training data is used for validation
print('There are {} Train, {} Validation and {} Test images'.format(int((1-Validation_split)*len(normed_train_data)),int(Validation_split*len(normed_train_data)),len(normed_test_data)))## check the numbers in each category
end = time.time()
print("Total time elapsed =", end - start)

# Getting all memory using os.popen()
total_memory, used_memory, free_memory = map(
    int, os.popen('free -t -m').readlines()[-1].split()[1:])
 
# Memory usage
print("RAM memory % used:", round((used_memory/total_memory) * 100, 2))
# Out:
# Found 7225 validated image filenames.
# Found 1275 validated image filenames.
# Found 1500 validated image filenames.
# There are 7225 Train, 1275 Validation and 1500 Test images
# Total time elapsed = 46.39942812919617
# RAM memory % used: 4.64

# %% [markdown]
# ### Checking image with cropping for verification

# %%
if X_res>= 128:
    for _ in range(5):
        img, label = train_generator.next()
        print(img.shape)   #  (1,256,256,3)
        plt.imshow(img[0])
        plt.show()
else:
    plt.imshow(trainImagesX[5])
    plt.show()
# Out:
# (32, 128, 128, 3)
# (32, 128, 128, 3)
# (32, 128, 128, 3)
# (32, 128, 128, 3)
# (32, 128, 128, 3)

# %% [markdown]
# ### Transfer Learning Codes
#
# Will be later moved to the Module Folder

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers


# modules added for the RESNET50
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import ZeroPadding2D, AveragePooling2D, GlobalMaxPooling2D, Add


def TRANSFERLEARNING(width,height,depth,classes=None,regress=False,multi_label=False,classification=False,option=None,transfer_model= None):

    '''
    This function introduces the use of Transfer learning to train the DPNNet Model
    Here we use the pretrained weights from the Imagenet data set
    
    Please note this here update the final layers to perform regress or classification
    or both regression and classification together
    
    Input:  1. Dimension of the image [width,height,depth]
            2. Number of classsification classes if used for calssification
            3. Regress on or off
            4. Multilabel -- True for multi-label regression Default == False
            5. Classification -- True or False 
            6. Option is the argument to use either softmax (default) or sigmoid for classification
            7. Select the transfer Learning Model from Either 3 RESNET50 or Efficientnet0-7 models
            
            
    Output : Model Build 
    
    '''
    
    ## Input layers
    X_input = layers.Input(shape=(X_res, Y_res, depth))
    x = X_input
    
    if transfer_model == None:
        transfer_model = EfficientNetB6
        print("Please Select the Network that will be used-- By Default {} will be used".format(str.lower(transfer_model.__name__)))
    
    #### Selecting the model along with the pretrained weights
    mod_name = transfer_model.__name__
    print("INFO: Keras Model used is {}".format(mod_name))
    print("Loading weights for {} since this notebook is not connected to internet".format(str.lower(mod_name)))
    
    try:
        model = transfer_model(include_top=False,input_tensor=x, weights='preloaded_weights/'+str.lower(mod_name)+'_notop.h5')
    except ValueError:
        model = transfer_model(include_top=False,input_tensor=x, weights='preloaded_weights/'+str.lower(mod_name)+'_weights_tf_dim_ordering_tf_kernels_notop.h5')
    
    print("IF the notebook is connected to internet then the weights can be directly downloaded-- Choose accordingly")
    # try:
    #     model = transfer_model(include_top=False,input_tensor=x, weights='imagenet')
    # except ValueError:
    #     model = transfer_model(include_top=False,input_tensor=x, weights='imagenet')
    
    # Freeze the pretrained weights
    model.trainable = True

    # Rebuild top

    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)

    XX = Flatten()(x)
    XX = Dense(100, kernel_initializer='he_uniform', activation='relu')(XX) 
    # outputs = layers.Dense(classes, activation="softmax", name="pred")(x)


    if classification==True:
      # print("A new fully Connexted layer is added")
       ## Adding a Fully connected layer for classification
      Xclas = XX
      # Xclas = BatchNormalization(axis=1)(Xclas)   
      top_dropout_rate = 0.30
      # Xclas = layers.Dropout(top_dropout_rate, name="top_dropout1")(Xclas)  
      Xclas = Dense(50, kernel_initializer='he_uniform', activation='relu')(Xclas)
      Xclas = BatchNormalization(axis=1)(Xclas)
      # top_dropout_rate = 0.20
      # Xclas = layers.Dropout(top_dropout_rate, name="top_dropout2")(Xclas)
      Xclas = Dense(20, kernel_initializer='he_uniform', activation='relu')(Xclas)
      Xclas = BatchNormalization(axis=1)(Xclas)
        
      print("INFO:CNN is used for classification")
      if option ==1:
          print("Additional INFO:Using Softmax for classification")
          Xclas = Dense(units=classes,name='cla',activation='softmax')(Xclas) 
      else:  
          print("Additional INFO: Using Sigmoid activation for classification")
          Xclas = Dense(units=classes, name='cla',activation='sigmoid')(Xclas)
          out_clas = Xclas 


    if regress == True:
      print("INFO:CNN is used for regression")
      if multi_label==False:           
        Xreg = Dense(1, activation='linear', name='reg', kernel_initializer = glorot_uniform(seed=0))(XX)
      if multi_label==True: 
        ## 28 Feb 2022 added the multi-label output 
        print("INFO: Note Multiple Labels are optimised during regression")
        Xreg = Dense(3, activation='linear', name='reg', kernel_initializer = glorot_uniform(seed=0))(XX)
        out_reg = Xreg
    

    ### Create model

    if classification == True and regress == True:
      print("INFO: Performing both regression and classification -- Model Training")
      modelNEWCNN = Model(inputs = X_input,outputs=[out_reg, out_clas])
    elif regress == False:
      X = out_clas
      print("INFO: Classification Model is being trained")
      modelNEWCNN = Model(inputs = X_input, outputs = X)
    elif classification is False:
      X = out_reg
      print("INFO: Regression Model is being trained")
      modelNEWCNN = Model(inputs = X_input, outputs = X)

    return modelNEWCNN

# %% [markdown]
# ## Training the CNN

# %%
print('INFO: Currently training using the {} NETWORK with regression = {} and classification = {}'.format(NETWORK,REG,CLA))
if NETWORK == "Vanilla":
    CNN = dm.build_cnn(X_res, Y_res, 3, regress=True)
elif NETWORK == "ALEXNET":
    CNN = alexnet(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "VGG":
    CNN = cnn_vgg(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "RESNET50":
    # CNN = Resnet50(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
    CNN = ocn.Resnet50(X_res, Y_res, 3,classes=3,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "TL":    
    CNN = TRANSFERLEARNING(X_res, Y_res, 3,classes=3,regress = REG,multi_label=True,classification=CLA,option=None,transfer_model=transfer_model)

optimizer = tf.keras.optimizers.Adam(init_lr, decay=init_lr/epochs)


if REG == True and CLA ==False:
    CNN.compile(loss='mean_squared_error',
                    optimizer=optimizer,
                    metrics=['mean_absolute_error', 'mean_squared_error'])
    
    if X_res >= 128:
        print("INFO: REGRESSION using GENERATORS")       
        CNN_history = CNN.fit(train_generator,
                            steps_per_epoch=STEP_SIZE_TRAIN,
                            validation_data=validation_generator,
                            validation_steps=STEP_SIZE_VALID,
                            epochs=epochs,callbacks=[early_stop])
    else:

        CNN_history = CNN.fit(x=trainImagesX, y=train_labels,
                          validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])

if REG == False and CLA ==True:
    CNN.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
    
    if X_res >= 128:          
        print("INFO: CLASSIFICATION using GENERATORS")  
        CNN_history = CNN.fit(train_generator,
                            steps_per_epoch=STEP_SIZE_TRAIN,
                            validation_data=validation_generator,
                            validation_steps=STEP_SIZE_VALID,
                            epochs=epochs)
    else: 
        
        CNN_history = CNN.fit(x=trainImagesX, y=Y_train,
                      validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])

if REG == True and CLA ==True:
    # When used for classification and regression
    CNN.compile(loss=['mean_squared_error','binary_crossentropy'],optimizer=optimizer,metrics=['mean_squared_error', 'accuracy'])

    CNN_history = CNN.fit(x=X_train, y=[train_labels,Y_train],
                      validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])
# Getting all memory using os.popen()


total_memory, used_memory, free_memory = map(
int, os.popen('free -t -m').readlines()[-1].split()[1:])

# Memory usage
print("RAM memory % used:", round((used_memory/total_memory) * 100, 2))
# print('Memory (After Training): {}Mb'.format(mem_profile.memory_usage()))
# Out:
# INFO: Currently training using the TL NETWORK with regression = True and classification = False
# INFO: Keras Model used is ResNet50
# Loading weights for resnet50 since this notebook is not connected to internet
# 2022-11-04 15:14:02.293057: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-04 15:14:02.938368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11319 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:04:00.0, compute capability: 6.0
# INFO:CNN is used for regression
# INFO: Note Multiple Labels are optimised during regression
# INFO: Regression Model is being trained
# INFO: REGRESSION using GENERATORS
# Epoch 1/200
# 2022-11-04 15:14:16.268743: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
# 2022-11-04 15:14:16.719112: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-04 15:14:16.725620: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-04 15:14:16.725683: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-04 15:14:16.730306: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-04 15:14:16.730390: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 225/225 [==============================] - 146s 601ms/step - loss: 221107.4062 - mean_absolute_error: 343.2229 - mean_squared_error: 221107.4062 - val_loss: 228796.0469 - val_mean_absolute_error: 350.0722 - val_mean_squared_error: 228796.0469
# Epoch 2/200
# 225/225 [==============================] - 107s 473ms/step - loss: 205944.7812 - mean_absolute_error: 332.0410 - mean_squared_error: 205944.7812 - val_loss: 226339.6406 - val_mean_absolute_error: 347.8567 - val_mean_squared_error: 226339.6406
# Epoch 3/200
# 225/225 [==============================] - 109s 485ms/step - loss: 192018.2031 - mean_absolute_error: 321.2801 - mean_squared_error: 192018.2031 - val_loss: 215604.0781 - val_mean_absolute_error: 336.3645 - val_mean_squared_error: 215604.0781
# Epoch 4/200
# 225/225 [==============================] - 156s 696ms/step - loss: 180243.1719 - mean_absolute_error: 310.7053 - mean_squared_error: 180243.1719 - val_loss: 172485.7344 - val_mean_absolute_error: 296.4271 - val_mean_squared_error: 172485.7344
# Epoch 5/200
# 225/225 [==============================] - 108s 482ms/step - loss: 168206.9375 - mean_absolute_error: 299.3937 - mean_squared_error: 168206.9375 - val_loss: 130140.8828 - val_mean_absolute_error: 257.0353 - val_mean_squared_error: 130140.8828
# Epoch 6/200
# 225/225 [==============================] - 110s 488ms/step - loss: 158270.0312 - mean_absolute_error: 288.9778 - mean_squared_error: 158270.0312 - val_loss: 117943.1250 - val_mean_absolute_error: 247.6045 - val_mean_squared_error: 117943.1250
# Epoch 7/200
# 225/225 [==============================] - 108s 478ms/step - loss: 147124.5625 - mean_absolute_error: 278.4550 - mean_squared_error: 147124.5625 - val_loss: 132863.0312 - val_mean_absolute_error: 264.1651 - val_mean_squared_error: 132863.0312
# Epoch 8/200
# 225/225 [==============================] - 118s 526ms/step - loss: 138060.0000 - mean_absolute_error: 268.9279 - mean_squared_error: 138060.0000 - val_loss: 130069.4609 - val_mean_absolute_error: 261.5610 - val_mean_squared_error: 130069.4609
# Epoch 9/200
# 225/225 [==============================] - 177s 788ms/step - loss: 127802.9844 - mean_absolute_error: 257.6461 - mean_squared_error: 127802.9844 - val_loss: 120636.1797 - val_mean_absolute_error: 249.9147 - val_mean_squared_error: 120636.1797
# Epoch 10/200
# 225/225 [==============================] - 109s 486ms/step - loss: 118072.8359 - mean_absolute_error: 246.9462 - mean_squared_error: 118072.8359 - val_loss: 104240.0625 - val_mean_absolute_error: 229.7396 - val_mean_squared_error: 104240.0625
# Epoch 11/200
# 225/225 [==============================] - 108s 481ms/step - loss: 110101.9062 - mean_absolute_error: 237.5857 - mean_squared_error: 110101.9062 - val_loss: 102583.1250 - val_mean_absolute_error: 230.9359 - val_mean_squared_error: 102583.1250
# Epoch 12/200
# 225/225 [==============================] - 113s 503ms/step - loss: 100870.6016 - mean_absolute_error: 227.8233 - mean_squared_error: 100870.6016 - val_loss: 95158.1016 - val_mean_absolute_error: 222.7879 - val_mean_squared_error: 95158.1016
# Epoch 13/200
# 225/225 [==============================] - 110s 489ms/step - loss: 93616.6250 - mean_absolute_error: 219.9036 - mean_squared_error: 93616.6250 - val_loss: 91682.1328 - val_mean_absolute_error: 219.9468 - val_mean_squared_error: 91682.1328
# Epoch 14/200
# 225/225 [==============================] - 174s 749ms/step - loss: 86474.5078 - mean_absolute_error: 211.3292 - mean_squared_error: 86474.5078 - val_loss: 85634.1484 - val_mean_absolute_error: 212.1665 - val_mean_squared_error: 85634.1484
# Epoch 15/200
# 225/225 [==============================] - 113s 503ms/step - loss: 80874.8984 - mean_absolute_error: 204.2833 - mean_squared_error: 80874.8984 - val_loss: 79708.3203 - val_mean_absolute_error: 204.6842 - val_mean_squared_error: 79708.3203
# Epoch 16/200
# 225/225 [==============================] - 116s 514ms/step - loss: 73736.9453 - mean_absolute_error: 195.0369 - mean_squared_error: 73736.9453 - val_loss: 65731.2188 - val_mean_absolute_error: 188.1277 - val_mean_squared_error: 65731.2188
# Epoch 17/200
# 225/225 [==============================] - 112s 499ms/step - loss: 69082.5703 - mean_absolute_error: 188.9321 - mean_squared_error: 69082.5703 - val_loss: 66211.2656 - val_mean_absolute_error: 185.5202 - val_mean_squared_error: 66211.2656
# Epoch 18/200
# 225/225 [==============================] - 151s 673ms/step - loss: 65506.1719 - mean_absolute_error: 184.8763 - mean_squared_error: 65506.1719 - val_loss: 56142.4727 - val_mean_absolute_error: 175.1841 - val_mean_squared_error: 56142.4727
# Epoch 19/200
# 225/225 [==============================] - 99s 440ms/step - loss: 60975.4961 - mean_absolute_error: 181.0516 - mean_squared_error: 60975.4961 - val_loss: 62923.0000 - val_mean_absolute_error: 185.6631 - val_mean_squared_error: 62923.0000
# Epoch 20/200
# 225/225 [==============================] - 109s 485ms/step - loss: 56545.2852 - mean_absolute_error: 173.4640 - mean_squared_error: 56545.2852 - val_loss: 57507.1680 - val_mean_absolute_error: 175.2915 - val_mean_squared_error: 57507.1680
# Epoch 21/200
# 225/225 [==============================] - 115s 509ms/step - loss: 49673.0117 - mean_absolute_error: 161.8540 - mean_squared_error: 49673.0117 - val_loss: 49740.6172 - val_mean_absolute_error: 162.2331 - val_mean_squared_error: 49740.6172
# Epoch 22/200
# 225/225 [==============================] - 132s 587ms/step - loss: 46761.8398 - mean_absolute_error: 156.0197 - mean_squared_error: 46761.8398 - val_loss: 50312.6328 - val_mean_absolute_error: 162.9818 - val_mean_squared_error: 50312.6328
# Epoch 23/200
# 225/225 [==============================] - 197s 877ms/step - loss: 44499.5117 - mean_absolute_error: 153.7685 - mean_squared_error: 44499.5117 - val_loss: 37209.0430 - val_mean_absolute_error: 141.3510 - val_mean_squared_error: 37209.0430
# Epoch 24/200
# 225/225 [==============================] - 118s 527ms/step - loss: 39959.8203 - mean_absolute_error: 145.9319 - mean_squared_error: 39959.8203 - val_loss: 34321.4180 - val_mean_absolute_error: 136.2359 - val_mean_squared_error: 34321.4180
# Epoch 25/200
# 225/225 [==============================] - 124s 552ms/step - loss: 37098.4805 - mean_absolute_error: 140.5455 - mean_squared_error: 37098.4805 - val_loss: 31417.0762 - val_mean_absolute_error: 131.5517 - val_mean_squared_error: 31417.0762
# Epoch 26/200
# 225/225 [==============================] - 138s 612ms/step - loss: 34734.6523 - mean_absolute_error: 135.0043 - mean_squared_error: 34734.6523 - val_loss: 29026.7012 - val_mean_absolute_error: 123.8865 - val_mean_squared_error: 29026.7012
# Epoch 27/200
# 225/225 [==============================] - 160s 710ms/step - loss: 31123.0898 - mean_absolute_error: 127.8366 - mean_squared_error: 31123.0898 - val_loss: 24443.6113 - val_mean_absolute_error: 119.7266 - val_mean_squared_error: 24443.6113
# Epoch 28/200
# 225/225 [==============================] - 104s 464ms/step - loss: 30483.5234 - mean_absolute_error: 127.9369 - mean_squared_error: 30483.5234 - val_loss: 24037.1250 - val_mean_absolute_error: 114.0271 - val_mean_squared_error: 24037.1250
# Epoch 29/200
# 225/225 [==============================] - 109s 486ms/step - loss: 27543.2344 - mean_absolute_error: 120.7720 - mean_squared_error: 27543.2344 - val_loss: 25983.1914 - val_mean_absolute_error: 118.8053 - val_mean_squared_error: 25983.1914
# Epoch 30/200
# 225/225 [==============================] - 107s 475ms/step - loss: 23931.8164 - mean_absolute_error: 112.8304 - mean_squared_error: 23931.8164 - val_loss: 20981.8535 - val_mean_absolute_error: 105.0680 - val_mean_squared_error: 20981.8535
# Epoch 31/200
# 225/225 [==============================] - 153s 679ms/step - loss: 22770.1426 - mean_absolute_error: 108.9262 - mean_squared_error: 22770.1426 - val_loss: 26640.2988 - val_mean_absolute_error: 116.8883 - val_mean_squared_error: 26640.2988
# Epoch 32/200
# 225/225 [==============================] - 184s 819ms/step - loss: 21204.4082 - mean_absolute_error: 105.7197 - mean_squared_error: 21204.4082 - val_loss: 16133.4082 - val_mean_absolute_error: 92.6087 - val_mean_squared_error: 16133.4082
# Epoch 33/200
# 225/225 [==============================] - 109s 486ms/step - loss: 19372.0059 - mean_absolute_error: 100.9166 - mean_squared_error: 19372.0059 - val_loss: 18051.9355 - val_mean_absolute_error: 98.3581 - val_mean_squared_error: 18051.9355
# Epoch 34/200
# 225/225 [==============================] - 116s 514ms/step - loss: 18612.8262 - mean_absolute_error: 98.8374 - mean_squared_error: 18612.8262 - val_loss: 18247.2441 - val_mean_absolute_error: 97.7019 - val_mean_squared_error: 18247.2441
# Epoch 35/200
# 225/225 [==============================] - 126s 561ms/step - loss: 17765.6250 - mean_absolute_error: 95.7895 - mean_squared_error: 17765.6250 - val_loss: 13785.8818 - val_mean_absolute_error: 82.6593 - val_mean_squared_error: 13785.8818
# Epoch 36/200
# 225/225 [==============================] - 117s 518ms/step - loss: 15634.0098 - mean_absolute_error: 89.2739 - mean_squared_error: 15634.0098 - val_loss: 14158.6123 - val_mean_absolute_error: 83.4505 - val_mean_squared_error: 14158.6123
# Epoch 37/200
# 225/225 [==============================] - 129s 573ms/step - loss: 14901.7002 - mean_absolute_error: 87.5611 - mean_squared_error: 14901.7002 - val_loss: 14212.6182 - val_mean_absolute_error: 82.0614 - val_mean_squared_error: 14212.6182
# Epoch 38/200
# 225/225 [==============================] - 110s 488ms/step - loss: 14191.1592 - mean_absolute_error: 85.9360 - mean_squared_error: 14191.1592 - val_loss: 12316.7139 - val_mean_absolute_error: 77.5166 - val_mean_squared_error: 12316.7139
# Epoch 39/200
# 225/225 [==============================] - 115s 510ms/step - loss: 14398.9854 - mean_absolute_error: 86.2576 - mean_squared_error: 14398.9854 - val_loss: 9882.8018 - val_mean_absolute_error: 71.1301 - val_mean_squared_error: 9882.8018
# Epoch 40/200
# 225/225 [==============================] - 113s 500ms/step - loss: 11639.2715 - mean_absolute_error: 78.7281 - mean_squared_error: 11639.2715 - val_loss: 9665.7529 - val_mean_absolute_error: 69.0711 - val_mean_squared_error: 9665.7529
# Epoch 41/200
# 225/225 [==============================] - 112s 499ms/step - loss: 10827.5791 - mean_absolute_error: 75.5416 - mean_squared_error: 10827.5791 - val_loss: 8567.8379 - val_mean_absolute_error: 63.9479 - val_mean_squared_error: 8567.8379
# Epoch 42/200
# 225/225 [==============================] - 147s 654ms/step - loss: 13060.1719 - mean_absolute_error: 82.4728 - mean_squared_error: 13060.1719 - val_loss: 13421.9854 - val_mean_absolute_error: 80.8842 - val_mean_squared_error: 13421.9854
# Epoch 43/200
# 225/225 [==============================] - 102s 452ms/step - loss: 10922.1191 - mean_absolute_error: 75.9188 - mean_squared_error: 10922.1191 - val_loss: 10059.3350 - val_mean_absolute_error: 69.8098 - val_mean_squared_error: 10059.3350
# Epoch 44/200
# 225/225 [==============================] - 110s 490ms/step - loss: 10021.4053 - mean_absolute_error: 73.3017 - mean_squared_error: 10021.4053 - val_loss: 8403.8350 - val_mean_absolute_error: 65.4638 - val_mean_squared_error: 8403.8350
# Epoch 45/200
# 225/225 [==============================] - 111s 494ms/step - loss: 10522.6875 - mean_absolute_error: 73.2773 - mean_squared_error: 10522.6875 - val_loss: 8172.6685 - val_mean_absolute_error: 64.1964 - val_mean_squared_error: 8172.6685
# Epoch 46/200
# 225/225 [==============================] - 110s 489ms/step - loss: 9391.6240 - mean_absolute_error: 70.9958 - mean_squared_error: 9391.6240 - val_loss: 8464.8877 - val_mean_absolute_error: 63.6994 - val_mean_squared_error: 8464.8877
# Epoch 47/200
# 225/225 [==============================] - 168s 748ms/step - loss: 8697.8379 - mean_absolute_error: 68.5279 - mean_squared_error: 8697.8379 - val_loss: 6342.1255 - val_mean_absolute_error: 56.4573 - val_mean_squared_error: 6342.1255
# Epoch 48/200
# 225/225 [==============================] - 101s 450ms/step - loss: 7646.0396 - mean_absolute_error: 64.1448 - mean_squared_error: 7646.0396 - val_loss: 6221.8979 - val_mean_absolute_error: 54.7725 - val_mean_squared_error: 6221.8979
# Epoch 49/200
# 225/225 [==============================] - 107s 477ms/step - loss: 7682.5908 - mean_absolute_error: 63.5645 - mean_squared_error: 7682.5908 - val_loss: 6096.9019 - val_mean_absolute_error: 52.6345 - val_mean_squared_error: 6096.9019
# Epoch 50/200
# 225/225 [==============================] - 108s 480ms/step - loss: 7418.7656 - mean_absolute_error: 62.4931 - mean_squared_error: 7418.7656 - val_loss: 5655.4102 - val_mean_absolute_error: 49.3837 - val_mean_squared_error: 5655.4102
# Epoch 51/200
# 225/225 [==============================] - 101s 450ms/step - loss: 7659.2222 - mean_absolute_error: 62.6170 - mean_squared_error: 7659.2222 - val_loss: 5608.0503 - val_mean_absolute_error: 51.6960 - val_mean_squared_error: 5608.0503
# Epoch 52/200
# 225/225 [==============================] - 171s 762ms/step - loss: 6509.2778 - mean_absolute_error: 58.5487 - mean_squared_error: 6509.2778 - val_loss: 6110.3384 - val_mean_absolute_error: 53.1689 - val_mean_squared_error: 6110.3384
# Epoch 53/200
# 225/225 [==============================] - 102s 454ms/step - loss: 7257.1929 - mean_absolute_error: 62.0609 - mean_squared_error: 7257.1929 - val_loss: 6393.9097 - val_mean_absolute_error: 54.8102 - val_mean_squared_error: 6393.9097
# Epoch 54/200
# 225/225 [==============================] - 111s 491ms/step - loss: 7256.1108 - mean_absolute_error: 62.3653 - mean_squared_error: 7256.1108 - val_loss: 6281.9604 - val_mean_absolute_error: 55.2741 - val_mean_squared_error: 6281.9604
# Epoch 55/200
# 225/225 [==============================] - 107s 473ms/step - loss: 7053.9048 - mean_absolute_error: 61.3222 - mean_squared_error: 7053.9048 - val_loss: 7408.2876 - val_mean_absolute_error: 58.0281 - val_mean_squared_error: 7408.2876
# Epoch 56/200
# 225/225 [==============================] - 106s 470ms/step - loss: 7474.8467 - mean_absolute_error: 61.2654 - mean_squared_error: 7474.8467 - val_loss: 5771.7339 - val_mean_absolute_error: 52.7971 - val_mean_squared_error: 5771.7339
# Epoch 57/200
# 225/225 [==============================] - 163s 724ms/step - loss: 6285.7261 - mean_absolute_error: 57.8796 - mean_squared_error: 6285.7261 - val_loss: 6604.7251 - val_mean_absolute_error: 55.4730 - val_mean_squared_error: 6604.7251
# Epoch 58/200
# 225/225 [==============================] - 103s 458ms/step - loss: 6489.4214 - mean_absolute_error: 58.6752 - mean_squared_error: 6489.4214 - val_loss: 5993.5547 - val_mean_absolute_error: 52.3942 - val_mean_squared_error: 5993.5547
# Epoch 59/200
# 225/225 [==============================] - 106s 473ms/step - loss: 6278.9614 - mean_absolute_error: 57.8342 - mean_squared_error: 6278.9614 - val_loss: 5627.4668 - val_mean_absolute_error: 50.6474 - val_mean_squared_error: 5627.4668
# Epoch 60/200
# 225/225 [==============================] - 105s 465ms/step - loss: 5849.2759 - mean_absolute_error: 55.7598 - mean_squared_error: 5849.2759 - val_loss: 5405.1494 - val_mean_absolute_error: 45.7484 - val_mean_squared_error: 5405.1494
# Epoch 61/200
# 225/225 [==============================] - 107s 478ms/step - loss: 6227.3960 - mean_absolute_error: 56.3862 - mean_squared_error: 6227.3960 - val_loss: 5484.7778 - val_mean_absolute_error: 48.6092 - val_mean_squared_error: 5484.7778
# Epoch 62/200
# 225/225 [==============================] - 156s 695ms/step - loss: 5942.7837 - mean_absolute_error: 56.1074 - mean_squared_error: 5942.7837 - val_loss: 5773.2778 - val_mean_absolute_error: 52.5903 - val_mean_squared_error: 5773.2778
# Epoch 63/200
# 225/225 [==============================] - 94s 416ms/step - loss: 5749.2188 - mean_absolute_error: 55.0227 - mean_squared_error: 5749.2188 - val_loss: 5054.8501 - val_mean_absolute_error: 46.0415 - val_mean_squared_error: 5054.8501
# Epoch 64/200
# 225/225 [==============================] - 104s 464ms/step - loss: 5442.0615 - mean_absolute_error: 53.9442 - mean_squared_error: 5442.0615 - val_loss: 4621.2646 - val_mean_absolute_error: 43.7527 - val_mean_squared_error: 4621.2646
# Epoch 65/200
# 225/225 [==============================] - 105s 466ms/step - loss: 5109.0366 - mean_absolute_error: 51.9191 - mean_squared_error: 5109.0366 - val_loss: 5324.4800 - val_mean_absolute_error: 48.5231 - val_mean_squared_error: 5324.4800
# Epoch 66/200
# 225/225 [==============================] - 105s 469ms/step - loss: 5193.4824 - mean_absolute_error: 52.4997 - mean_squared_error: 5193.4824 - val_loss: 5928.1113 - val_mean_absolute_error: 54.3870 - val_mean_squared_error: 5928.1113
# Epoch 67/200
# 225/225 [==============================] - 106s 472ms/step - loss: 4851.3267 - mean_absolute_error: 50.7253 - mean_squared_error: 4851.3267 - val_loss: 4355.2021 - val_mean_absolute_error: 43.8862 - val_mean_squared_error: 4355.2021
# Epoch 68/200
# 225/225 [==============================] - 147s 655ms/step - loss: 4502.0884 - mean_absolute_error: 49.4267 - mean_squared_error: 4502.0884 - val_loss: 5751.2051 - val_mean_absolute_error: 52.4846 - val_mean_squared_error: 5751.2051
# Epoch 69/200
# 225/225 [==============================] - 103s 458ms/step - loss: 4766.8706 - mean_absolute_error: 50.1742 - mean_squared_error: 4766.8706 - val_loss: 5197.5547 - val_mean_absolute_error: 46.8472 - val_mean_squared_error: 5197.5547
# Epoch 70/200
# 225/225 [==============================] - 105s 464ms/step - loss: 4741.7583 - mean_absolute_error: 50.4228 - mean_squared_error: 4741.7583 - val_loss: 4043.9600 - val_mean_absolute_error: 42.5736 - val_mean_squared_error: 4043.9600
# Epoch 71/200
# 225/225 [==============================] - 99s 441ms/step - loss: 4408.0610 - mean_absolute_error: 47.7840 - mean_squared_error: 4408.0610 - val_loss: 4171.2397 - val_mean_absolute_error: 41.9104 - val_mean_squared_error: 4171.2397
# Epoch 72/200
# 225/225 [==============================] - 99s 441ms/step - loss: 4346.8257 - mean_absolute_error: 48.0030 - mean_squared_error: 4346.8257 - val_loss: 4789.3491 - val_mean_absolute_error: 45.9509 - val_mean_squared_error: 4789.3491
# Epoch 73/200
# 225/225 [==============================] - 169s 751ms/step - loss: 3989.3232 - mean_absolute_error: 45.5550 - mean_squared_error: 3989.3232 - val_loss: 3740.9387 - val_mean_absolute_error: 39.8617 - val_mean_squared_error: 3740.9387
# Epoch 74/200
# 225/225 [==============================] - 98s 434ms/step - loss: 4025.9302 - mean_absolute_error: 45.0960 - mean_squared_error: 4025.9302 - val_loss: 3886.0962 - val_mean_absolute_error: 41.8844 - val_mean_squared_error: 3886.0962
# Epoch 75/200
# 225/225 [==============================] - 99s 441ms/step - loss: 4083.9563 - mean_absolute_error: 46.5059 - mean_squared_error: 4083.9563 - val_loss: 4972.7729 - val_mean_absolute_error: 46.8435 - val_mean_squared_error: 4972.7729
# Epoch 76/200
# 225/225 [==============================] - 101s 450ms/step - loss: 4704.0991 - mean_absolute_error: 49.4948 - mean_squared_error: 4704.0991 - val_loss: 5048.6548 - val_mean_absolute_error: 44.2926 - val_mean_squared_error: 5048.6548
# Epoch 77/200
# 225/225 [==============================] - 100s 443ms/step - loss: 4228.3354 - mean_absolute_error: 46.7975 - mean_squared_error: 4228.3354 - val_loss: 5413.3384 - val_mean_absolute_error: 48.6560 - val_mean_squared_error: 5413.3384
# Epoch 78/200
# 225/225 [==============================] - 97s 430ms/step - loss: 3800.6819 - mean_absolute_error: 44.8326 - mean_squared_error: 3800.6819 - val_loss: 3954.6626 - val_mean_absolute_error: 41.1357 - val_mean_squared_error: 3954.6626
# Epoch 79/200
# 225/225 [==============================] - 124s 554ms/step - loss: 3698.8394 - mean_absolute_error: 44.1238 - mean_squared_error: 3698.8394 - val_loss: 3386.3557 - val_mean_absolute_error: 38.7779 - val_mean_squared_error: 3386.3557
# Epoch 80/200
# 225/225 [==============================] - 92s 410ms/step - loss: 3483.6389 - mean_absolute_error: 43.0980 - mean_squared_error: 3483.6389 - val_loss: 4364.5103 - val_mean_absolute_error: 42.4742 - val_mean_squared_error: 4364.5103
# Epoch 81/200
# 225/225 [==============================] - 94s 418ms/step - loss: 3377.7065 - mean_absolute_error: 41.9843 - mean_squared_error: 3377.7065 - val_loss: 3562.1445 - val_mean_absolute_error: 38.4357 - val_mean_squared_error: 3562.1445
# Epoch 82/200
# 225/225 [==============================] - 91s 404ms/step - loss: 3357.7773 - mean_absolute_error: 42.3495 - mean_squared_error: 3357.7773 - val_loss: 5122.5142 - val_mean_absolute_error: 48.6996 - val_mean_squared_error: 5122.5142
# Epoch 83/200
# 225/225 [==============================] - 94s 416ms/step - loss: 3255.6040 - mean_absolute_error: 41.4490 - mean_squared_error: 3255.6040 - val_loss: 4074.3906 - val_mean_absolute_error: 44.1910 - val_mean_squared_error: 4074.3906
# Epoch 84/200
# 225/225 [==============================] - 96s 424ms/step - loss: 3061.3101 - mean_absolute_error: 40.5944 - mean_squared_error: 3061.3101 - val_loss: 3860.2131 - val_mean_absolute_error: 40.1650 - val_mean_squared_error: 3860.2131
# Epoch 85/200
# 225/225 [==============================] - 155s 690ms/step - loss: 2975.7358 - mean_absolute_error: 39.5946 - mean_squared_error: 2975.7358 - val_loss: 4143.2168 - val_mean_absolute_error: 40.8865 - val_mean_squared_error: 4143.2168
# Epoch 86/200
# 225/225 [==============================] - 89s 397ms/step - loss: 3125.4033 - mean_absolute_error: 40.3731 - mean_squared_error: 3125.4033 - val_loss: 3974.6580 - val_mean_absolute_error: 41.4104 - val_mean_squared_error: 3974.6580
# Epoch 87/200
# 225/225 [==============================] - 93s 414ms/step - loss: 3305.0713 - mean_absolute_error: 41.7865 - mean_squared_error: 3305.0713 - val_loss: 3596.1157 - val_mean_absolute_error: 39.8570 - val_mean_squared_error: 3596.1157
# Epoch 88/200
# 225/225 [==============================] - 94s 417ms/step - loss: 2923.0276 - mean_absolute_error: 38.6614 - mean_squared_error: 2923.0276 - val_loss: 3412.8833 - val_mean_absolute_error: 38.8335 - val_mean_squared_error: 3412.8833
# Epoch 89/200
# 225/225 [==============================] - 92s 407ms/step - loss: 2987.1826 - mean_absolute_error: 39.4929 - mean_squared_error: 2987.1826 - val_loss: 3395.2444 - val_mean_absolute_error: 38.3358 - val_mean_squared_error: 3395.2444
# Epoch 90/200
# 225/225 [==============================] - 143s 637ms/step - loss: 2722.8040 - mean_absolute_error: 37.8490 - mean_squared_error: 2722.8040 - val_loss: 2992.4236 - val_mean_absolute_error: 35.7270 - val_mean_squared_error: 2992.4236
# Epoch 91/200
# 225/225 [==============================] - 89s 394ms/step - loss: 2765.6475 - mean_absolute_error: 38.2061 - mean_squared_error: 2765.6475 - val_loss: 3597.7405 - val_mean_absolute_error: 39.0449 - val_mean_squared_error: 3597.7405
# Epoch 92/200
# 225/225 [==============================] - 87s 386ms/step - loss: 2855.6548 - mean_absolute_error: 38.1100 - mean_squared_error: 2855.6548 - val_loss: 3933.1780 - val_mean_absolute_error: 40.8307 - val_mean_squared_error: 3933.1780
# Epoch 93/200
# 225/225 [==============================] - 90s 402ms/step - loss: 3056.2351 - mean_absolute_error: 39.5038 - mean_squared_error: 3056.2351 - val_loss: 3960.7512 - val_mean_absolute_error: 40.2132 - val_mean_squared_error: 3960.7512
# Epoch 94/200
# 225/225 [==============================] - 91s 403ms/step - loss: 2486.7534 - mean_absolute_error: 36.3511 - mean_squared_error: 2486.7534 - val_loss: 3632.5276 - val_mean_absolute_error: 39.9264 - val_mean_squared_error: 3632.5276
# Epoch 95/200
# 225/225 [==============================] - 92s 410ms/step - loss: 2364.3530 - mean_absolute_error: 35.4476 - mean_squared_error: 2364.3530 - val_loss: 3386.8350 - val_mean_absolute_error: 36.2385 - val_mean_squared_error: 3386.8350
# Epoch 96/200
# 225/225 [==============================] - 91s 403ms/step - loss: 2371.9094 - mean_absolute_error: 35.1198 - mean_squared_error: 2371.9094 - val_loss: 3250.1819 - val_mean_absolute_error: 36.2725 - val_mean_squared_error: 3250.1819
# Epoch 97/200
# 225/225 [==============================] - 124s 550ms/step - loss: 2303.1870 - mean_absolute_error: 34.3723 - mean_squared_error: 2303.1870 - val_loss: 3413.2876 - val_mean_absolute_error: 36.8516 - val_mean_squared_error: 3413.2876
# Epoch 98/200
# 225/225 [==============================] - 88s 392ms/step - loss: 2324.5808 - mean_absolute_error: 34.8250 - mean_squared_error: 2324.5808 - val_loss: 3304.4504 - val_mean_absolute_error: 36.4779 - val_mean_squared_error: 3304.4504
# Epoch 99/200
# 225/225 [==============================] - 91s 406ms/step - loss: 2043.2408 - mean_absolute_error: 32.8223 - mean_squared_error: 2043.2408 - val_loss: 3349.0508 - val_mean_absolute_error: 34.9518 - val_mean_squared_error: 3349.0508
# Epoch 100/200
# 225/225 [==============================] - 90s 399ms/step - loss: 2183.1990 - mean_absolute_error: 33.4864 - mean_squared_error: 2183.1990 - val_loss: 3035.4089 - val_mean_absolute_error: 34.2598 - val_mean_squared_error: 3035.4089
# Epoch 101/200
# 225/225 [==============================] - 90s 402ms/step - loss: 2124.6631 - mean_absolute_error: 33.5803 - mean_squared_error: 2124.6631 - val_loss: 3076.5435 - val_mean_absolute_error: 35.7437 - val_mean_squared_error: 3076.5435
# Epoch 102/200
# 225/225 [==============================] - 94s 416ms/step - loss: 2041.5979 - mean_absolute_error: 32.7099 - mean_squared_error: 2041.5979 - val_loss: 3545.6824 - val_mean_absolute_error: 39.2419 - val_mean_squared_error: 3545.6824
# Epoch 103/200
# 225/225 [==============================] - 132s 585ms/step - loss: 1844.7061 - mean_absolute_error: 31.1399 - mean_squared_error: 1844.7061 - val_loss: 3851.0520 - val_mean_absolute_error: 39.9135 - val_mean_squared_error: 3851.0520
# Epoch 104/200
# 225/225 [==============================] - 89s 397ms/step - loss: 2005.5748 - mean_absolute_error: 32.0990 - mean_squared_error: 2005.5748 - val_loss: 2896.3308 - val_mean_absolute_error: 34.4329 - val_mean_squared_error: 2896.3308
# Epoch 105/200
# 225/225 [==============================] - 91s 406ms/step - loss: 2308.1477 - mean_absolute_error: 34.7963 - mean_squared_error: 2308.1477 - val_loss: 3402.0732 - val_mean_absolute_error: 38.0830 - val_mean_squared_error: 3402.0732
# Epoch 106/200
# 225/225 [==============================] - 93s 412ms/step - loss: 1888.1211 - mean_absolute_error: 31.3450 - mean_squared_error: 1888.1211 - val_loss: 3574.7986 - val_mean_absolute_error: 37.9411 - val_mean_squared_error: 3574.7986
# Epoch 107/200
# 225/225 [==============================] - 93s 414ms/step - loss: 1920.7203 - mean_absolute_error: 31.6032 - mean_squared_error: 1920.7203 - val_loss: 2859.5144 - val_mean_absolute_error: 32.7847 - val_mean_squared_error: 2859.5144
# Epoch 108/200
# 225/225 [==============================] - 91s 404ms/step - loss: 1713.6914 - mean_absolute_error: 29.6929 - mean_squared_error: 1713.6914 - val_loss: 3087.9570 - val_mean_absolute_error: 35.5461 - val_mean_squared_error: 3087.9570
# Epoch 109/200
# 225/225 [==============================] - 115s 510ms/step - loss: 1886.9347 - mean_absolute_error: 31.5423 - mean_squared_error: 1886.9347 - val_loss: 2971.7205 - val_mean_absolute_error: 35.2307 - val_mean_squared_error: 2971.7205
# Epoch 110/200
# 225/225 [==============================] - 88s 392ms/step - loss: 1733.7517 - mean_absolute_error: 30.5375 - mean_squared_error: 1733.7517 - val_loss: 3242.3777 - val_mean_absolute_error: 35.5930 - val_mean_squared_error: 3242.3777
# Epoch 111/200
# 225/225 [==============================] - 89s 397ms/step - loss: 1889.1754 - mean_absolute_error: 31.6002 - mean_squared_error: 1889.1754 - val_loss: 3205.2456 - val_mean_absolute_error: 34.9839 - val_mean_squared_error: 3205.2456
# Epoch 112/200
# 225/225 [==============================] - 92s 409ms/step - loss: 1636.5051 - mean_absolute_error: 29.4312 - mean_squared_error: 1636.5051 - val_loss: 2942.1777 - val_mean_absolute_error: 33.2866 - val_mean_squared_error: 2942.1777
# Epoch 113/200
# 225/225 [==============================] - 92s 408ms/step - loss: 1555.5776 - mean_absolute_error: 28.3738 - mean_squared_error: 1555.5776 - val_loss: 3090.5962 - val_mean_absolute_error: 35.1251 - val_mean_squared_error: 3090.5962
# Epoch 114/200
# 225/225 [==============================] - 90s 402ms/step - loss: 1380.8068 - mean_absolute_error: 27.2046 - mean_squared_error: 1380.8068 - val_loss: 3299.1467 - val_mean_absolute_error: 35.6707 - val_mean_squared_error: 3299.1467
# Epoch 115/200
# 225/225 [==============================] - 145s 643ms/step - loss: 1552.3756 - mean_absolute_error: 28.2908 - mean_squared_error: 1552.3756 - val_loss: 2930.4761 - val_mean_absolute_error: 33.2364 - val_mean_squared_error: 2930.4761
# Epoch 116/200
# 225/225 [==============================] - 87s 386ms/step - loss: 1422.2118 - mean_absolute_error: 27.1547 - mean_squared_error: 1422.2118 - val_loss: 3423.7593 - val_mean_absolute_error: 36.2839 - val_mean_squared_error: 3423.7593
# Epoch 117/200
# 225/225 [==============================] - 87s 387ms/step - loss: 1430.4520 - mean_absolute_error: 27.4175 - mean_squared_error: 1430.4520 - val_loss: 4023.3052 - val_mean_absolute_error: 40.3001 - val_mean_squared_error: 4023.3052
# Epoch 118/200
# 225/225 [==============================] - 91s 402ms/step - loss: 1352.8522 - mean_absolute_error: 26.7145 - mean_squared_error: 1352.8522 - val_loss: 2663.6714 - val_mean_absolute_error: 31.1842 - val_mean_squared_error: 2663.6714
# Epoch 119/200
# 225/225 [==============================] - 90s 398ms/step - loss: 1332.3971 - mean_absolute_error: 26.4488 - mean_squared_error: 1332.3971 - val_loss: 2852.2144 - val_mean_absolute_error: 32.5822 - val_mean_squared_error: 2852.2144
# Epoch 120/200
# 225/225 [==============================] - 90s 399ms/step - loss: 1461.0000 - mean_absolute_error: 27.5147 - mean_squared_error: 1461.0000 - val_loss: 3057.5542 - val_mean_absolute_error: 33.0752 - val_mean_squared_error: 3057.5542
# Epoch 121/200
# 225/225 [==============================] - 136s 605ms/step - loss: 1578.3165 - mean_absolute_error: 28.1335 - mean_squared_error: 1578.3165 - val_loss: 3117.6191 - val_mean_absolute_error: 34.5854 - val_mean_squared_error: 3117.6191
# Epoch 122/200
# 225/225 [==============================] - 93s 414ms/step - loss: 1365.1052 - mean_absolute_error: 26.7207 - mean_squared_error: 1365.1052 - val_loss: 3475.8599 - val_mean_absolute_error: 39.7142 - val_mean_squared_error: 3475.8599
# Epoch 123/200
# 225/225 [==============================] - 87s 385ms/step - loss: 1229.8655 - mean_absolute_error: 25.2351 - mean_squared_error: 1229.8655 - val_loss: 2763.9436 - val_mean_absolute_error: 32.4733 - val_mean_squared_error: 2763.9436
# Epoch 124/200
# 225/225 [==============================] - 88s 391ms/step - loss: 1266.5929 - mean_absolute_error: 25.7738 - mean_squared_error: 1266.5929 - val_loss: 3401.6501 - val_mean_absolute_error: 37.1227 - val_mean_squared_error: 3401.6501
# Epoch 125/200
# 225/225 [==============================] - 89s 396ms/step - loss: 1381.0381 - mean_absolute_error: 26.4789 - mean_squared_error: 1381.0381 - val_loss: 3559.0444 - val_mean_absolute_error: 36.0480 - val_mean_squared_error: 3559.0444
# Epoch 126/200
# 225/225 [==============================] - 97s 429ms/step - loss: 1237.3274 - mean_absolute_error: 25.2456 - mean_squared_error: 1237.3274 - val_loss: 2730.0630 - val_mean_absolute_error: 31.4874 - val_mean_squared_error: 2730.0630
# Epoch 127/200
# 225/225 [==============================] - 93s 415ms/step - loss: 1112.4751 - mean_absolute_error: 24.5296 - mean_squared_error: 1112.4751 - val_loss: 2910.4226 - val_mean_absolute_error: 33.4546 - val_mean_squared_error: 2910.4226
# Epoch 128/200
# 220/225 [============================>.] - ETA: 2s - loss: 1151.2689 - mean_absolute_error: 24.8184 - mean_squared_error: 1151.2689

# %% [markdown]
# ## Saving the network and the loss history for future use

# %%
hist_df = pd.DataFrame(CNN_history.history)  ## converting to dataframe for future usels
## Saving the history and the model
if NETWORK == "TL":
    if REG == True and CLA == True:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC'+'_history.csv')
    elif REG == True and CLA == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR'+'_history.csv')    
    elif CLA == True and REG == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC')        
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC'+'_history.csv')
    
else:    

    if REG == True and CLA == True:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelRC'+'_history.csv')
    elif REG == True and CLA == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelR')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelR'+'_history.csv')    
    elif CLA == True and REG == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelC'+'_history.csv')

# %% [markdown]
# # Loading the model

# %%
# Loading the model

if NETWORK == "TL":
    if REG == True and CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC')
    elif REG == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR')
    elif CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC')
        
    print("INFO:The Trained model {} at res {} is loaded ".format(NETWORK+'_'+str( transfer_model.__name__),str(X_res)))
else:
    if REG == True and CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
    elif REG == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelR')
    elif CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelC')



# CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
#Check its architecture
# CNN.summary()

# %% [markdown]
# ### Model Predictions and Results for the regression and Classification

# %%
test_index = 41 # 550  #550 ##210
if X_res >= 128:

    test_generator.reset()
    pred_CNN=CNN.predict(test_generator,
    steps=STEP_SIZE_TEST,
    verbose=1)
else:
    
    pred_CNN = CNN.predict(testImagesX)  
pred_CNN[test_index]

# %%
# plt.imshow(testImagesX[test_iclass_mode)
if REG == True:
    print("The predicted Values are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test_labels.iloc[test_index]))
elif CLA == True:
    print("The predicted prbability of the presence of planets are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],Y_test.iloc[test_index]))
    print("The predicted Values are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test_labels.iloc[test_index]))

# %%
# CNN_history.history
# Y_test.iloc[test_index]

# %%
# CNN_history.history ##val_fc_mean_squared_error val_fc_accuracy' val_dense_3_mean_squared_error val_dense_3_accuracy

###fc_mean_squared_error fc_accuracy dense_3_mean_squared_error dense_3_accuracy
hist =pd.DataFrame(CNN_history.history)
hist['epoch'] = hist.index = hist.index
hist
if NETWORK == "TL":
    plot_name = NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)
else:
    plot_name = NETWORK+'_'+str(X_res)
if  CLA == True and REG== False:
    cla_acc = CNN_history.history['accuracy']
    val_cla_acc = CNN_history.history['val_accuracy']
    cla_loss =CNN_history.history['loss']
    val_cla_loss = CNN_history.history['val_loss']
    
    plt.figure(figsize=(8, 8))
    # plt.subplot(2, 2, 1)
    plt.plot(hist['epoch'], cla_acc, label='cla-Training Accuracy')
    plt.plot(hist['epoch'], val_cla_acc, label='cla-Validation Accuracy')
    
    plt.legend(loc='upper right')
    plt.title('Classification Training and Validation Accuracy')
    plt.savefig('figures/'+plot_name+'_c.png')
    plt.show()
    
if REG == True and CLA == False:
    ## For Regression
    reg_mse = CNN_history.history['mean_squared_error']
    val_reg_mse =CNN_history.history['val_mean_squared_error']
    reg_loss =CNN_history.history['loss']
    val_reg_loss = CNN_history.history['val_loss']
    
    plt.figure(figsize=(8, 8))
    # plt.subplot(2, 2, 1)
    # plt.ylim(0,50000)
    plt.plot(hist['epoch'], reg_mse, label='reg-Training MSE')
    plt.plot(hist['epoch'], val_reg_mse, label='reg-Validation MSE')
    plt.legend(loc='upper right')
    plt.title('Regression Training and Validation MSE')
    plt.show()
    plt.savefig('figures/'+plot_name+'_r.png')

if REG == True and CLA == True:
    ## For classification
    cla_acc = CNN_history.history['cla_accuracy']
    val_cla_acc = CNN_history.history['val_cla_accuracy']
    cla_loss =CNN_history.history['cla_loss']
    val_cla_loss = CNN_history.history['val_cla_loss']

    ## For Regression
    reg_mse = CNN_history.history['reg_mean_squared_error']
    val_reg_mse =CNN_history.history['val_reg_mean_squared_error']
    reg_loss =CNN_history.history['reg_loss']
    val_reg_loss = CNN_history.history['val_reg_loss']
    
    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(hist['epoch'], cla_acc, label='cla-Training Accuracy')
    plt.plot(hist['epoch'], val_cla_acc, label='cla-Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Classification Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(hist['epoch'], reg_mse, label='reg-Training MSE')
    plt.plot(hist['epoch'], val_reg_mse, label='reg-Validation MSE')
    plt.legend(loc='upper right')
    plt.title('Regression Training and Validation MSE')
    plt.savefig('figures/'+plot_name+'_cr.png')
