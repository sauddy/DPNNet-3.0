# %% [markdown]
# # DPNNet-RT -- 22 October 2022
#
# ##### This notebook develops a ML model that can Classify and Predict the number of hidden planets and the corresponding planet mass for each of the planets from the protoplanetary disk images directly.

# %%
#####    Please note this version of the code is compatible with Google colab  ####
##################################### Mount the drive if running from Colab ##########################################
# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# ### IDEA behind this notebook :
# #### Authors : Sayantan and Subhrat
# #### Created : 3 Feb 2022
# #### This notebook is adopted from the DPNNet-2.0
#
# - Update 1: 24 Feb 2022 to include multi-outputs
# - Update 2: 22 October 2022 to include the all the date from the 700 FARGO3D calculations
#
# This notebook is developed to train the Model with Radiative Transfer (RT) images:
# We want to perform the following set of tasks
#
# P.S. This is a modular notebook that does the following:
#
#  1. Import all the customized Modules from Modules_DPNNet
#  2. For data processing we use data_processing_RT.py script
#  3. A functional module to call the different networks independently. (deep_models.py, other_cnn.py)
#  4. On October 2022, we are updating this notebook. We can now access the complete data but shall choose randomly from the images
#  5. Still only considering the axysymmetric images

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import cv2
import os
import csv

## Modules to check the performance of the code
from time import process_time 


## Importing the necessary TesnorFLow modules modules
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# from tensorflow.python.compiler.mlcompute import mlcompute
# mlcompute.set_mlc_device(device_name='gpu')

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from sklearn.metrics import r2_score ## form calcualting the r2 score
from sklearn.utils import shuffle
from tensorflow import keras as k
from keras_preprocessing.image import ImageDataGenerator
import tensorflow as tf
import keras_tuner as kt

## Trasfer Learning Models

from tensorflow.keras.applications import EfficientNetB0, EfficientNetB1 
from tensorflow.keras.applications import EfficientNetB2, EfficientNetB3
from tensorflow.keras.applications import EfficientNetB4, EfficientNetB5 
from tensorflow.keras.applications import EfficientNetB6, EfficientNetB7
from tensorflow.keras.applications import ResNet50,ResNet50V2
import re

## Modules for hyperparameter tuning keras-tuner
# import keras_tuner as kt

## Checking the availbale number of GPUs
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:",gpu.name,"Type:",gpu.device_type)
print("TensorFlow version used ",tf.__version__)
# Out:
# Num GPUs Available:  1
# Name: /physical_device:GPU:0 Type: GPU
# TensorFlow version used  2.10.0

# %% [markdown]
# #### Folder management

# %%
############ Please provide the path to the code directory if using Colab ################

# Path_gdrive= '/content/drive/MyDrive/ISU_Regresion/DPNNet-RT/' ## Comment out this line if using local computer

## Importing the Modules from Modules_DPNNet
import sys
try: ## tries to find the modules in the local directory first
  current_directory = os.getcwd()
  path = current_directory + '/' # For local computer 
#   path = '' # For local computer  
  sys.path.append(path+'MODULES_DPNNeT')
  import data_processing_RT as dp
  import deep_models as dm
  import other_cnns as ocn

########### Folders to save the processed data, files and figures when using Local computer ##############
  output_folder_list = ['data_folder','figures','saved_model']
  for file in output_folder_list:
    try:
        os.makedirs(file)
    except OSError:
        print ("Creation of the directory %s failed/ not needed as it already exit" % file)
    else:
        print ("Successfully created the directory %s" % file)
  
except ModuleNotFoundError:
  
  # #For Colab use:
  # #Point to the path containing the modules in the above section
  #(data folder are a directory above the directory containing the notebook)
  try:
    path = Path_gdrive
    print(path)
    sys.path.append(path+'MODULES_DPNNeT')
    import data_processing_RT as dp
    import deep_models as dm
    import other_cnns as ocn

    ########### Folders to save the processed data, files and figures when using GDRIVE ##############
    import os
    os.chdir(path)
    print("Creating the folders")
    # !mkdir -p data_folder
    # !mkdir -p figures ## to save the figures
    # !mkdir -p figures_paper
    # !mkdir -p saved_model
  except ModuleNotFoundError:
    print("The path to the modules is incorrect-- Provide current path")

print("[INFO] Modules imported")
# Out:
# We are currently using the Modules_DPCNet-RT
# Creation of the directory data_folder failed/ not needed as it already exit
# Creation of the directory figures failed/ not needed as it already exit
# Creation of the directory saved_model failed/ not needed as it already exit
# [INFO] Modules imported

# %% [markdown]
# ### Creating a csv with simulations params and path to each RT images

# %%
## Taking a look at the paramter file 
parameter_df = dp.load_parameter_csv(path)
parameter_df
# Out:
#      Planet_Mass1  Planet_Mass2  Planet_Mass3  Epsilon  Alpha    Stokes  \
# 0        0.000322       0.00204      0.001210    0.050  0.001  1.570000
# 1        0.002280       0.00154      0.000963    0.025  0.010  1.570000
# 2        0.002450       0.00262      0.002460    0.025  0.010  1.570000
# 3        0.000917       0.00195      0.001050    0.010  0.001  1.570000
# 4        0.001770       0.00187      0.002210    0.025  0.050  1.570000
# ..            ...           ...           ...      ...    ...       ...
# 695      0.002110       0.00000      0.000000    0.025  0.005  0.000157
# 696      0.002530       0.00000      0.000000    0.025  0.010  0.000157
# 697      0.000577       0.00000      0.000000    0.025  0.001  0.000157
# 698      0.001940       0.00000      0.000000    0.025  0.050  0.000157
# 699      0.002790       0.00000      0.000000    0.050  0.005  0.000157
#
#      Aspect_Ratio  SigmaSlope  Flaring_Index    Rp1   Rp2   Rp3  a_grain_mic
# 0          0.0432         1.0          0.010  1.010  2.19  3.22       3000.0
# 1          0.0561         1.0          0.075  0.943  2.16  3.37       1000.0
# 2          0.0261         1.0          0.075  1.160  1.84  3.15      10000.0
# 3          0.0496         1.0          0.250  1.100  1.82  2.99      10000.0
# 4          0.0625         1.0          0.075  0.863  2.08  3.32       3000.0
# ..            ...         ...            ...    ...   ...   ...          ...
# 695        0.0454         1.0          0.010  1.100  1.94  3.29        100.0
# 696        0.0882         1.0          0.075  0.851  1.99  3.10        100.0
# 697        0.0732         1.0          0.250  1.130  2.00  3.35        100.0
# 698        0.0711         1.0          0.075  0.966  2.02  3.32        100.0
# 699        0.0646         1.0          0.250  1.010  1.87  3.25        100.0
#
# [700 rows x 13 columns]

# %% [markdown]
# # Model Selections and Hyperparameters
#
# - Select the resolution of the images. For res > Cutoff_resolution, generators are used as that allow the network to load images during training directly from the data folder. For lower resolution images, those are loaded directly to the RAM memory.
# - Select number of sims and the nums of images from each sim for training
# - Regression or Classification: For Classification one can tune the hyperparameter of the layer succeding the main network
# - Select either network directly, so use transfer learning for the more advanced RESNET type networks
# - Select the batch sizes, epochs and initial learning rate. Note for hyper parameter tuning the default epoch is set to 10.

# %%
#### Desired Image resoltuion  and Batch Size #####
X_res = Y_res = 128

## For random sampling from the images
num_sims = 700 
axisymmetric = True
num_ims_per_sim = 30  ## Choose the number of images from each FARGO3D sims

## Select the kind of Traning ## Both can be selected as well
REG =True#True  ## When choosing regression
CLA =False #False #False #True  ## When Choosing Clasiffication

hyperparam_tune = False ## Only used when classification is true 

Cutoff_resolution = 64

## Select the Network type

# NETWORK = "Vanilla" ## Cannot be uses at the moment
# NETWORK = "ALEXNET"
# NETWORK = "VGG"
# NETWORK = "RESNET50"

                                ########## When using Trasnfer Learning ######################
NETWORK = "TL"
transfer_model= ResNet50
# transfer_model=EfficientNetB3

## Hyper-Parameter to define
batch_size = 50 ## 20 was for regression ## the best was for 200 last run
valid_batch_size = 100
epochs=100 ## best was 100
init_lr = 1e-5 # 1e-5 (works for regression)

# early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)
early_stop = keras.callbacks.EarlyStopping(monitor='mean_absolute_error', min_delta=1e-5,
                                           patience=20, verbose=1, mode='min',restore_best_weights=True)

# %% [markdown]
# #### Address to the data folder
# Genrating the .csv file with the image address to load them later

# %%
############# Address to the data folder ###################

# ## updating the image paths once the transfer is done
try:     
    list_RT_path = glob.glob(path+ 'image_directory_complete/'+ 'RT_A*') ## make a list of all the RT folder where each folder is for each sim
    # ## For google colab this needs to be updated
    list_sorted_RT_path  = sorted(list_RT_path, key=lambda f: [int(n) for n in re.findall(r"\d+", f)][-1]) ## sorting the images
    data_complete = dp.create_complete_data_csv(list_sorted_RT_path,path)
except ValueError:
    print("Looking for images in the folder above-- Please give the correct path to the images if images are not loaded")
    list_RT_path = glob.glob(path+ '../image_directory_complete/'+ 'RT_A*') ## make a list of all the RT folder where each folder is for each sim
    # ## For google colab this needs to be updated
    list_sorted_RT_path  = sorted(list_RT_path, key=lambda f: [int(n) for n in re.findall(r"\d+", f)][-1]) ## sorting the images
    data_complete = dp.create_complete_data_csv(list_sorted_RT_path,path)
    
    
# data_complete
## Removing the nan if any
data_complete.isna().sum()  # summing the number of na
data_complete= data_complete.dropna()
data_complete

# data_complete['Planet_Count'] = (data_complete.loc[:, ['Planet_Mass1', 'Planet_Mass2', 'Planet_Mass3']] != 0).sum(axis=1)
data_complete = shuffle(data_complete,random_state=42)
dc_list = []

for  i in range(1, num_sims+1):
  if axisymmetric == True:
    dc_list.append(data_complete.loc[data_complete['image_path'].str.contains('RT_A_' + str(i))][:num_ims_per_sim])
  else:
    dc_list.append(data_complete.loc[data_complete['image_path'].str.contains('RT_NA_' + str(i))][:num_ims_per_sim])

data_complete = pd.concat(dc_list)
data_complete = shuffle(data_complete,random_state=49)

def f(row):
    if (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] == 0) and (row['Planet_Mass3'] == 0):
        val = 1
    elif (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] == 0) and (row['Planet_Mass3'] != 0):
        val = 2
    elif (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] != 0) and (row['Planet_Mass3'] == 0):
        val = 3
    elif (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] != 0) and (row['Planet_Mass3'] != 0):
        val = 4
    return val

data_complete['Planet_Count'] = data_complete.apply(f, axis=1)
data_complete
# Out:
# [INFO]: Importing path for all the RT images
# [INFO]: Contatination of the paths of all the RT images are now complete
#        Planet_Mass1  Planet_Mass2  Planet_Mass3  Epsilon   Alpha    Stokes  \
# 70957    164.000000      0.000000    182.333333    0.050  0.0500  0.001570
# 74841    107.333333     60.000000    240.000000    0.025  0.0100  0.001570
# 66658    390.000000    261.000000    793.333333    0.050  0.0100  0.001570
# 63900    305.666667    483.333333    930.000000    0.010  0.0010  0.001570
# 76580    503.333333      0.000000      0.000000    0.010  0.0001  0.001570
# ...             ...           ...           ...      ...     ...       ...
# 40212    420.000000      0.000000      0.000000    0.025  0.0010  0.015700
# 39626    900.000000      0.000000      0.000000    0.025  0.0050  0.015700
# 98225    446.666667    333.333333    240.000000    0.025  0.0050  0.000157
# 79263     50.666667      0.000000      0.000000    0.010  0.0050  0.001570
# 23747     79.000000     65.666667    543.333333    0.025  0.0050  0.015700
#
#        Aspect_Ratio  SigmaSlope  Flaring_Index    Rp1   Rp2   Rp3  \
# 70957        0.0346         1.0          0.010  1.080  1.92  3.25
# 74841        0.0646         1.0          0.075  0.954  2.02  3.49
# 66658        0.0604         1.0          0.250  0.863  2.02  3.49
# 63900        0.0625         1.0          0.010  1.060  2.01  3.23
# 76580        0.0475         1.0          0.075  1.150  2.01  3.47
# ...             ...         ...            ...    ...   ...   ...
# 40212        0.0968         1.0          0.075  1.190  2.02  3.32
# 39626        0.0496         1.0          0.250  1.150  2.08  3.37
# 98225        0.0411         1.0          0.010  0.851  1.89  3.27
# 79263        0.0411         1.0          0.010  1.190  1.97  3.22
# 23747        0.0861         1.0          0.075  0.977  1.83  3.03
#
#        a_grain_mic                                         image_path  \
# 70957        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 74841        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 66658        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 63900        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 76580        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# ...            ...                                                ...
# 40212       3000.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 39626       1000.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 98225        100.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 79263        100.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 23747       3000.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
#
#        Planet_Count
# 70957             2
# 74841             4
# 66658             4
# 63900             4
# 76580             1
# ...             ...
# 40212             1
# 39626             1
# 98225             4
# 79263             1
# 23747             4
#
# [21000 rows x 15 columns]

# %% [markdown]
# ### Preparing data

# %%
## partition the data csv file into training and testing splits using 85% of
## the data for training and the remaining 15% for testing
split = train_test_split(data_complete, test_size=0.15, random_state=42)
(train, test) = split

## Save the train and the test data for future use as well.
test.to_csv(path+'data_folder/test_dataset.csv')
train.to_csv(path+'data_folder/train_dataset.csv')

## Generate the Normalized data
normed_train_data, normed_test_data, train_labels, test_labels = dp.process_the_disk_attributes(train, test, path,multi_label=True)
# Out:
# [INFO] preparing the normalized data training/testing split...
# Droping the irrelevant columns
# INFO: considering multiple planets as output
# [INFO] Done...

# %% [markdown]
# ### Loading the images or Creating the train, validation and test generators

# %%
import time
start = time.time()

if CLA == True:

        y_col = ['Planet_Count']

elif REG == True:
        y_col=["Planet_Mass1",'Planet_Mass2','Planet_Mass3']

        
        ###### Generate the training and the test images######
if X_res >= Cutoff_resolution:
    
    def custom_augmentation(np_tensor):

        '''
        This function is used to crop the images when those are loaded using the 
        ImageDataGenerator Keras function. This custom augmentation function only
        works for three different res as given below. For other resolutions the 
        image needs to the cropped appropiately.

        '''

        # # # dimensions for cropping the image
        if X_res == 64:
          top,left,bottom,right = 8,11,55,48
        if X_res == 128:
          top,left,bottom,right = 20,25,110,90 
        if X_res == 256:          
          top,left,bottom,right = 40,50,220,180          
        if X_res == 512:
          top,left,bottom,right = 60,90,450,380          
                
        image = np.squeeze(np_tensor) 
        crop_image = image[top:bottom, left:right]
        crop_image = cv2.resize(crop_image, (X_res, Y_res)) 
        crop_image = k.preprocessing.image.img_to_array(crop_image)
        return crop_image

#     datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,samplewise_center=True, samplewise_std_normalization=True,rescale=1./255.,validation_split=0.15)
#     datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,featurewise_center=True,featurewise_std_normalization=True,rescale=1./255.,validation_split=0.15)
    if transfer_model == ResNet50:
        datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,zca_epsilon = 100, zca_whitening=True,rescale=1./255.,validation_split=0.15)
    else:
        datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,validation_split=0.15)

    #### TRAINING GENERATOR #####
    train_generator=datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="image_path",
    y_col=y_col,
    subset="training",
    batch_size=batch_size,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(X_res,Y_res))

    #### VALIDATION GENERATOR #####
    validation_generator=datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="image_path",
    y_col=y_col,
    subset="validation",
    batch_size=batch_size,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(X_res,Y_res))

    #### TESTING GENERATOR #####
    test_datagen= k.preprocessing.image.ImageDataGenerator(preprocessing_function=custom_augmentation,zca_epsilon = 100, zca_whitening = True,rescale=1./255.)
    test_generator=test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=None,
    x_col="image_path",
    y_col=y_col,
    batch_size=batch_size,
    seed=42,
    shuffle=False,
    class_mode=None,
    target_size=(X_res,Y_res))
    
    
    ## STEP SIZES later used for training using generators
    STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
    STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

 

else:
    print("Uploading directly to RAM as the image resoltuion is manageable")
    trainImagesX = dp.load_disk_images(train, X_res, Y_res, Type = "Train")
    testImagesX = dp.load_disk_images(test, X_res, Y_res, Type = "Test")

Validation_split = 0.15 # 15 percent of the training data is used for validation
print('There are {} Train, {} Validation and {} Test images'.format(int((1-Validation_split)*len(normed_train_data)),int(Validation_split*len(normed_train_data)),len(normed_test_data)))## check the numbers in each category
end = time.time()
print("Total time elapsed =", end - start)

# # Getting all memory using os.popen()
# total_memory, used_memory, free_memory = map(
#     int, os.popen('free -t -m').readlines()[-1].split()[1:])
 
# # Memory usage
# print("RAM memory % used:", round((used_memory/total_memory) * 100, 2))
# Out:
# Found 15173 validated image filenames.
# Found 2677 validated image filenames.
# Found 3150 validated image filenames.
# There are 15172 Train, 2677 Validation and 3150 Test images
# Total time elapsed = 0.15023422241210938
# /opt/miniconda3/envs/proj/lib/python3.9/site-packages/keras_preprocessing/image/image_data_generator.py:337: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '
# /opt/miniconda3/envs/proj/lib/python3.9/site-packages/keras/preprocessing/image.py:1446: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn(

# %% [markdown]
# ### Checking image with cropping for verification

# %%
if X_res>= Cutoff_resolution:
    for _ in range(5):
        img, label = train_generator.next()
        print(img.shape)   #  (1,256,256,3)
        plt.imshow(img[0])
        plt.show()
else:
    plt.imshow(trainImagesX[5])
    plt.show()

# filenames =train_generator.filenames
# filenames[1]
# Out:
# /opt/miniconda3/envs/proj/lib/python3.9/site-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /opt/miniconda3/envs/proj/lib/python3.9/site-packages/keras_preprocessing/image/image_data_generator.py:739: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# (50, 128, 128, 3)
# (50, 128, 128, 3)
# (50, 128, 128, 3)
# (50, 128, 128, 3)
# (50, 128, 128, 3)

# %% [markdown]
# ## Preparing the Model Network

# %%
print('INFO: Currently training using the {} NETWORK with regression = {} and classification = {}'.format(NETWORK,REG,CLA))
if NETWORK == "Vanilla":
    CNN = dm.build_cnn(X_res, Y_res, 3, regress=True)
elif NETWORK == "ALEXNET":
    CNN = alexnet(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "VGG":
    CNN = cnn_vgg(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "RESNET50":
    # CNN = Resnet50(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
    CNN = ocn.Resnet50(X_res, Y_res, 3,classes=3,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "TL":      
    if hyperparam_tune == True and CLA ==True: 
        print("hyperparameters are only tuned for classification -- For regression hyperparams are standard and not tuned")
        hypermodel = ocn.TRANSFERLEARNINGHYPERMODEL(X_res, Y_res, 3,classes=1,regress = REG,multi_label=True,classification=CLA,option=None,transfer_model=transfer_model,
                                                   init_lr=init_lr,epochs=epochs)
        tuner_c=kt.RandomSearch(hypermodel,
            objective=kt.Objective('val_mean_absolute_error', direction="min"),
            max_trials=3,
            executions_per_trial=2,
            directory='tuner_c',
            project_name='ppd_c')
        tuner_c.search(train_generator,
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data=validation_generator,
                                validation_steps=STEP_SIZE_VALID,
                                epochs=10)
        CNN = tuner_c.get_best_models(num_models=1)[0]
    else : 
        
         CNN = ocn.TRANSFERLEARNING(X_res, Y_res, 3,classes=1,regress = REG,multi_label=True,classification=CLA,option=None,transfer_model=transfer_model,
                                                   init_lr=init_lr,epochs=epochs)
# Out:
# INFO: Currently training using the TL NETWORK with regression = True and classification = False
# IF the notebook is connected to internet then the weights can be directly downloaded-- Choose accordingly
# Metal device set to: Apple M1
# 2023-03-01 00:18:53.794504: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-01 00:18:53.794771: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# INFO:CNN is used for regression
# INFO: Note Multiple Labels are optimised during regression
# INFO: Regression Model is being trained

# %% [markdown]
# ## Training

# %%
if REG == True and CLA ==False:
    
    optimizer = tf.keras.optimizers.Adam(init_lr, decay=init_lr/epochs)
    CNN.compile(loss='mean_squared_error',
                    optimizer=optimizer,
                    metrics=['mean_absolute_error', 'mean_squared_error'])
    
    if X_res >= Cutoff_resolution:
        print("INFO: Switching to Generator as Resosultion is greater than {}: REGRESSION using GENERATORS".format(X_res))         
        CNN_history = CNN.fit(train_generator,
                            steps_per_epoch=STEP_SIZE_TRAIN,
                            validation_data=validation_generator,
                            validation_steps=STEP_SIZE_VALID,
                            epochs=epochs,callbacks=[early_stop])
    else:

        CNN_history = CNN.fit(x=trainImagesX, y=train_labels,
                          validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])

if REG == False and CLA ==True:
    
    optimizer = tf.keras.optimizers.Adam(init_lr, decay=init_lr/epochs)
    CNN.compile(loss='mean_squared_error',optimizer=optimizer,metrics=['mean_absolute_error'])
    
    if X_res >= Cutoff_resolution:          
        print("INFO: Switching to Generator as Resosultion is greater than {}: CLASSIFICATION using GENERATORS".format(X_res))  
        CNN_history = CNN.fit(train_generator,
                            steps_per_epoch=STEP_SIZE_TRAIN,
                            validation_data=validation_generator,
                            validation_steps=STEP_SIZE_VALID,
                            epochs=epochs,callbacks=[early_stop])
    else: 
        
        CNN_history = CNN.fit(x=trainImagesX, y=Y_train,
                      validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])

if REG == True and CLA ==True:
    
    # When used for classification and regression
    CNN.compile(loss=['mean_squared_error','binary_crossentropy'],optimizer=optimizer,metrics=['mean_squared_error', 'accuracy'])

    CNN_history = CNN.fit(x=X_train, y=[train_labels,Y_train],
                      validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])
    
# total_memory, used_memory, free_memory = map(
# int, os.popen('free -t -m').readlines()[-1].split()[1:])

# # Memory usage
# print("RAM memory % used:", round((used_memory/total_memory) * 100, 2))
# Out:
# INFO: Switching to Generator as Resosultion is greater than 128: REGRESSION using GENERATORS
# Epoch 1/100
# 2023-03-01 00:21:11.124490: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-01 00:21:12.625326: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 303/303 [==============================] - ETA: 0s - loss: 212137.9531 - mean_absolute_error: 331.8757 - mean_squared_error: 212137.9531
# 2023-03-01 00:24:17.680870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 303/303 [==============================] - 200s 650ms/step - loss: 212137.9531 - mean_absolute_error: 331.8757 - mean_squared_error: 212137.9531 - val_loss: 218559.6094 - val_mean_absolute_error: 334.5167 - val_mean_squared_error: 218559.6094
# Epoch 2/100
# 303/303 [==============================] - 195s 644ms/step - loss: 192650.2500 - mean_absolute_error: 318.6912 - mean_squared_error: 192650.2500 - val_loss: 214416.7656 - val_mean_absolute_error: 331.9216 - val_mean_squared_error: 214416.7656
# Epoch 3/100
# 303/303 [==============================] - 195s 644ms/step - loss: 177422.8750 - mean_absolute_error: 307.4609 - mean_squared_error: 177422.8750 - val_loss: 184157.5625 - val_mean_absolute_error: 307.5836 - val_mean_squared_error: 184157.5625
# Epoch 4/100
# 303/303 [==============================] - 195s 643ms/step - loss: 163400.3438 - mean_absolute_error: 296.5344 - mean_squared_error: 163400.3438 - val_loss: 142237.2188 - val_mean_absolute_error: 272.8060 - val_mean_squared_error: 142237.2188
# Epoch 5/100
# 303/303 [==============================] - 194s 639ms/step - loss: 149615.1875 - mean_absolute_error: 285.2372 - mean_squared_error: 149615.1875 - val_loss: 133108.2969 - val_mean_absolute_error: 269.5336 - val_mean_squared_error: 133108.2969
# Epoch 6/100
# 303/303 [==============================] - 193s 637ms/step - loss: 136446.2500 - mean_absolute_error: 273.8044 - mean_squared_error: 136446.2500 - val_loss: 124779.4844 - val_mean_absolute_error: 260.6222 - val_mean_squared_error: 124779.4844
# Epoch 7/100
# 303/303 [==============================] - 193s 638ms/step - loss: 123953.6094 - mean_absolute_error: 262.2676 - mean_squared_error: 123953.6094 - val_loss: 119359.9297 - val_mean_absolute_error: 259.0020 - val_mean_squared_error: 119359.9375
# Epoch 8/100
# 303/303 [==============================] - 193s 636ms/step - loss: 112275.9688 - mean_absolute_error: 250.3714 - mean_squared_error: 112275.9766 - val_loss: 107193.4453 - val_mean_absolute_error: 247.4096 - val_mean_squared_error: 107193.4453
# Epoch 9/100
# 303/303 [==============================] - 193s 638ms/step - loss: 100630.0469 - mean_absolute_error: 237.8239 - mean_squared_error: 100630.0469 - val_loss: 91967.6016 - val_mean_absolute_error: 228.8994 - val_mean_squared_error: 91967.6094
# Epoch 10/100
# 303/303 [==============================] - 190s 627ms/step - loss: 90875.1641 - mean_absolute_error: 226.3425 - mean_squared_error: 90875.1641 - val_loss: 90637.8281 - val_mean_absolute_error: 226.4368 - val_mean_squared_error: 90637.8281
# Epoch 11/100
# 303/303 [==============================] - 189s 623ms/step - loss: 81951.7031 - mean_absolute_error: 216.0051 - mean_squared_error: 81951.7031 - val_loss: 75839.1250 - val_mean_absolute_error: 209.4195 - val_mean_squared_error: 75839.1250
# Epoch 12/100
# 303/303 [==============================] - 192s 632ms/step - loss: 72907.1484 - mean_absolute_error: 203.8393 - mean_squared_error: 72907.1484 - val_loss: 68278.1328 - val_mean_absolute_error: 198.0150 - val_mean_squared_error: 68278.1406
# Epoch 13/100
# 303/303 [==============================] - 189s 622ms/step - loss: 66279.1328 - mean_absolute_error: 193.9131 - mean_squared_error: 66279.1328 - val_loss: 56790.7148 - val_mean_absolute_error: 180.8116 - val_mean_squared_error: 56790.7148
# Epoch 14/100
# 303/303 [==============================] - 189s 622ms/step - loss: 59310.2344 - mean_absolute_error: 185.5714 - mean_squared_error: 59310.2422 - val_loss: 62645.9883 - val_mean_absolute_error: 191.9415 - val_mean_squared_error: 62645.9883
# Epoch 15/100
# 303/303 [==============================] - 189s 622ms/step - loss: 55834.1172 - mean_absolute_error: 178.8595 - mean_squared_error: 55834.1211 - val_loss: 50128.1992 - val_mean_absolute_error: 170.3081 - val_mean_squared_error: 50128.1992
# Epoch 16/100
# 303/303 [==============================] - 189s 622ms/step - loss: 47939.4102 - mean_absolute_error: 166.3607 - mean_squared_error: 47939.4102 - val_loss: 46305.1836 - val_mean_absolute_error: 163.4340 - val_mean_squared_error: 46305.1836
# Epoch 17/100
# 303/303 [==============================] - 189s 625ms/step - loss: 43339.0000 - mean_absolute_error: 157.1587 - mean_squared_error: 43339.0000 - val_loss: 43153.4688 - val_mean_absolute_error: 155.3085 - val_mean_squared_error: 43153.4688
# Epoch 18/100
# 303/303 [==============================] - 189s 624ms/step - loss: 39075.5625 - mean_absolute_error: 148.3522 - mean_squared_error: 39075.5625 - val_loss: 34133.7891 - val_mean_absolute_error: 138.8464 - val_mean_squared_error: 34133.7891
# Epoch 19/100
# 303/303 [==============================] - 189s 623ms/step - loss: 36498.4766 - mean_absolute_error: 143.2269 - mean_squared_error: 36498.4805 - val_loss: 30820.2949 - val_mean_absolute_error: 131.1269 - val_mean_squared_error: 30820.2949
# Epoch 20/100
# 303/303 [==============================] - 190s 625ms/step - loss: 32008.9883 - mean_absolute_error: 133.4148 - mean_squared_error: 32008.9883 - val_loss: 28669.6973 - val_mean_absolute_error: 125.1782 - val_mean_squared_error: 28669.6973
# Epoch 21/100
# 303/303 [==============================] - 195s 643ms/step - loss: 30745.5527 - mean_absolute_error: 130.3200 - mean_squared_error: 30745.5527 - val_loss: 34724.7617 - val_mean_absolute_error: 136.2046 - val_mean_squared_error: 34724.7617
# Epoch 22/100
# 303/303 [==============================] - 192s 633ms/step - loss: 27020.5605 - mean_absolute_error: 120.0038 - mean_squared_error: 27020.5605 - val_loss: 22485.5977 - val_mean_absolute_error: 108.7203 - val_mean_squared_error: 22485.5977
# Epoch 23/100
# 303/303 [==============================] - 194s 639ms/step - loss: 23664.8203 - mean_absolute_error: 112.0458 - mean_squared_error: 23664.8203 - val_loss: 18542.5371 - val_mean_absolute_error: 99.7852 - val_mean_squared_error: 18542.5410
# Epoch 24/100
# 303/303 [==============================] - 195s 643ms/step - loss: 21430.3086 - mean_absolute_error: 106.5985 - mean_squared_error: 21430.3086 - val_loss: 27051.5645 - val_mean_absolute_error: 119.0429 - val_mean_squared_error: 27051.5684
# Epoch 25/100
# 303/303 [==============================] - 194s 641ms/step - loss: 20522.3223 - mean_absolute_error: 103.1718 - mean_squared_error: 20522.3242 - val_loss: 19340.8262 - val_mean_absolute_error: 104.0509 - val_mean_squared_error: 19340.8262
# Epoch 26/100
# 303/303 [==============================] - 194s 641ms/step - loss: 18124.7969 - mean_absolute_error: 95.6528 - mean_squared_error: 18124.7988 - val_loss: 15591.9561 - val_mean_absolute_error: 87.3869 - val_mean_squared_error: 15591.9561
# Epoch 27/100
# 303/303 [==============================] - 195s 642ms/step - loss: 16482.9180 - mean_absolute_error: 89.8163 - mean_squared_error: 16482.9180 - val_loss: 16623.6289 - val_mean_absolute_error: 92.9123 - val_mean_squared_error: 16623.6289
# Epoch 28/100
# 303/303 [==============================] - 193s 636ms/step - loss: 16711.5859 - mean_absolute_error: 90.6885 - mean_squared_error: 16711.5859 - val_loss: 12814.6963 - val_mean_absolute_error: 77.5344 - val_mean_squared_error: 12814.6963
# Epoch 29/100
# 303/303 [==============================] - 193s 637ms/step - loss: 15443.9072 - mean_absolute_error: 84.2521 - mean_squared_error: 15443.9072 - val_loss: 11741.1670 - val_mean_absolute_error: 74.2594 - val_mean_squared_error: 11741.1670
# Epoch 30/100
# 303/303 [==============================] - 194s 638ms/step - loss: 13301.7285 - mean_absolute_error: 80.5578 - mean_squared_error: 13301.7285 - val_loss: 10108.7822 - val_mean_absolute_error: 69.1656 - val_mean_squared_error: 10108.7822
# Epoch 31/100
# 303/303 [==============================] - 187s 616ms/step - loss: 12012.5977 - mean_absolute_error: 76.8105 - mean_squared_error: 12012.5977 - val_loss: 9625.1758 - val_mean_absolute_error: 70.5264 - val_mean_squared_error: 9625.1777
# Epoch 32/100
# 303/303 [==============================] - 191s 629ms/step - loss: 11346.3203 - mean_absolute_error: 75.3329 - mean_squared_error: 11346.3203 - val_loss: 11360.2461 - val_mean_absolute_error: 72.6292 - val_mean_squared_error: 11360.2461
# Epoch 33/100
# 303/303 [==============================] - 193s 637ms/step - loss: 9920.5977 - mean_absolute_error: 69.2406 - mean_squared_error: 9920.5977 - val_loss: 8464.0635 - val_mean_absolute_error: 62.1913 - val_mean_squared_error: 8464.0645
# Epoch 34/100
# 303/303 [==============================] - 190s 625ms/step - loss: 11161.0762 - mean_absolute_error: 71.2338 - mean_squared_error: 11161.0762 - val_loss: 9779.2100 - val_mean_absolute_error: 64.5746 - val_mean_squared_error: 9779.2109
# Epoch 35/100
# 303/303 [==============================] - 187s 617ms/step - loss: 10685.1035 - mean_absolute_error: 70.2882 - mean_squared_error: 10685.1035 - val_loss: 13281.3555 - val_mean_absolute_error: 83.0487 - val_mean_squared_error: 13281.3555
# Epoch 36/100
# 303/303 [==============================] - 187s 615ms/step - loss: 9545.3633 - mean_absolute_error: 69.2878 - mean_squared_error: 9545.3633 - val_loss: 7976.6338 - val_mean_absolute_error: 58.9595 - val_mean_squared_error: 7976.6348
# Epoch 37/100
# 303/303 [==============================] - 189s 623ms/step - loss: 9559.5537 - mean_absolute_error: 67.7142 - mean_squared_error: 9559.5537 - val_loss: 10207.6611 - val_mean_absolute_error: 66.9523 - val_mean_squared_error: 10207.6611
# Epoch 38/100
# 303/303 [==============================] - 186s 613ms/step - loss: 11102.0742 - mean_absolute_error: 72.0422 - mean_squared_error: 11102.0742 - val_loss: 8132.3623 - val_mean_absolute_error: 61.7681 - val_mean_squared_error: 8132.3623
# Epoch 39/100
# 303/303 [==============================] - 186s 613ms/step - loss: 8816.2363 - mean_absolute_error: 66.7026 - mean_squared_error: 8816.2363 - val_loss: 7942.6255 - val_mean_absolute_error: 62.3138 - val_mean_squared_error: 7942.6255
# Epoch 40/100
# 303/303 [==============================] - 186s 615ms/step - loss: 7996.8516 - mean_absolute_error: 63.0658 - mean_squared_error: 7996.8521 - val_loss: 6399.6499 - val_mean_absolute_error: 51.5617 - val_mean_squared_error: 6399.6499
# Epoch 41/100
# 303/303 [==============================] - 192s 634ms/step - loss: 7465.4282 - mean_absolute_error: 61.2859 - mean_squared_error: 7465.4282 - val_loss: 7761.5933 - val_mean_absolute_error: 64.1453 - val_mean_squared_error: 7761.5933
# Epoch 42/100
# 303/303 [==============================] - 186s 614ms/step - loss: 6978.4087 - mean_absolute_error: 59.4580 - mean_squared_error: 6978.4087 - val_loss: 4016.7488 - val_mean_absolute_error: 43.3433 - val_mean_squared_error: 4016.7488
# Epoch 43/100
# 303/303 [==============================] - 187s 617ms/step - loss: 6497.1309 - mean_absolute_error: 56.4938 - mean_squared_error: 6497.1309 - val_loss: 8551.6260 - val_mean_absolute_error: 63.7350 - val_mean_squared_error: 8551.6260
# Epoch 44/100
# 303/303 [==============================] - 192s 631ms/step - loss: 7404.7559 - mean_absolute_error: 59.1264 - mean_squared_error: 7404.7563 - val_loss: 5258.0669 - val_mean_absolute_error: 48.5433 - val_mean_squared_error: 5258.0669
# Epoch 45/100
# 303/303 [==============================] - 192s 632ms/step - loss: 6612.4150 - mean_absolute_error: 56.0558 - mean_squared_error: 6612.4150 - val_loss: 4860.8584 - val_mean_absolute_error: 44.5083 - val_mean_squared_error: 4860.8589
# Epoch 46/100
# 303/303 [==============================] - 192s 633ms/step - loss: 6163.7837 - mean_absolute_error: 54.3748 - mean_squared_error: 6163.7837 - val_loss: 4251.0972 - val_mean_absolute_error: 42.1530 - val_mean_squared_error: 4251.0972
# Epoch 47/100
# 303/303 [==============================] - 193s 636ms/step - loss: 5432.6177 - mean_absolute_error: 51.8444 - mean_squared_error: 5432.6177 - val_loss: 5643.8794 - val_mean_absolute_error: 48.7780 - val_mean_squared_error: 5643.8794
# Epoch 48/100
# 303/303 [==============================] - 192s 633ms/step - loss: 5471.7109 - mean_absolute_error: 51.5472 - mean_squared_error: 5471.7109 - val_loss: 6100.8657 - val_mean_absolute_error: 53.0563 - val_mean_squared_error: 6100.8657
# Epoch 49/100
# 303/303 [==============================] - 192s 632ms/step - loss: 6687.5854 - mean_absolute_error: 54.3514 - mean_squared_error: 6687.5854 - val_loss: 4846.3896 - val_mean_absolute_error: 47.5562 - val_mean_squared_error: 4846.3896
# Epoch 50/100
# 303/303 [==============================] - 192s 633ms/step - loss: 5453.9795 - mean_absolute_error: 51.3625 - mean_squared_error: 5453.9795 - val_loss: 3772.1169 - val_mean_absolute_error: 43.3090 - val_mean_squared_error: 3772.1169
# Epoch 51/100
# 303/303 [==============================] - 192s 633ms/step - loss: 4938.9038 - mean_absolute_error: 49.4248 - mean_squared_error: 4938.9043 - val_loss: 4330.3896 - val_mean_absolute_error: 46.2760 - val_mean_squared_error: 4330.3896
# Epoch 52/100
# 303/303 [==============================] - 192s 632ms/step - loss: 7309.9521 - mean_absolute_error: 59.3224 - mean_squared_error: 7309.9521 - val_loss: 6170.6172 - val_mean_absolute_error: 54.5079 - val_mean_squared_error: 6170.6172
# Epoch 53/100
# 303/303 [==============================] - 192s 634ms/step - loss: 5877.5679 - mean_absolute_error: 53.5751 - mean_squared_error: 5877.5679 - val_loss: 3988.8132 - val_mean_absolute_error: 44.8481 - val_mean_squared_error: 3988.8132
# Epoch 54/100
# 303/303 [==============================] - 192s 634ms/step - loss: 4425.2720 - mean_absolute_error: 47.1455 - mean_squared_error: 4425.2729 - val_loss: 2698.2654 - val_mean_absolute_error: 34.8996 - val_mean_squared_error: 2698.2654
# Epoch 55/100
# 303/303 [==============================] - 192s 633ms/step - loss: 3965.9749 - mean_absolute_error: 44.4079 - mean_squared_error: 3965.9749 - val_loss: 2373.9446 - val_mean_absolute_error: 32.3400 - val_mean_squared_error: 2373.9446
# Epoch 56/100
# 303/303 [==============================] - 192s 634ms/step - loss: 3868.9285 - mean_absolute_error: 44.1588 - mean_squared_error: 3868.9285 - val_loss: 3188.4434 - val_mean_absolute_error: 40.1031 - val_mean_squared_error: 3188.4434
# Epoch 57/100
# 303/303 [==============================] - 192s 633ms/step - loss: 3688.7651 - mean_absolute_error: 42.5057 - mean_squared_error: 3688.7651 - val_loss: 7166.9429 - val_mean_absolute_error: 55.3809 - val_mean_squared_error: 7166.9429
# Epoch 58/100
# 303/303 [==============================] - 192s 632ms/step - loss: 3706.0830 - mean_absolute_error: 42.9946 - mean_squared_error: 3706.0830 - val_loss: 3434.3708 - val_mean_absolute_error: 40.2938 - val_mean_squared_error: 3434.3708
# Epoch 59/100
# 303/303 [==============================] - 192s 633ms/step - loss: 3778.4136 - mean_absolute_error: 42.7897 - mean_squared_error: 3778.4138 - val_loss: 6213.4712 - val_mean_absolute_error: 54.0374 - val_mean_squared_error: 6213.4712
# Epoch 60/100
# 303/303 [==============================] - 192s 634ms/step - loss: 3600.2324 - mean_absolute_error: 42.0166 - mean_squared_error: 3600.2324 - val_loss: 2687.1729 - val_mean_absolute_error: 35.5410 - val_mean_squared_error: 2687.1731
# Epoch 61/100
# 303/303 [==============================] - 192s 635ms/step - loss: 3056.3079 - mean_absolute_error: 39.1761 - mean_squared_error: 3056.3079 - val_loss: 2762.9829 - val_mean_absolute_error: 36.2011 - val_mean_squared_error: 2762.9829
# Epoch 62/100
# 303/303 [==============================] - 192s 633ms/step - loss: 3102.9922 - mean_absolute_error: 39.1845 - mean_squared_error: 3102.9922 - val_loss: 2580.4597 - val_mean_absolute_error: 34.9453 - val_mean_squared_error: 2580.4597
# Epoch 63/100
# 303/303 [==============================] - 192s 634ms/step - loss: 3119.6375 - mean_absolute_error: 38.9332 - mean_squared_error: 3119.6377 - val_loss: 2885.4807 - val_mean_absolute_error: 34.1072 - val_mean_squared_error: 2885.4807
# Epoch 64/100
# 303/303 [==============================] - 192s 633ms/step - loss: 2860.9570 - mean_absolute_error: 37.8147 - mean_squared_error: 2860.9570 - val_loss: 2347.6399 - val_mean_absolute_error: 32.5491 - val_mean_squared_error: 2347.6399
# Epoch 65/100
# 303/303 [==============================] - 192s 633ms/step - loss: 2721.1787 - mean_absolute_error: 36.6213 - mean_squared_error: 2721.1787 - val_loss: 1899.7919 - val_mean_absolute_error: 27.9376 - val_mean_squared_error: 1899.7919
# Epoch 66/100
# 303/303 [==============================] - 192s 633ms/step - loss: 2551.8801 - mean_absolute_error: 35.5798 - mean_squared_error: 2551.8801 - val_loss: 2883.1399 - val_mean_absolute_error: 35.2371 - val_mean_squared_error: 2883.1399
# Epoch 67/100
# 303/303 [==============================] - 193s 636ms/step - loss: 2342.2009 - mean_absolute_error: 34.3907 - mean_squared_error: 2342.2009 - val_loss: 2058.4324 - val_mean_absolute_error: 28.2472 - val_mean_squared_error: 2058.4324
# Epoch 68/100
# 303/303 [==============================] - 193s 636ms/step - loss: 2266.9509 - mean_absolute_error: 33.8282 - mean_squared_error: 2266.9509 - val_loss: 2046.4844 - val_mean_absolute_error: 28.7700 - val_mean_squared_error: 2046.4844
# Epoch 69/100
# 303/303 [==============================] - 192s 635ms/step - loss: 2101.3997 - mean_absolute_error: 32.7530 - mean_squared_error: 2101.3997 - val_loss: 1811.4520 - val_mean_absolute_error: 27.6874 - val_mean_squared_error: 1811.4520
# Epoch 70/100
# 303/303 [==============================] - 192s 633ms/step - loss: 2374.0994 - mean_absolute_error: 33.9511 - mean_squared_error: 2374.0994 - val_loss: 3104.1931 - val_mean_absolute_error: 36.1506 - val_mean_squared_error: 3104.1931
# Epoch 71/100
# 303/303 [==============================] - 192s 633ms/step - loss: 2085.5586 - mean_absolute_error: 32.3911 - mean_squared_error: 2085.5588 - val_loss: 2321.3232 - val_mean_absolute_error: 32.0017 - val_mean_squared_error: 2321.3232
# Epoch 72/100
# 303/303 [==============================] - 192s 633ms/step - loss: 2188.6143 - mean_absolute_error: 33.0812 - mean_squared_error: 2188.6143 - val_loss: 2770.7986 - val_mean_absolute_error: 33.7104 - val_mean_squared_error: 2770.7988
# Epoch 73/100
# 303/303 [==============================] - 192s 633ms/step - loss: 1995.4457 - mean_absolute_error: 31.3110 - mean_squared_error: 1995.4457 - val_loss: 1749.2939 - val_mean_absolute_error: 27.8163 - val_mean_squared_error: 1749.2939
# Epoch 74/100
# 303/303 [==============================] - 192s 635ms/step - loss: 1880.8151 - mean_absolute_error: 30.9299 - mean_squared_error: 1880.8154 - val_loss: 3199.2446 - val_mean_absolute_error: 38.8193 - val_mean_squared_error: 3199.2446
# Epoch 75/100
# 303/303 [==============================] - 192s 633ms/step - loss: 1724.8174 - mean_absolute_error: 29.5566 - mean_squared_error: 1724.8174 - val_loss: 1683.4840 - val_mean_absolute_error: 25.7526 - val_mean_squared_error: 1683.4840
# Epoch 76/100
# 303/303 [==============================] - 192s 632ms/step - loss: 1860.4414 - mean_absolute_error: 30.4161 - mean_squared_error: 1860.4414 - val_loss: 2155.5103 - val_mean_absolute_error: 30.4781 - val_mean_squared_error: 2155.5103
# Epoch 77/100
# 303/303 [==============================] - 192s 633ms/step - loss: 1835.8813 - mean_absolute_error: 30.5371 - mean_squared_error: 1835.8813 - val_loss: 1672.7560 - val_mean_absolute_error: 27.0800 - val_mean_squared_error: 1672.7560
# Epoch 78/100
# 303/303 [==============================] - 192s 633ms/step - loss: 1602.1337 - mean_absolute_error: 28.2037 - mean_squared_error: 1602.1337 - val_loss: 1614.2722 - val_mean_absolute_error: 26.0774 - val_mean_squared_error: 1614.2722
# Epoch 79/100
# 303/303 [==============================] - 192s 633ms/step - loss: 1665.3612 - mean_absolute_error: 28.9336 - mean_squared_error: 1665.3613 - val_loss: 2256.8271 - val_mean_absolute_error: 31.1915 - val_mean_squared_error: 2256.8271
# Epoch 80/100
# 303/303 [==============================] - 192s 634ms/step - loss: 1605.7408 - mean_absolute_error: 28.4697 - mean_squared_error: 1605.7408 - val_loss: 2154.4500 - val_mean_absolute_error: 30.1101 - val_mean_squared_error: 2154.4500
# Epoch 81/100
# 303/303 [==============================] - 188s 619ms/step - loss: 1478.0975 - mean_absolute_error: 27.4857 - mean_squared_error: 1478.0975 - val_loss: 1359.7542 - val_mean_absolute_error: 23.4661 - val_mean_squared_error: 1359.7542
# Epoch 82/100
# 303/303 [==============================] - 14894s 49s/step - loss: 1417.5040 - mean_absolute_error: 26.6505 - mean_squared_error: 1417.5040 - val_loss: 1961.8557 - val_mean_absolute_error: 28.5295 - val_mean_squared_error: 1961.8557
# Epoch 83/100
# 303/303 [==============================] - 21304s 71s/step - loss: 1549.4702 - mean_absolute_error: 27.8050 - mean_squared_error: 1549.4702 - val_loss: 1607.9474 - val_mean_absolute_error: 25.5494 - val_mean_squared_error: 1607.9474
# Epoch 84/100
# 303/303 [==============================] - 189s 624ms/step - loss: 1440.2124 - mean_absolute_error: 26.4741 - mean_squared_error: 1440.2124 - val_loss: 1509.4884 - val_mean_absolute_error: 24.8151 - val_mean_squared_error: 1509.4884
# Epoch 85/100
# 303/303 [==============================] - 191s 628ms/step - loss: 1313.3149 - mean_absolute_error: 25.7160 - mean_squared_error: 1313.3149 - val_loss: 2074.4236 - val_mean_absolute_error: 30.6217 - val_mean_squared_error: 2074.4236
# Epoch 86/100
# 303/303 [==============================] - 191s 628ms/step - loss: 1327.3612 - mean_absolute_error: 26.0864 - mean_squared_error: 1327.3612 - val_loss: 1367.2632 - val_mean_absolute_error: 23.4387 - val_mean_squared_error: 1367.2632
# Epoch 87/100
# 303/303 [==============================] - 190s 625ms/step - loss: 1189.1224 - mean_absolute_error: 24.3782 - mean_squared_error: 1189.1224 - val_loss: 1564.8474 - val_mean_absolute_error: 24.0440 - val_mean_squared_error: 1564.8475
# Epoch 88/100
# 303/303 [==============================] - 188s 620ms/step - loss: 1224.5035 - mean_absolute_error: 24.8088 - mean_squared_error: 1224.5037 - val_loss: 1730.1667 - val_mean_absolute_error: 25.7700 - val_mean_squared_error: 1730.1667
# Epoch 89/100
# 303/303 [==============================] - 187s 617ms/step - loss: 1276.2623 - mean_absolute_error: 24.8137 - mean_squared_error: 1276.2623 - val_loss: 1927.5969 - val_mean_absolute_error: 29.7088 - val_mean_squared_error: 1927.5969
# Epoch 90/100
# 303/303 [==============================] - 189s 624ms/step - loss: 1139.4116 - mean_absolute_error: 23.9802 - mean_squared_error: 1139.4117 - val_loss: 2080.1194 - val_mean_absolute_error: 30.6822 - val_mean_squared_error: 2080.1194
# Epoch 91/100
# 303/303 [==============================] - 189s 622ms/step - loss: 958.2244 - mean_absolute_error: 22.1991 - mean_squared_error: 958.2244 - val_loss: 2561.0469 - val_mean_absolute_error: 33.9878 - val_mean_squared_error: 2561.0469
# Epoch 92/100
# 303/303 [==============================] - 189s 622ms/step - loss: 992.1786 - mean_absolute_error: 22.4087 - mean_squared_error: 992.1787 - val_loss: 1501.2805 - val_mean_absolute_error: 25.0032 - val_mean_squared_error: 1501.2805
# Epoch 93/100
#  62/303 [=====>........................] - ETA: 2:19 - loss: 1054.4874 - mean_absolute_error: 22.5632 - mean_squared_error: 1054.4874

# %% [markdown]
# ## Saving the network and the loss history for future use

# %%
hist_df = pd.DataFrame(CNN_history.history)  ## converting to dataframe for future usels
## Saving the history and the model
if NETWORK == "TL":
    if REG == True and CLA == True:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC'+'_history.csv')
    elif REG == True and CLA == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR'+'_history.csv')    
    elif CLA == True and REG == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC')        
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC'+'_history.csv')
    
else:    

    if REG == True and CLA == True:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelRC'+'_history.csv')
    elif REG == True and CLA == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelR')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelR'+'_history.csv')    
    elif CLA == True and REG == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelC'+'_history.csv')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/subhrat/DPNNet_RT/saved_model/TL_ResNet50_128_modelR/assets
# INFO:tensorflow:Assets written to: /Users/subhrat/DPNNet_RT/saved_model/TL_ResNet50_128_modelR/assets

# %% [markdown]
# # Loading the model

# %%
if NETWORK == "TL":
    if REG == True and CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC')
    elif REG == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR')
    elif CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC')
        
    print("INFO:The Trained model {} at res {} is loaded ".format(NETWORK+'_'+str( transfer_model.__name__),str(X_res)))
else:
    if REG == True and CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
    elif REG == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelR')
    elif CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelC')
# Out:
# INFO:The Trained model TL_ResNet50 at res 128 is loaded

# %% [markdown]
# ### Model Predictions and Results for the regression and Classification

# %%
test_index = 41 # 550  #550 ##210
if X_res >= Cutoff_resolution:

    test_generator.reset()
    pred_CNN=CNN.predict_generator(test_generator,
    steps=STEP_SIZE_TEST,
    verbose=1)
else:
    
    pred_CNN = CNN.predict(testImagesX)  
pred_CNN[test_index]
# Out:
# /var/folders/hc/r7dfp_9n1kz9cl4mvp0p617r0000gn/T/ipykernel_7552/384813347.py:5: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   pred_CNN=CNN.predict_generator(test_generator,
# 63/63 [==============================] - 15s 240ms/step
# array([ 3.0753983e+02, -2.9650134e-01,  5.8568840e+00], dtype=float32)

# %%
test_index = 1000 # 550  #550 ##210#
# plt.imshow(testImagesX[test_iclass_mode])
if REG == True:
    print("The predicted Values are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test_labels.iloc[test_index]))
elif CLA == True:
    print("The predicted prbability of the presence of planets are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test['Planet_Count'].iloc[test_index]))
    print("The predicted Values are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test_labels.iloc[test_index]))
# Out:
# The predicted Values are [687.4285   37.63727 128.416  ] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2     60.000000
# Planet_Mass3     99.333333
# Name: 29827, dtype: float64

# %%
###fc_mean_squared_error fc_accuracy dense_3_mean_squared_error dense_3_accuracy
hist =pd.DataFrame(CNN_history.history)
hist['epoch'] = hist.index = hist.index
hist
if NETWORK == "TL":
    plot_name = NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)
else:
    plot_name = NETWORK+'_'+str(X_res)
if  CLA == True and REG== False:
    cla_acc = CNN_history.history['mean_absolute_error']
    val_cla_acc = CNN_history.history['val_mean_absolute_error']
    cla_loss =CNN_history.history['loss']
    val_cla_loss = CNN_history.history['val_loss']
    
    plt.figure(figsize=(8, 8))
    # plt.subplot(2, 2, 1)
    plt.plot(hist['epoch'], cla_acc, label='cla-Training mean_absolute_error')
    plt.plot(hist['epoch'], val_cla_acc, label='cla-Validation mean_absolute_error')
    
    plt.legend(loc='upper right')
    plt.xlabel("epochs")
    plt.ylabel("mean_absolute_error")
    plt.title('Classification Training and Validation mean_absolute_error')
    plt.savefig('figures/'+plot_name+'_c.png')
    plt.show()
    
if REG == True and CLA == False:
    ## For Regression
    reg_mse = CNN_history.history['mean_squared_error']
    val_reg_mse =CNN_history.history['val_mean_squared_error']
    reg_loss =CNN_history.history['loss']
    val_reg_loss = CNN_history.history['val_loss']
    
    plt.figure(figsize=(8, 8))
    # plt.subplot(2, 2, 1)
    # plt.ylim(0,50000)
    plt.plot(hist['epoch'], reg_mse, label='reg-Training MSE')
    plt.plot(hist['epoch'], val_reg_mse, label='reg-Validation MSE')
    plt.legend(loc='upper right')
    plt.title('Regression Training and Validation MSE')
    plt.xlabel("epochs")
    plt.ylabel("MSE")
    plt.show()
    plt.savefig('figures/'+plot_name+'_r.png')

if REG == True and CLA == True:
    ## For classification
    cla_acc = CNN_history.history['cla_accuracy']
    val_cla_acc = CNN_history.history['val_cla_accuracy']
    cla_loss =CNN_history.history['cla_loss']
    val_cla_loss = CNN_history.history['val_cla_loss']

    ## For Regression
    reg_mse = CNN_history.history['reg_mean_squared_error']
    val_reg_mse =CNN_history.history['val_reg_mean_squared_error']
    reg_loss =CNN_history.history['reg_loss']
    val_reg_loss = CNN_history.history['val_reg_loss']
    
    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(hist['epoch'], cla_acc, label='cla-Training Accuracy')
    plt.plot(hist['epoch'], val_cla_acc, label='cla-Validation Accuracy')
    plt.legend(loc='lower right')
    plt.xlabel("epochs")
    plt.ylabels("accuracy")
    plt.title('Classification Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(hist['epoch'], reg_mse, label='reg-Training MSE')
    plt.plot(hist['epoch'], val_reg_mse, label='reg-Validation MSE')
    plt.legend(loc='upper right')
    plt.xlabel("epochs")
    plt.ylabel("MSE")
    plt.title('Regression Training and Validation MSE')
    plt.savefig('figures/'+plot_name+'_cr.png')

# %%
tp = pd.DataFrame(
    {'Predictions': predictions,
     'Truth': truth
    })
tp
# Out:
#       Predictions  Truth
# 0        3.883348      4
# 1        3.919844      4
# 2        1.866138      2
# 3        1.149912      1
# 4        3.975621      4
# ...           ...    ...
# 3145     3.932772      4
# 3146     3.881231      4
# 3147     3.918737      4
# 3148     3.925975      4
# 3149     3.890346      4
#
# [3150 rows x 2 columns]

# %%
np.mean(tp['Truth']-tp['Predictions'])
# Out:
# 0.058163327622035195

# %%
tp1 = tp.loc[tp['Truth'] == 1]
tp1
# Out:
#       Predictions  Truth
# 3        1.149912      1
# 5        1.137314      1
# 7        1.056326      1
# 11       1.085444      1
# 22       0.933645      1
# ...           ...    ...
# 3132     1.047378      1
# 3135     1.172706      1
# 3138     1.130675      1
# 3142     1.136221      1
# 3144     1.122740      1
#
# [914 rows x 2 columns]

# %%
np.mean(tp1['Truth']-tp1['Predictions'])
# Out:
# -0.04183883674817743

# %%
tp2 = tp.loc[tp['Truth'] == 2]
tp2
# Out:
#       Predictions  Truth
# 2        1.866138      2
# 6        1.925165      2
# 28       1.991065      2
# 36       2.045863      2
# 44       1.790217      2
# ...           ...    ...
# 3102     1.950534      2
# 3105     2.073118      2
# 3111     2.142585      2
# 3121     2.182886      2
# 3130     1.344867      2
#
# [339 rows x 2 columns]

# %%
np.mean(tp2['Truth']-tp2['Predictions'])
# Out:
# -0.11207409189865652

# %%
tp3 = tp.loc[tp['Truth'] == 3]
tp3
# Out:
#       Predictions  Truth
# 15       2.833871      3
# 57       3.152247      3
# 69       3.429189      3
# 71       2.629112      3
# 76       3.065350      3
# ...           ...    ...
# 3019     2.898144      3
# 3020     3.271947      3
# 3027     2.790201      3
# 3061     2.901910      3
# 3127     3.183476      3
#
# [182 rows x 2 columns]

# %%
np.mean(tp3['Truth']-tp3['Predictions'])
# Out:
# 0.12749670495043744

# %%
tp4 = tp.loc[tp['Truth'] == 4]
tp4
# Out:
#       Predictions  Truth
# 0        3.883348      4
# 1        3.919844      4
# 4        3.975621      4
# 8        3.894954      4
# 9        3.983680      4
# ...           ...    ...
# 3145     3.932772      4
# 3146     3.881231      4
# 3147     3.918737      4
# 3148     3.925975      4
# 3149     3.890346      4
#
# [1715 rows x 2 columns]

# %%
np.mean(tp4['Truth']-tp4['Predictions'])
# Out:
# 0.13775154265300874

# %%
from tensorflow.keras.preprocessing import image
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

img_path = '/Users/subhrat/Downloads/unseen_data/' + 'hltau_vla.jpg' # hltau_vla.jpg HD163296.jpg IM_Lup_ALMA_NRAO.jpg 1.jpg 2.jpg image_1.png
img = image.load_img(img_path, target_size=(X_res, Y_res))
# top,left,bottom,right = 20,25,110,90
# img = img.crop((left, top, right, bottom))
plt.imshow(img)
plt.show()
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
img_preprocessed = preprocess_input(img_batch)
prediction = CNN.predict(img_preprocessed)/255
prediction
# Out:
# 1/1 [==============================] - 0s 137ms/step
# array([[345.23532, 157.09491, 143.28378]], dtype=float32)
