# %% [markdown]
# # DPNNet-RT -- 22 October 2022
#
# ##### This notebook develops a ML model that can Classify and Predict the number of hidden planets and the corresponding planet mass for each of the planets from the protoplanetary disk images directly.

# %%
#####    Please note this version of the code is compatible with Google colab  ####
##################################### Mount the drive if running from Colab ##########################################
# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# ### IDEA behind this notebook :
# #### Authors : Sayantan and Subhrat
# #### Created : 3 Feb 2022
# #### This notebook is adopted from the DPNNet-2.0
#
# - Update 1: 24 Feb 2022 to include multi-outputs
# - Update 2: 22 October 2022 to include the all the date from the 700 FARGO3D calculations
#
# This notebook is developed to train the Model with Radiative Transfer (RT) images:
# We want to perform the following set of tasks
#
# P.S. This is a modular notebook that does the following:
#
#  1. Import all the customized Modules from Modules_DPNNet
#  2. For data processing we use data_processing_RT.py script
#  3. A functional module to call the different networks independently. (deep_models.py, other_cnn.py)
#  4. On October 2022, we are updating this notebook. We can now access the complete data but shall choose randomly from the images
#  5. Still only considering the axysymmetric images

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import cv2
import os
import csv

## Modules to check the performance of the code
from time import process_time 


## Importing the necessary TesnorFLow modules modules
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# from tensorflow.python.compiler.mlcompute import mlcompute
# mlcompute.set_mlc_device(device_name='gpu')

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from sklearn.metrics import r2_score ## form calcualting the r2 score
from sklearn.utils import shuffle
from tensorflow import keras as k
from keras_preprocessing.image import ImageDataGenerator
import tensorflow as tf
import keras_tuner as kt

## Trasfer Learning Models

from tensorflow.keras.applications import EfficientNetB0, EfficientNetB1 
from tensorflow.keras.applications import EfficientNetB2, EfficientNetB3
from tensorflow.keras.applications import EfficientNetB4, EfficientNetB5 
from tensorflow.keras.applications import EfficientNetB6, EfficientNetB7
from tensorflow.keras.applications import ResNet50,ResNet50V2
import re

## Modules for hyperparameter tuning keras-tuner
# import keras_tuner as kt

## Checking the availbale number of GPUs
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:",gpu.name,"Type:",gpu.device_type)
print("TensorFlow version used ",tf.__version__)
# Out:
# Num GPUs Available:  1
# Name: /physical_device:GPU:0 Type: GPU
# TensorFlow version used  2.10.0

# %% [markdown]
# #### Folder management

# %%
############ Please provide the path to the code directory if using Colab ################

# Path_gdrive= '/content/drive/MyDrive/ISU_Regresion/DPNNet-RT/' ## Comment out this line if using local computer

## Importing the Modules from Modules_DPNNet
import sys
try: ## tries to find the modules in the local directory first
  current_directory = os.getcwd()
  path = current_directory + '/' # For local computer 
#   path = '' # For local computer  
  sys.path.append(path+'MODULES_DPNNeT')
  import data_processing_RT as dp
  import deep_models as dm
  import other_cnns as ocn

########### Folders to save the processed data, files and figures when using Local computer ##############
  output_folder_list = ['data_folder','figures','saved_model']
  for file in output_folder_list:
    try:
        os.makedirs(file)
    except OSError:
        print ("Creation of the directory %s failed/ not needed as it already exit" % file)
    else:
        print ("Successfully created the directory %s" % file)
  
except ModuleNotFoundError:
  
  # #For Colab use:
  # #Point to the path containing the modules in the above section
  #(data folder are a directory above the directory containing the notebook)
  try:
    path = Path_gdrive
    print(path)
    sys.path.append(path+'MODULES_DPNNeT')
    import data_processing_RT as dp
    import deep_models as dm
    import other_cnns as ocn

    ########### Folders to save the processed data, files and figures when using GDRIVE ##############
    import os
    os.chdir(path)
    print("Creating the folders")
    # !mkdir -p data_folder
    # !mkdir -p figures ## to save the figures
    # !mkdir -p figures_paper
    # !mkdir -p saved_model
  except ModuleNotFoundError:
    print("The path to the modules is incorrect-- Provide current path")

print("[INFO] Modules imported")
# Out:
# We are currently using the Modules_DPCNet-RT
# Creation of the directory data_folder failed/ not needed as it already exit
# Creation of the directory figures failed/ not needed as it already exit
# Creation of the directory saved_model failed/ not needed as it already exit
# [INFO] Modules imported

# %% [markdown]
# ### Creating a csv with simulations params and path to each RT images

# %%
## Taking a look at the paramter file 
parameter_df = dp.load_parameter_csv(path)
parameter_df
# Out:
#      Planet_Mass1  Planet_Mass2  Planet_Mass3  Epsilon  Alpha    Stokes  \
# 0        0.000322       0.00204      0.001210    0.050  0.001  1.570000
# 1        0.002280       0.00154      0.000963    0.025  0.010  1.570000
# 2        0.002450       0.00262      0.002460    0.025  0.010  1.570000
# 3        0.000917       0.00195      0.001050    0.010  0.001  1.570000
# 4        0.001770       0.00187      0.002210    0.025  0.050  1.570000
# ..            ...           ...           ...      ...    ...       ...
# 695      0.002110       0.00000      0.000000    0.025  0.005  0.000157
# 696      0.002530       0.00000      0.000000    0.025  0.010  0.000157
# 697      0.000577       0.00000      0.000000    0.025  0.001  0.000157
# 698      0.001940       0.00000      0.000000    0.025  0.050  0.000157
# 699      0.002790       0.00000      0.000000    0.050  0.005  0.000157
#
#      Aspect_Ratio  SigmaSlope  Flaring_Index    Rp1   Rp2   Rp3  a_grain_mic
# 0          0.0432         1.0          0.010  1.010  2.19  3.22       3000.0
# 1          0.0561         1.0          0.075  0.943  2.16  3.37       1000.0
# 2          0.0261         1.0          0.075  1.160  1.84  3.15      10000.0
# 3          0.0496         1.0          0.250  1.100  1.82  2.99      10000.0
# 4          0.0625         1.0          0.075  0.863  2.08  3.32       3000.0
# ..            ...         ...            ...    ...   ...   ...          ...
# 695        0.0454         1.0          0.010  1.100  1.94  3.29        100.0
# 696        0.0882         1.0          0.075  0.851  1.99  3.10        100.0
# 697        0.0732         1.0          0.250  1.130  2.00  3.35        100.0
# 698        0.0711         1.0          0.075  0.966  2.02  3.32        100.0
# 699        0.0646         1.0          0.250  1.010  1.87  3.25        100.0
#
# [700 rows x 13 columns]

# %% [markdown]
# # Model Selections and Hyperparameters
#
# - Select the resolution of the images. For res > Cutoff_resolution, generators are used as that allow the network to load images during training directly from the data folder. For lower resolution images, those are loaded directly to the RAM memory.
# - Select number of sims and the nums of images from each sim for training
# - Regression or Classification: For Classification one can tune the hyperparameter of the layer succeding the main network
# - Select either network directly, so use transfer learning for the more advanced RESNET type networks
# - Select the batch sizes, epochs and initial learning rate. Note for hyper parameter tuning the default epoch is set to 10.

# %%
#### Desired Image resoltuion  and Batch Size #####
X_res = Y_res =64

## For random sampling from the images
num_sims = 700 
axisymmetric = True
num_ims_per_sim = 30  ## Choose the number of images from each FARGO3D sims

## Select the kind of Traning ## Both can be selected as well
REG =False#True  ## When choosing regression
CLA =True #False #False #True  ## When Choosing Clasiffication

hyperparam_tune = True ## Only used when classification is true 

Cutoff_resolution = 64

## Select the Network type

# NETWORK = "Vanilla" ## Cannot be uses at the moment
# NETWORK = "ALEXNET"
# NETWORK = "VGG"
# NETWORK = "RESNET50"

                                ########## When using Trasnfer Learning ######################
NETWORK = "TL"
transfer_model= ResNet50
# transfer_model=EfficientNetB3

## Hyper-Parameter to define
batch_size = 50 ## 20 was for regression ## the best was for 200 last run
valid_batch_size = 100
epochs=100 ## best was 100
init_lr = 1e-5 # 1e-5 (works for regression)

# early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)
early_stop = keras.callbacks.EarlyStopping(monitor='mean_absolute_error', min_delta=1e-5,
                                           patience=20, verbose=1, mode='min',restore_best_weights=True)

# %% [markdown]
# #### Address to the data folder
# Genrating the .csv file with the image address to load them later

# %%
############# Address to the data folder ###################

# ## updating the image paths once the transfer is done
try:     
    list_RT_path = glob.glob(path+ 'image_directory_complete/'+ 'RT_A*') ## make a list of all the RT folder where each folder is for each sim
    # ## For google colab this needs to be updated
    list_sorted_RT_path  = sorted(list_RT_path, key=lambda f: [int(n) for n in re.findall(r"\d+", f)][-1]) ## sorting the images
    data_complete = dp.create_complete_data_csv(list_sorted_RT_path,path)
except ValueError:
    print("Looking for images in the folder above-- Please give the correct path to the images if images are not loaded")
    list_RT_path = glob.glob(path+ '../image_directory_complete/'+ 'RT_A*') ## make a list of all the RT folder where each folder is for each sim
    # ## For google colab this needs to be updated
    list_sorted_RT_path  = sorted(list_RT_path, key=lambda f: [int(n) for n in re.findall(r"\d+", f)][-1]) ## sorting the images
    data_complete = dp.create_complete_data_csv(list_sorted_RT_path,path)
    
    
# data_complete
## Removing the nan if any
data_complete.isna().sum()  # summing the number of na
data_complete= data_complete.dropna()
data_complete

# data_complete['Planet_Count'] = (data_complete.loc[:, ['Planet_Mass1', 'Planet_Mass2', 'Planet_Mass3']] != 0).sum(axis=1)
data_complete = shuffle(data_complete,random_state=42)
dc_list = []

for  i in range(1, num_sims+1):
  if axisymmetric == True:
    dc_list.append(data_complete.loc[data_complete['image_path'].str.contains('RT_A_' + str(i))][:num_ims_per_sim])
  else:
    dc_list.append(data_complete.loc[data_complete['image_path'].str.contains('RT_NA_' + str(i))][:num_ims_per_sim])

data_complete = pd.concat(dc_list)
data_complete = shuffle(data_complete,random_state=49)

def f(row):
    if (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] == 0) and (row['Planet_Mass3'] == 0):
        val = 1
    elif (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] == 0) and (row['Planet_Mass3'] != 0):
        val = 2
    elif (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] != 0) and (row['Planet_Mass3'] == 0):
        val = 3
    elif (row['Planet_Mass1'] != 0) and (row['Planet_Mass2'] != 0) and (row['Planet_Mass3'] != 0):
        val = 4
    return val

data_complete['Planet_Count'] = data_complete.apply(f, axis=1)
data_complete
# Out:
# [INFO]: Importing path for all the RT images
# [INFO]: Contatination of the paths of all the RT images are now complete
#        Planet_Mass1  Planet_Mass2  Planet_Mass3  Epsilon   Alpha    Stokes  \
# 70957    164.000000      0.000000    182.333333    0.050  0.0500  0.001570
# 74841    107.333333     60.000000    240.000000    0.025  0.0100  0.001570
# 66658    390.000000    261.000000    793.333333    0.050  0.0100  0.001570
# 63900    305.666667    483.333333    930.000000    0.010  0.0010  0.001570
# 76580    503.333333      0.000000      0.000000    0.010  0.0001  0.001570
# ...             ...           ...           ...      ...     ...       ...
# 40212    420.000000      0.000000      0.000000    0.025  0.0010  0.015700
# 39626    900.000000      0.000000      0.000000    0.025  0.0050  0.015700
# 98225    446.666667    333.333333    240.000000    0.025  0.0050  0.000157
# 79263     50.666667      0.000000      0.000000    0.010  0.0050  0.001570
# 23747     79.000000     65.666667    543.333333    0.025  0.0050  0.015700
#
#        Aspect_Ratio  SigmaSlope  Flaring_Index    Rp1   Rp2   Rp3  \
# 70957        0.0346         1.0          0.010  1.080  1.92  3.25
# 74841        0.0646         1.0          0.075  0.954  2.02  3.49
# 66658        0.0604         1.0          0.250  0.863  2.02  3.49
# 63900        0.0625         1.0          0.010  1.060  2.01  3.23
# 76580        0.0475         1.0          0.075  1.150  2.01  3.47
# ...             ...         ...            ...    ...   ...   ...
# 40212        0.0968         1.0          0.075  1.190  2.02  3.32
# 39626        0.0496         1.0          0.250  1.150  2.08  3.37
# 98225        0.0411         1.0          0.010  0.851  1.89  3.27
# 79263        0.0411         1.0          0.010  1.190  1.97  3.22
# 23747        0.0861         1.0          0.075  0.977  1.83  3.03
#
#        a_grain_mic                                         image_path  \
# 70957        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 74841        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 66658        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 63900        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 76580        300.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# ...            ...                                                ...
# 40212       3000.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 39626       1000.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 98225        100.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 79263        100.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
# 23747       3000.0  /Users/subhrat/DPNNet_RT/image_directory_compl...
#
#        Planet_Count
# 70957             2
# 74841             4
# 66658             4
# 63900             4
# 76580             1
# ...             ...
# 40212             1
# 39626             1
# 98225             4
# 79263             1
# 23747             4
#
# [21000 rows x 15 columns]

# %% [markdown]
# ### Preparing data

# %%
## partition the data csv file into training and testing splits using 85% of
## the data for training and the remaining 15% for testing
split = train_test_split(data_complete, test_size=0.15, random_state=42)
(train, test) = split

## Save the train and the test data for future use as well.
test.to_csv(path+'data_folder/test_dataset.csv')
train.to_csv(path+'data_folder/train_dataset.csv')

## Generate the Normalized data
normed_train_data, normed_test_data, train_labels, test_labels = dp.process_the_disk_attributes(train, test, path,multi_label=True)
# Out:
# [INFO] preparing the normalized data training/testing split...
# Droping the irrelevant columns
# INFO: considering multiple planets as output
# [INFO] Done...

# %% [markdown]
# ### Loading the images or Creating the train, validation and test generators

# %%
import time
start = time.time()

if CLA == True:

        y_col = ['Planet_Count']

elif REG == True:
        y_col=["Planet_Mass1",'Planet_Mass2','Planet_Mass3']

        
        ###### Generate the training and the test images######
if X_res >= Cutoff_resolution:
    
    def custom_augmentation(np_tensor):

        '''
        This function is used to crop the images when those are loaded using the 
        ImageDataGenerator Keras function. This custom augmentation function only
        works for three different res as given below. For other resolutions the 
        image needs to the cropped appropiately.

        '''

        # # # dimensions for cropping the image
        if X_res == 64:
          top,left,bottom,right = 8,11,55,48
        if X_res == 128:
          top,left,bottom,right = 20,25,110,90 
        if X_res == 256:          
          top,left,bottom,right = 40,50,220,180          
        if X_res == 512:
          top,left,bottom,right = 60,90,450,380          
                
        image = np.squeeze(np_tensor) 
        crop_image = image[top:bottom, left:right]
        crop_image = cv2.resize(crop_image, (X_res, Y_res)) 
        crop_image = k.preprocessing.image.img_to_array(crop_image)
        return crop_image

#     datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,samplewise_center=True, samplewise_std_normalization=True,rescale=1./255.,validation_split=0.15)
#     datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,featurewise_center=True,featurewise_std_normalization=True,rescale=1./255.,validation_split=0.15)
    if transfer_model == ResNet50:
        datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,rescale=1./255.,validation_split=0.15)
    else:
        datagen= ImageDataGenerator(preprocessing_function=custom_augmentation,validation_split=0.15)

    #### TRAINING GENERATOR #####
    train_generator=datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="image_path",
    y_col=y_col,
    subset="training",
    batch_size=batch_size,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(X_res,Y_res))

    #### VALIDATION GENERATOR #####
    validation_generator=datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="image_path",
    y_col=y_col,
    subset="validation",
    batch_size=batch_size,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(X_res,Y_res))

    #### TESTING GENERATOR #####
    test_datagen= k.preprocessing.image.ImageDataGenerator(preprocessing_function=custom_augmentation,rescale=1./255.)
    test_generator=test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=None,
    x_col="image_path",
    y_col=y_col,
    batch_size=batch_size,
    seed=42,
    shuffle=False,
    class_mode=None,
    target_size=(X_res,Y_res))
    
    
    ## STEP SIZES later used for training using generators
    STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
    STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
    STEP_SIZE_TEST=test_generator.n//test_generator.batch_size

 

else:
    print("Uploading directly to RAM as the image resoltuion is manageable")
    trainImagesX = dp.load_disk_images(train, X_res, Y_res, Type = "Train")
    testImagesX = dp.load_disk_images(test, X_res, Y_res, Type = "Test")

Validation_split = 0.15 # 15 percent of the training data is used for validation
print('There are {} Train, {} Validation and {} Test images'.format(int((1-Validation_split)*len(normed_train_data)),int(Validation_split*len(normed_train_data)),len(normed_test_data)))## check the numbers in each category
end = time.time()
print("Total time elapsed =", end - start)

# # Getting all memory using os.popen()
# total_memory, used_memory, free_memory = map(
#     int, os.popen('free -t -m').readlines()[-1].split()[1:])
 
# # Memory usage
# print("RAM memory % used:", round((used_memory/total_memory) * 100, 2))
# Out:
# Found 15173 validated image filenames.
# Found 2677 validated image filenames.
# Found 3150 validated image filenames.
# There are 15172 Train, 2677 Validation and 3150 Test images
# Total time elapsed = 0.7804079055786133

# %% [markdown]
# ### Checking image with cropping for verification

# %%
if X_res>= Cutoff_resolution:
    for _ in range(5):
        img, label = train_generator.next()
        print(img.shape)   #  (1,256,256,3)
        plt.imshow(img[0])
        plt.show()
else:
    plt.imshow(trainImagesX[5])
    plt.show()

# filenames =train_generator.filenames
# filenames[1]
# Out:
# (50, 64, 64, 3)
# (50, 64, 64, 3)
# (50, 64, 64, 3)
# (50, 64, 64, 3)
# (50, 64, 64, 3)

# %% [markdown]
# ## Preparing the Model Network

# %%
print('INFO: Currently training using the {} NETWORK with regression = {} and classification = {}'.format(NETWORK,REG,CLA))
if NETWORK == "Vanilla":
    CNN = dm.build_cnn(X_res, Y_res, 3, regress=True)
elif NETWORK == "ALEXNET":
    CNN = alexnet(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "VGG":
    CNN = cnn_vgg(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "RESNET50":
    # CNN = Resnet50(X_res, Y_res, 3,classes=2,regress = REG,multi_label=True,classification=CLA,option=None)
    CNN = ocn.Resnet50(X_res, Y_res, 3,classes=3,regress = REG,multi_label=True,classification=CLA,option=None)
elif NETWORK == "TL":      
    if hyperparam_tune == True and CLA ==True: 
        print("hyperparameters are only tuned for classification -- For regression hyperparams are standard and not tuned")
        hypermodel = ocn.TRANSFERLEARNINGHYPERMODEL(X_res, Y_res, 3,classes=1,regress = REG,multi_label=True,classification=CLA,option=None,transfer_model=transfer_model,
                                                   init_lr=init_lr,epochs=epochs)
        tuner_c=kt.RandomSearch(hypermodel,
            objective=kt.Objective('val_mean_absolute_error', direction="min"),
            max_trials=3,
            executions_per_trial=2,
            directory='tuner_c',
            project_name='ppd_c')
        tuner_c.search(train_generator,
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data=validation_generator,
                                validation_steps=STEP_SIZE_VALID,
                                epochs=10)
        CNN = tuner_c.get_best_models(num_models=1)[0]
    else : 
        
         CNN = ocn.TRANSFERLEARNING(X_res, Y_res, 3,classes=3,regress = REG,multi_label=True,classification=CLA,option=None,transfer_model=transfer_model)
 
         optimizer = tf.keras.optimizers.Adam(init_lr, decay=init_lr/epochs)
# Out:
# Trial 3 Complete [00h 30m 13s]
# val_mean_absolute_error: 1.0047204494476318
#
# Best val_mean_absolute_error So Far: 1.0047204494476318
# Total elapsed time: 01h 33m 20s
# INFO:tensorflow:Oracle triggered exit
# IF the notebook is connected to internet then the weights can be directly downloaded-- Choose accordingly
# INFO:CNN is used for Classification and hyperparameters are being tuned
# INFO: Classification Model is being trained

# %% [markdown]
# ## Training

# %%
if REG == True and CLA ==False:
    
    CNN.compile(loss='mean_squared_error',
                    optimizer=optimizer,
                    metrics=['mean_absolute_error', 'mean_squared_error'])
    
    if X_res >= Cutoff_resolution:
        print("INFO: Switching to Generator as Resosultion is greater than {}: REGRESSION using GENERATORS".format(X_res))         
        CNN_history = CNN.fit(train_generator,
                            steps_per_epoch=STEP_SIZE_TRAIN,
                            validation_data=validation_generator,
                            validation_steps=STEP_SIZE_VALID,
                            epochs=epochs,callbacks=[early_stop])
    else:

        CNN_history = CNN.fit(x=trainImagesX, y=train_labels,
                          validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])

if REG == False and CLA ==True:
    
    optimizer = tf.keras.optimizers.Adam(init_lr, decay=init_lr/epochs)
    CNN.compile(loss='mean_squared_error',optimizer=optimizer,metrics=['mean_absolute_error'])
    
    if X_res >= Cutoff_resolution:          
        print("INFO: Switching to Generator as Resosultion is greater than {}: CLASSIFICATION using GENERATORS".format(X_res))  
        CNN_history = CNN.fit(train_generator,
                            steps_per_epoch=STEP_SIZE_TRAIN,
                            validation_data=validation_generator,
                            validation_steps=STEP_SIZE_VALID,
                            epochs=epochs,callbacks=[early_stop])
    else: 
        
        CNN_history = CNN.fit(x=trainImagesX, y=Y_train,
                      validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])

if REG == True and CLA ==True:
    
    # When used for classification and regression
    CNN.compile(loss=['mean_squared_error','binary_crossentropy'],optimizer=optimizer,metrics=['mean_squared_error', 'accuracy'])

    CNN_history = CNN.fit(x=X_train, y=[train_labels,Y_train],
                      validation_split = 0.15,epochs=epochs, batch_size=batch_size,callbacks=[early_stop])
    
# total_memory, used_memory, free_memory = map(
# int, os.popen('free -t -m').readlines()[-1].split()[1:])

# # Memory usage
# print("RAM memory % used:", round((used_memory/total_memory) * 100, 2))
# Out:
# INFO: Switching to Generator as Resosultion is greater than 64: CLASSIFICATION using GENERATORS
# Epoch 1/100
# 2022-12-17 19:57:51.803999: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 303/303 [==============================] - ETA: 0s - loss: 2.0712 - mean_absolute_error: 1.1290
# 2022-12-17 19:59:20.971475: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 303/303 [==============================] - 105s 321ms/step - loss: 2.0712 - mean_absolute_error: 1.1290 - val_loss: 1.1945 - val_mean_absolute_error: 0.8156
# Epoch 2/100
# 303/303 [==============================] - 88s 290ms/step - loss: 1.6930 - mean_absolute_error: 1.0101 - val_loss: 0.8650 - val_mean_absolute_error: 0.7053
# Epoch 3/100
# 303/303 [==============================] - 88s 289ms/step - loss: 1.4845 - mean_absolute_error: 0.9427 - val_loss: 0.8164 - val_mean_absolute_error: 0.6764
# Epoch 4/100
# 303/303 [==============================] - 88s 291ms/step - loss: 1.3154 - mean_absolute_error: 0.8823 - val_loss: 0.7403 - val_mean_absolute_error: 0.6523
# Epoch 5/100
# 303/303 [==============================] - 91s 299ms/step - loss: 1.1898 - mean_absolute_error: 0.8402 - val_loss: 0.6649 - val_mean_absolute_error: 0.6302
# Epoch 6/100
# 303/303 [==============================] - 89s 293ms/step - loss: 1.0982 - mean_absolute_error: 0.7990 - val_loss: 0.7320 - val_mean_absolute_error: 0.6084
# Epoch 7/100
# 303/303 [==============================] - 88s 288ms/step - loss: 1.0489 - mean_absolute_error: 0.7828 - val_loss: 0.6169 - val_mean_absolute_error: 0.5918
# Epoch 8/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.9622 - mean_absolute_error: 0.7439 - val_loss: 0.8089 - val_mean_absolute_error: 0.6328
# Epoch 9/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.9500 - mean_absolute_error: 0.7328 - val_loss: 0.5656 - val_mean_absolute_error: 0.5485
# Epoch 10/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.8920 - mean_absolute_error: 0.7084 - val_loss: 0.5761 - val_mean_absolute_error: 0.5331
# Epoch 11/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.8083 - mean_absolute_error: 0.6759 - val_loss: 0.4962 - val_mean_absolute_error: 0.5150
# Epoch 12/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.7834 - mean_absolute_error: 0.6568 - val_loss: 0.5358 - val_mean_absolute_error: 0.5443
# Epoch 13/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.7355 - mean_absolute_error: 0.6356 - val_loss: 0.5222 - val_mean_absolute_error: 0.5315
# Epoch 14/100
# 303/303 [==============================] - 88s 289ms/step - loss: 0.6931 - mean_absolute_error: 0.6143 - val_loss: 0.6727 - val_mean_absolute_error: 0.5508
# Epoch 15/100
# 303/303 [==============================] - 88s 291ms/step - loss: 0.6888 - mean_absolute_error: 0.6048 - val_loss: 0.4858 - val_mean_absolute_error: 0.5003
# Epoch 16/100
# 303/303 [==============================] - 88s 291ms/step - loss: 0.6412 - mean_absolute_error: 0.5839 - val_loss: 0.4854 - val_mean_absolute_error: 0.4932
# Epoch 17/100
# 303/303 [==============================] - 87s 288ms/step - loss: 0.6017 - mean_absolute_error: 0.5635 - val_loss: 0.4058 - val_mean_absolute_error: 0.4445
# Epoch 18/100
# 303/303 [==============================] - 88s 289ms/step - loss: 0.5880 - mean_absolute_error: 0.5626 - val_loss: 0.4146 - val_mean_absolute_error: 0.4573
# Epoch 19/100
# 303/303 [==============================] - 89s 292ms/step - loss: 0.5508 - mean_absolute_error: 0.5434 - val_loss: 0.4675 - val_mean_absolute_error: 0.4832
# Epoch 20/100
# 303/303 [==============================] - 89s 292ms/step - loss: 0.5350 - mean_absolute_error: 0.5291 - val_loss: 0.3804 - val_mean_absolute_error: 0.4401
# Epoch 21/100
# 303/303 [==============================] - 89s 293ms/step - loss: 0.4677 - mean_absolute_error: 0.4956 - val_loss: 0.3688 - val_mean_absolute_error: 0.4114
# Epoch 22/100
# 303/303 [==============================] - 90s 295ms/step - loss: 0.4838 - mean_absolute_error: 0.5022 - val_loss: 0.3665 - val_mean_absolute_error: 0.4311
# Epoch 23/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.4407 - mean_absolute_error: 0.4754 - val_loss: 0.3708 - val_mean_absolute_error: 0.4278
# Epoch 24/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.4338 - mean_absolute_error: 0.4674 - val_loss: 0.3475 - val_mean_absolute_error: 0.4038
# Epoch 25/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.4263 - mean_absolute_error: 0.4642 - val_loss: 0.3785 - val_mean_absolute_error: 0.4332
# Epoch 26/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.4109 - mean_absolute_error: 0.4562 - val_loss: 0.4143 - val_mean_absolute_error: 0.4485
# Epoch 27/100
# 303/303 [==============================] - 94s 311ms/step - loss: 0.3716 - mean_absolute_error: 0.4308 - val_loss: 0.3611 - val_mean_absolute_error: 0.4054
# Epoch 28/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.3558 - mean_absolute_error: 0.4138 - val_loss: 0.3214 - val_mean_absolute_error: 0.3937
# Epoch 29/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.3524 - mean_absolute_error: 0.4141 - val_loss: 0.3058 - val_mean_absolute_error: 0.3753
# Epoch 30/100
# 303/303 [==============================] - 89s 293ms/step - loss: 0.3412 - mean_absolute_error: 0.4032 - val_loss: 0.3403 - val_mean_absolute_error: 0.3935
# Epoch 31/100
# 303/303 [==============================] - 88s 290ms/step - loss: 0.3352 - mean_absolute_error: 0.3972 - val_loss: 0.4205 - val_mean_absolute_error: 0.4347
# Epoch 32/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.3132 - mean_absolute_error: 0.3854 - val_loss: 0.2976 - val_mean_absolute_error: 0.3643
# Epoch 33/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.3049 - mean_absolute_error: 0.3776 - val_loss: 0.3345 - val_mean_absolute_error: 0.3696
# Epoch 34/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.3058 - mean_absolute_error: 0.3776 - val_loss: 0.3323 - val_mean_absolute_error: 0.3917
# Epoch 35/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.2839 - mean_absolute_error: 0.3610 - val_loss: 0.2672 - val_mean_absolute_error: 0.3321
# Epoch 36/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.2781 - mean_absolute_error: 0.3569 - val_loss: 0.3141 - val_mean_absolute_error: 0.3568
# Epoch 37/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.2726 - mean_absolute_error: 0.3510 - val_loss: 0.3618 - val_mean_absolute_error: 0.3740
# Epoch 38/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.2630 - mean_absolute_error: 0.3439 - val_loss: 0.3132 - val_mean_absolute_error: 0.3767
# Epoch 39/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.2598 - mean_absolute_error: 0.3406 - val_loss: 0.2870 - val_mean_absolute_error: 0.3458
# Epoch 40/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.2405 - mean_absolute_error: 0.3269 - val_loss: 0.2641 - val_mean_absolute_error: 0.3165
# Epoch 41/100
# 303/303 [==============================] - 86s 282ms/step - loss: 0.2357 - mean_absolute_error: 0.3214 - val_loss: 0.3564 - val_mean_absolute_error: 0.3724
# Epoch 42/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.2304 - mean_absolute_error: 0.3193 - val_loss: 0.2838 - val_mean_absolute_error: 0.3245
# Epoch 43/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.2227 - mean_absolute_error: 0.3146 - val_loss: 0.2837 - val_mean_absolute_error: 0.3259
# Epoch 44/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.2278 - mean_absolute_error: 0.3186 - val_loss: 0.3029 - val_mean_absolute_error: 0.3277
# Epoch 45/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.2133 - mean_absolute_error: 0.3083 - val_loss: 0.2456 - val_mean_absolute_error: 0.2904
# Epoch 46/100
# 303/303 [==============================] - 86s 282ms/step - loss: 0.1980 - mean_absolute_error: 0.2935 - val_loss: 0.2909 - val_mean_absolute_error: 0.3283
# Epoch 47/100
# 303/303 [==============================] - 85s 281ms/step - loss: 0.2001 - mean_absolute_error: 0.2958 - val_loss: 0.2843 - val_mean_absolute_error: 0.3264
# Epoch 48/100
# 303/303 [==============================] - 85s 281ms/step - loss: 0.1930 - mean_absolute_error: 0.2864 - val_loss: 0.3737 - val_mean_absolute_error: 0.3593
# Epoch 49/100
# 303/303 [==============================] - 86s 282ms/step - loss: 0.1842 - mean_absolute_error: 0.2779 - val_loss: 0.2492 - val_mean_absolute_error: 0.2848
# Epoch 50/100
# 303/303 [==============================] - 85s 281ms/step - loss: 0.1924 - mean_absolute_error: 0.2879 - val_loss: 0.3351 - val_mean_absolute_error: 0.3451
# Epoch 51/100
# 303/303 [==============================] - 85s 280ms/step - loss: 0.1919 - mean_absolute_error: 0.2878 - val_loss: 0.3434 - val_mean_absolute_error: 0.3423
# Epoch 52/100
# 303/303 [==============================] - 85s 281ms/step - loss: 0.1710 - mean_absolute_error: 0.2706 - val_loss: 0.2769 - val_mean_absolute_error: 0.3177
# Epoch 53/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.1703 - mean_absolute_error: 0.2687 - val_loss: 0.2739 - val_mean_absolute_error: 0.3021
# Epoch 54/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.1796 - mean_absolute_error: 0.2720 - val_loss: 0.2476 - val_mean_absolute_error: 0.2765
# Epoch 55/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1779 - mean_absolute_error: 0.2691 - val_loss: 0.2967 - val_mean_absolute_error: 0.3281
# Epoch 56/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1784 - mean_absolute_error: 0.2702 - val_loss: 0.2730 - val_mean_absolute_error: 0.3026
# Epoch 57/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1589 - mean_absolute_error: 0.2587 - val_loss: 0.2276 - val_mean_absolute_error: 0.2709
# Epoch 58/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.1493 - mean_absolute_error: 0.2496 - val_loss: 0.2318 - val_mean_absolute_error: 0.2657
# Epoch 59/100
# 303/303 [==============================] - 88s 290ms/step - loss: 0.1558 - mean_absolute_error: 0.2553 - val_loss: 0.2292 - val_mean_absolute_error: 0.2590
# Epoch 60/100
# 303/303 [==============================] - 88s 290ms/step - loss: 0.1498 - mean_absolute_error: 0.2448 - val_loss: 0.5510 - val_mean_absolute_error: 0.4223
# Epoch 61/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.1457 - mean_absolute_error: 0.2439 - val_loss: 0.2404 - val_mean_absolute_error: 0.2913
# Epoch 62/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.1364 - mean_absolute_error: 0.2379 - val_loss: 0.2701 - val_mean_absolute_error: 0.2881
# Epoch 63/100
# 303/303 [==============================] - 86s 282ms/step - loss: 0.1468 - mean_absolute_error: 0.2431 - val_loss: 0.2520 - val_mean_absolute_error: 0.2705
# Epoch 64/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.1374 - mean_absolute_error: 0.2338 - val_loss: 0.2657 - val_mean_absolute_error: 0.2775
# Epoch 65/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1463 - mean_absolute_error: 0.2410 - val_loss: 0.2909 - val_mean_absolute_error: 0.2824
# Epoch 66/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.1393 - mean_absolute_error: 0.2320 - val_loss: 0.2243 - val_mean_absolute_error: 0.2530
# Epoch 67/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.1261 - mean_absolute_error: 0.2275 - val_loss: 0.2589 - val_mean_absolute_error: 0.2811
# Epoch 68/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.1170 - mean_absolute_error: 0.2180 - val_loss: 0.2592 - val_mean_absolute_error: 0.2750
# Epoch 69/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1315 - mean_absolute_error: 0.2281 - val_loss: 0.2690 - val_mean_absolute_error: 0.2699
# Epoch 70/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1441 - mean_absolute_error: 0.2375 - val_loss: 0.2597 - val_mean_absolute_error: 0.2688
# Epoch 71/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1147 - mean_absolute_error: 0.2182 - val_loss: 0.2541 - val_mean_absolute_error: 0.2709
# Epoch 72/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.1231 - mean_absolute_error: 0.2216 - val_loss: 0.2900 - val_mean_absolute_error: 0.2984
# Epoch 73/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1140 - mean_absolute_error: 0.2148 - val_loss: 0.2311 - val_mean_absolute_error: 0.2493
# Epoch 74/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1136 - mean_absolute_error: 0.2123 - val_loss: 0.2694 - val_mean_absolute_error: 0.2757
# Epoch 75/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.1076 - mean_absolute_error: 0.2080 - val_loss: 0.2774 - val_mean_absolute_error: 0.2839
# Epoch 76/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1140 - mean_absolute_error: 0.2106 - val_loss: 0.2363 - val_mean_absolute_error: 0.2548
# Epoch 77/100
# 303/303 [==============================] - 89s 294ms/step - loss: 0.1181 - mean_absolute_error: 0.2147 - val_loss: 0.2605 - val_mean_absolute_error: 0.2846
# Epoch 78/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.1090 - mean_absolute_error: 0.2100 - val_loss: 0.2378 - val_mean_absolute_error: 0.2701
# Epoch 79/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.0983 - mean_absolute_error: 0.2004 - val_loss: 0.2760 - val_mean_absolute_error: 0.2943
# Epoch 80/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.0958 - mean_absolute_error: 0.1950 - val_loss: 0.2717 - val_mean_absolute_error: 0.2692
# Epoch 81/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.0931 - mean_absolute_error: 0.1915 - val_loss: 0.2038 - val_mean_absolute_error: 0.2314
# Epoch 82/100
# 303/303 [==============================] - 86s 282ms/step - loss: 0.0989 - mean_absolute_error: 0.1984 - val_loss: 0.2607 - val_mean_absolute_error: 0.2666
# Epoch 83/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.0904 - mean_absolute_error: 0.1916 - val_loss: 0.2516 - val_mean_absolute_error: 0.2555
# Epoch 84/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.0973 - mean_absolute_error: 0.1941 - val_loss: 0.2331 - val_mean_absolute_error: 0.2280
# Epoch 85/100
# 303/303 [==============================] - 87s 285ms/step - loss: 0.1170 - mean_absolute_error: 0.2059 - val_loss: 0.4559 - val_mean_absolute_error: 0.3566
# Epoch 86/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.1294 - mean_absolute_error: 0.2180 - val_loss: 0.2382 - val_mean_absolute_error: 0.2547
# Epoch 87/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.1054 - mean_absolute_error: 0.1978 - val_loss: 0.2281 - val_mean_absolute_error: 0.2455
# Epoch 88/100
# 303/303 [==============================] - 88s 288ms/step - loss: 0.1173 - mean_absolute_error: 0.2090 - val_loss: 0.2303 - val_mean_absolute_error: 0.2467
# Epoch 89/100
# 303/303 [==============================] - 87s 288ms/step - loss: 0.0993 - mean_absolute_error: 0.1962 - val_loss: 0.2253 - val_mean_absolute_error: 0.2472
# Epoch 90/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.1045 - mean_absolute_error: 0.1956 - val_loss: 0.2558 - val_mean_absolute_error: 0.2673
# Epoch 91/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.0966 - mean_absolute_error: 0.1901 - val_loss: 0.3207 - val_mean_absolute_error: 0.2911
# Epoch 92/100
# 303/303 [==============================] - 86s 284ms/step - loss: 0.0882 - mean_absolute_error: 0.1861 - val_loss: 0.2443 - val_mean_absolute_error: 0.2454
# Epoch 93/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.0961 - mean_absolute_error: 0.1884 - val_loss: 0.2327 - val_mean_absolute_error: 0.2513
# Epoch 94/100
# 303/303 [==============================] - 86s 283ms/step - loss: 0.0990 - mean_absolute_error: 0.1891 - val_loss: 0.2990 - val_mean_absolute_error: 0.2786
# Epoch 95/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.1050 - mean_absolute_error: 0.1919 - val_loss: 0.3562 - val_mean_absolute_error: 0.3129
# Epoch 96/100
# 303/303 [==============================] - 85s 281ms/step - loss: 0.1062 - mean_absolute_error: 0.1947 - val_loss: 0.2405 - val_mean_absolute_error: 0.2401
# Epoch 97/100
# 303/303 [==============================] - 86s 285ms/step - loss: 0.1008 - mean_absolute_error: 0.1909 - val_loss: 0.2380 - val_mean_absolute_error: 0.2546
# Epoch 98/100
# 303/303 [==============================] - 91s 299ms/step - loss: 0.1098 - mean_absolute_error: 0.1936 - val_loss: 0.4395 - val_mean_absolute_error: 0.3613
# Epoch 99/100
# 303/303 [==============================] - 87s 287ms/step - loss: 0.1027 - mean_absolute_error: 0.1915 - val_loss: 0.2436 - val_mean_absolute_error: 0.2514
# Epoch 100/100
# 303/303 [==============================] - 87s 286ms/step - loss: 0.0832 - mean_absolute_error: 0.1774 - val_loss: 0.2300 - val_mean_absolute_error: 0.2417

# %% [markdown]
# ## Saving the network and the loss history for future use

# %%
hist_df = pd.DataFrame(CNN_history.history)  ## converting to dataframe for future usels
## Saving the history and the model
if NETWORK == "TL":
    if REG == True and CLA == True:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC'+'_history.csv')
    elif REG == True and CLA == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR'+'_history.csv')    
    elif CLA == True and REG == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC')        
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC'+'_history.csv')
    
else:    

    if REG == True and CLA == True:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelRC'+'_history.csv')
    elif REG == True and CLA == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelR')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelR'+'_history.csv')    
    elif CLA == True and REG == False:
        CNN.save(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelC')
        hist_df.to_csv(path+'data_folder/'+NETWORK+'_'+str(X_res)+'_modelC'+'_history.csv')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/subhrat/DPNNet_RT/saved_model/TL_ResNet50_64_modelC/assets
# INFO:tensorflow:Assets written to: /Users/subhrat/DPNNet_RT/saved_model/TL_ResNet50_64_modelC/assets

# %% [markdown]
# # Loading the model

# %%
if NETWORK == "TL":
    if REG == True and CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelRC')
    elif REG == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelR')
    elif CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)+'_modelC')
        
    print("INFO:The Trained model {} at res {} is loaded ".format(NETWORK+'_'+str( transfer_model.__name__),str(X_res)))
else:
    if REG == True and CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelRC')
    elif REG == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelR')
    elif CLA == True:
        CNN = tf.keras.models.load_model(path+'saved_model/'+NETWORK+'_'+str(X_res)+'_modelC')
# Out:
# INFO:The Trained model TL_ResNet50 at res 64 is loaded

# %% [markdown]
# ### Model Predictions and Results for the regression and Classification

# %%
test_index = 41 # 550  #550 ##210
if X_res >= Cutoff_resolution:

    test_generator.reset()
    pred_CNN=CNN.predict_generator(test_generator,
    steps=STEP_SIZE_TEST,
    verbose=1)
else:
    
    pred_CNN = CNN.predict(testImagesX)  
pred_CNN[test_index]
# Out:
# /var/folders/hc/r7dfp_9n1kz9cl4mvp0p617r0000gn/T/ipykernel_69674/384813347.py:5: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   pred_CNN=CNN.predict_generator(test_generator,
# 2022-12-17 22:27:59.759753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 63/63 [==============================] - 16s 239ms/step
# array([1.0905353], dtype=float32)

# %%
predictions = []
truth = []

for i in range(3151):
    test_index = i # 550  #550 ##210#
    predictions.append(pred_CNN[test_index].item())
    truth.append(test['Planet_Count'].iloc[test_index])
    # plt.imshow(testImagesX[test_iclass_mode])
    if REG == True:
        print("The predicted Values are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test_labels.iloc[test_index]))
    elif CLA == True:
        print("The predicted prbability of the presence of planets are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test['Planet_Count'].iloc[test_index]))
        print("The predicted Values are {} and \nThe True values are \n{} ".format(pred_CNN[test_index],test_labels.iloc[test_index]))
# Out:
# The predicted prbability of the presence of planets are [3.6455615] and
# The True values are
# 4
# The predicted Values are [3.6455615] and
# The True values are
# Planet_Mass1     135.666667
# Planet_Mass2     333.333333
# Planet_Mass3    1000.000000
# Name: 35627, dtype: float64
# The predicted prbability of the presence of planets are [3.6964028] and
# The True values are
# 4
# The predicted Values are [3.6964028] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2    706.666667
# Planet_Mass3    820.000000
# Name: 64252, dtype: float64
# The predicted prbability of the presence of planets are [1.7563874] and
# The True values are
# 2
# The predicted Values are [1.7563874] and
# The True values are
# Planet_Mass1    363.333333
# Planet_Mass2      0.000000
# Planet_Mass3     44.000000
# Name: 49188, dtype: float64
# The predicted prbability of the presence of planets are [1.5527197] and
# The True values are
# 1
# The predicted Values are [1.5527197] and
# The True values are
# Planet_Mass1    164.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 80862, dtype: float64
# The predicted prbability of the presence of planets are [3.9615986] and
# The True values are
# 4
# The predicted Values are [3.9615986] and
# The True values are
# Planet_Mass1    420.000000
# Planet_Mass2     60.000000
# Planet_Mass3    846.666667
# Name: 30811, dtype: float64
# The predicted prbability of the presence of planets are [1.1856117] and
# The True values are
# 1
# The predicted Values are [1.1856117] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 39392, dtype: float64
# The predicted prbability of the presence of planets are [1.9301354] and
# The True values are
# 2
# The predicted Values are [1.9301354] and
# The True values are
# Planet_Mass1    956.666667
# Planet_Mass2      0.000000
# Planet_Mass3    240.000000
# Name: 98831, dtype: float64
# The predicted prbability of the presence of planets are [1.1856805] and
# The True values are
# 1
# The predicted Values are [1.1856805] and
# The True values are
# Planet_Mass1    390.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 101699, dtype: float64
# The predicted prbability of the presence of planets are [3.881082] and
# The True values are
# 4
# The predicted Values are [3.881082] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 96919, dtype: float64
# The predicted prbability of the presence of planets are [4.274773] and
# The True values are
# 4
# The predicted Values are [4.274773] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2    623.333333
# Planet_Mass3    793.333333
# Name: 88076, dtype: float64
# The predicted prbability of the presence of planets are [3.9344683] and
# The True values are
# 4
# The predicted Values are [3.9344683] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2    121.666667
# Planet_Mass3     44.000000
# Name: 44571, dtype: float64
# The predicted prbability of the presence of planets are [1.2782167] and
# The True values are
# 1
# The predicted Values are [1.2782167] and
# The True values are
# Planet_Mass1    673.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 40616, dtype: float64
# The predicted prbability of the presence of planets are [3.8299196] and
# The True values are
# 4
# The predicted Values are [3.8299196] and
# The True values are
# Planet_Mass1    616.666667
# Planet_Mass2    333.333333
# Planet_Mass3    240.000000
# Name: 97371, dtype: float64
# The predicted prbability of the presence of planets are [3.7936845] and
# The True values are
# 4
# The predicted Values are [3.7936845] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2    790.000000
# Planet_Mass3    516.666667
# Name: 67404, dtype: float64
# The predicted prbability of the presence of planets are [4.036238] and
# The True values are
# 4
# The predicted Values are [4.036238] and
# The True values are
# Planet_Mass1    560.000000
# Planet_Mass2     60.000000
# Planet_Mass3    793.333333
# Name: 51089, dtype: float64
# The predicted prbability of the presence of planets are [3.7579343] and
# The True values are
# 3
# The predicted Values are [3.7579343] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 52526, dtype: float64
# The predicted prbability of the presence of planets are [3.9333298] and
# The True values are
# 4
# The predicted Values are [3.9333298] and
# The True values are
# Planet_Mass1    135.666667
# Planet_Mass2    373.333333
# Planet_Mass3    516.666667
# Name: 87115, dtype: float64
# The predicted prbability of the presence of planets are [3.9482691] and
# The True values are
# 4
# The predicted Values are [3.9482691] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2     60.000000
# Planet_Mass3    680.000000
# Name: 94327, dtype: float64
# The predicted prbability of the presence of planets are [3.2447798] and
# The True values are
# 4
# The predicted Values are [3.2447798] and
# The True values are
# Planet_Mass1    363.333333
# Planet_Mass2    233.000000
# Planet_Mass3    182.333333
# Name: 68138, dtype: float64
# The predicted prbability of the presence of planets are [3.8104265] and
# The True values are
# 4
# The predicted Values are [3.8104265] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2    596.666667
# Planet_Mass3    127.000000
# Name: 88991, dtype: float64
# The predicted prbability of the presence of planets are [3.9021327] and
# The True values are
# 4
# The predicted Values are [3.9021327] and
# The True values are
# Planet_Mass1    900.000000
# Planet_Mass2    333.333333
# Planet_Mass3    240.000000
# Name: 32515, dtype: float64
# The predicted prbability of the presence of planets are [3.8869772] and
# The True values are
# 4
# The predicted Values are [3.8869772] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 96967, dtype: float64
# The predicted prbability of the presence of planets are [1.2963616] and
# The True values are
# 1
# The predicted Values are [1.2963616] and
# The True values are
# Planet_Mass1    730.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 103671, dtype: float64
# The predicted prbability of the presence of planets are [1.0285691] and
# The True values are
# 1
# The predicted Values are [1.0285691] and
# The True values are
# Planet_Mass1    79.0
# Planet_Mass2     0.0
# Planet_Mass3     0.0
# Name: 83812, dtype: float64
# The predicted prbability of the presence of planets are [4.130822] and
# The True values are
# 4
# The predicted Values are [4.130822] and
# The True values are
# Planet_Mass1    900.000000
# Planet_Mass2    790.000000
# Planet_Mass3    596.666667
# Name: 23311, dtype: float64
# The predicted prbability of the presence of planets are [1.0538528] and
# The True values are
# 1
# The predicted Values are [1.0538528] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 82603, dtype: float64
# The predicted prbability of the presence of planets are [4.3250294] and
# The True values are
# 4
# The predicted Values are [4.3250294] and
# The True values are
# Planet_Mass1    930.000000
# Planet_Mass2    873.333333
# Planet_Mass3    460.000000
# Name: 43212, dtype: float64
# The predicted prbability of the presence of planets are [0.9827357] and
# The True values are
# 1
# The predicted Values are [0.9827357] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 41344, dtype: float64
# The predicted prbability of the presence of planets are [1.8692352] and
# The True values are
# 2
# The predicted Values are [1.8692352] and
# The True values are
# Planet_Mass1    590.000000
# Planet_Mass2      0.000000
# Planet_Mass3    793.333333
# Name: 93550, dtype: float64
# The predicted prbability of the presence of planets are [0.9731368] and
# The True values are
# 1
# The predicted Values are [0.9731368] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 102993, dtype: float64
# The predicted prbability of the presence of planets are [2.2411234] and
# The True values are
# 1
# The predicted Values are [2.2411234] and
# The True values are
# Planet_Mass1    503.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 82724, dtype: float64
# The predicted prbability of the presence of planets are [3.6779706] and
# The True values are
# 4
# The predicted Values are [3.6779706] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2    149.333333
# Planet_Mass3    596.666667
# Name: 86855, dtype: float64
# The predicted prbability of the presence of planets are [3.739357] and
# The True values are
# 4
# The predicted Values are [3.739357] and
# The True values are
# Planet_Mass1    760.000000
# Planet_Mass2    706.666667
# Planet_Mass3    960.000000
# Name: 45243, dtype: float64
# The predicted prbability of the presence of planets are [3.9533684] and
# The True values are
# 4
# The predicted Values are [3.9533684] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2    177.333333
# Planet_Mass3    293.333333
# Name: 23028, dtype: float64
# The predicted prbability of the presence of planets are [3.902292] and
# The True values are
# 4
# The predicted Values are [3.902292] and
# The True values are
# Planet_Mass1    390.000000
# Planet_Mass2    790.000000
# Planet_Mass3    182.333333
# Name: 85347, dtype: float64
# The predicted prbability of the presence of planets are [3.980846] and
# The True values are
# 4
# The predicted Values are [3.980846] and
# The True values are
# Planet_Mass1    560.000000
# Planet_Mass2     60.000000
# Planet_Mass3    793.333333
# Name: 28585, dtype: float64
# The predicted prbability of the presence of planets are [1.8581742] and
# The True values are
# 2
# The predicted Values are [1.8581742] and
# The True values are
# Planet_Mass1     843.333333
# Planet_Mass2       0.000000
# Planet_Mass3    1000.000000
# Name: 76480, dtype: float64
# The predicted prbability of the presence of planets are [1.0185587] and
# The True values are
# 1
# The predicted Values are [1.0185587] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 19264, dtype: float64
# The predicted prbability of the presence of planets are [1.3217137] and
# The True values are
# 1
# The predicted Values are [1.3217137] and
# The True values are
# Planet_Mass1    900.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 57794, dtype: float64
# The predicted prbability of the presence of planets are [3.7531683] and
# The True values are
# 4
# The predicted Values are [3.7531683] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2    333.333333
# Planet_Mass3    321.000000
# Name: 73105, dtype: float64
# The predicted prbability of the presence of planets are [1.499331] and
# The True values are
# 1
# The predicted Values are [1.499331] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 59339, dtype: float64
# The predicted prbability of the presence of planets are [1.0905353] and
# The True values are
# 1
# The predicted Values are [1.0905353] and
# The True values are
# Planet_Mass1    305.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 103270, dtype: float64
# The predicted prbability of the presence of planets are [1.01521] and
# The True values are
# 4
# The predicted Values are [1.01521] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2     60.000000
# Planet_Mass3     44.000000
# Name: 30097, dtype: float64
# The predicted prbability of the presence of planets are [3.964066] and
# The True values are
# 4
# The predicted Values are [3.964066] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2    333.333333
# Planet_Mass3    960.000000
# Name: 50121, dtype: float64
# The predicted prbability of the presence of planets are [1.9198575] and
# The True values are
# 2
# The predicted Values are [1.9198575] and
# The True values are
# Planet_Mass1     560.0
# Planet_Mass2       0.0
# Planet_Mass3    1000.0
# Name: 12750, dtype: float64
# The predicted prbability of the presence of planets are [3.9929008] and
# The True values are
# 4
# The predicted Values are [3.9929008] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2    790.000000
# Planet_Mass3    516.666667
# Name: 67385, dtype: float64
# The predicted prbability of the presence of planets are [3.9559166] and
# The True values are
# 4
# The predicted Values are [3.9559166] and
# The True values are
# Planet_Mass1     986.666667
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 95923, dtype: float64
# The predicted prbability of the presence of planets are [3.9601593] and
# The True values are
# 4
# The predicted Values are [3.9601593] and
# The True values are
# Planet_Mass1    560.000000
# Planet_Mass2    333.333333
# Planet_Mass3    293.333333
# Name: 9129, dtype: float64
# The predicted prbability of the presence of planets are [1.9242176] and
# The True values are
# 4
# The predicted Values are [1.9242176] and
# The True values are
# Planet_Mass1     730.0
# Planet_Mass2      60.0
# Planet_Mass3    1000.0
# Name: 73946, dtype: float64
# The predicted prbability of the presence of planets are [1.8702707] and
# The True values are
# 2
# The predicted Values are [1.8702707] and
# The True values are
# Planet_Mass1    135.666667
# Planet_Mass2      0.000000
# Planet_Mass3    265.666667
# Name: 27651, dtype: float64
# The predicted prbability of the presence of planets are [1.190052] and
# The True values are
# 1
# The predicted Values are [1.190052] and
# The True values are
# Planet_Mass1    760.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 101818, dtype: float64
# The predicted prbability of the presence of planets are [1.215803] and
# The True values are
# 1
# The predicted Values are [1.215803] and
# The True values are
# Planet_Mass1    560.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 79354, dtype: float64
# The predicted prbability of the presence of planets are [1.2588947] and
# The True values are
# 1
# The predicted Values are [1.2588947] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 83034, dtype: float64
# The predicted prbability of the presence of planets are [4.104433] and
# The True values are
# 4
# The predicted Values are [4.104433] and
# The True values are
# Planet_Mass1     390.0
# Planet_Mass2      60.0
# Planet_Mass3    1000.0
# Name: 54296, dtype: float64
# The predicted prbability of the presence of planets are [3.6827867] and
# The True values are
# 4
# The predicted Values are [3.6827867] and
# The True values are
# Planet_Mass1    673.333333
# Planet_Mass2     60.000000
# Planet_Mass3    293.333333
# Name: 28895, dtype: float64
# The predicted prbability of the presence of planets are [1.2156144] and
# The True values are
# 1
# The predicted Values are [1.2156144] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 83067, dtype: float64
# The predicted prbability of the presence of planets are [3.9086907] and
# The True values are
# 4
# The predicted Values are [3.9086907] and
# The True values are
# Planet_Mass1      50.666667
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 55224, dtype: float64
# The predicted prbability of the presence of planets are [2.6837082] and
# The True values are
# 3
# The predicted Values are [2.6837082] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 77544, dtype: float64
# The predicted prbability of the presence of planets are [3.804933] and
# The True values are
# 4
# The predicted Values are [3.804933] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2     60.000000
# Planet_Mass3    543.333333
# Name: 69188, dtype: float64
# The predicted prbability of the presence of planets are [1.2861713] and
# The True values are
# 1
# The predicted Values are [1.2861713] and
# The True values are
# Planet_Mass1    503.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 100789, dtype: float64
# The predicted prbability of the presence of planets are [1.2066928] and
# The True values are
# 1
# The predicted Values are [1.2066928] and
# The True values are
# Planet_Mass1    616.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 102423, dtype: float64
# The predicted prbability of the presence of planets are [1.231122] and
# The True values are
# 1
# The predicted Values are [1.231122] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 39351, dtype: float64
# The predicted prbability of the presence of planets are [0.9599031] and
# The True values are
# 1
# The predicted Values are [0.9599031] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 61967, dtype: float64
# The predicted prbability of the presence of planets are [3.6247652] and
# The True values are
# 4
# The predicted Values are [3.6247652] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2    333.333333
# Planet_Mass3    238.000000
# Name: 49964, dtype: float64
# The predicted prbability of the presence of planets are [3.741556] and
# The True values are
# 4
# The predicted Values are [3.741556] and
# The True values are
# Planet_Mass1    900.000000
# Planet_Mass2    930.000000
# Planet_Mass3    433.333333
# Name: 85482, dtype: float64
# The predicted prbability of the presence of planets are [1.1768929] and
# The True values are
# 1
# The predicted Values are [1.1768929] and
# The True values are
# Planet_Mass1    277.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 80651, dtype: float64
# The predicted prbability of the presence of planets are [3.7153945] and
# The True values are
# 4
# The predicted Values are [3.7153945] and
# The True values are
# Planet_Mass1    390.0
# Planet_Mass2     60.0
# Planet_Mass3    930.0
# Name: 91692, dtype: float64
# The predicted prbability of the presence of planets are [1.2928699] and
# The True values are
# 1
# The predicted Values are [1.2928699] and
# The True values are
# Planet_Mass1    760.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 80063, dtype: float64
# The predicted prbability of the presence of planets are [3.9690747] and
# The True values are
# 4
# The predicted Values are [3.9690747] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2    846.666667
# Planet_Mass3    543.333333
# Name: 63574, dtype: float64
# The predicted prbability of the presence of planets are [3.8614519] and
# The True values are
# 3
# The predicted Values are [3.8614519] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 77435, dtype: float64
# The predicted prbability of the presence of planets are [0.9969109] and
# The True values are
# 1
# The predicted Values are [0.9969109] and
# The True values are
# Planet_Mass1    390.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 61079, dtype: float64
# The predicted prbability of the presence of planets are [2.6773767] and
# The True values are
# 3
# The predicted Values are [2.6773767] and
# The True values are
# Planet_Mass1    503.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 13279, dtype: float64
# The predicted prbability of the presence of planets are [1.007513] and
# The True values are
# 1
# The predicted Values are [1.007513] and
# The True values are
# Planet_Mass1    956.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 20512, dtype: float64
# The predicted prbability of the presence of planets are [3.9806638] and
# The True values are
# 4
# The predicted Values are [3.9806638] and
# The True values are
# Planet_Mass1     760.000000
# Planet_Mass2     333.333333
# Planet_Mass3    1000.000000
# Name: 76714, dtype: float64
# The predicted prbability of the presence of planets are [3.9494653] and
# The True values are
# 4
# The predicted Values are [3.9494653] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2    566.666667
# Planet_Mass3    763.333333
# Name: 68073, dtype: float64
# The predicted prbability of the presence of planets are [3.6775231] and
# The True values are
# 4
# The predicted Values are [3.6775231] and
# The True values are
# Planet_Mass1    900.000000
# Planet_Mass2    930.000000
# Planet_Mass3    433.333333
# Name: 85434, dtype: float64
# The predicted prbability of the presence of planets are [3.6311126] and
# The True values are
# 3
# The predicted Values are [3.6311126] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 52574, dtype: float64
# The predicted prbability of the presence of planets are [1.2095283] and
# The True values are
# 1
# The predicted Values are [1.2095283] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 61418, dtype: float64
# The predicted prbability of the presence of planets are [1.2621441] and
# The True values are
# 1
# The predicted Values are [1.2621441] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 61430, dtype: float64
# The predicted prbability of the presence of planets are [1.2747904] and
# The True values are
# 1
# The predicted Values are [1.2747904] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 80759, dtype: float64
# The predicted prbability of the presence of planets are [3.9808047] and
# The True values are
# 4
# The predicted Values are [3.9808047] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2    333.333333
# Planet_Mass3    182.333333
# Name: 90170, dtype: float64
# The predicted prbability of the presence of planets are [1.3165069] and
# The True values are
# 1
# The predicted Values are [1.3165069] and
# The True values are
# Planet_Mass1    930.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 41550, dtype: float64
# The predicted prbability of the presence of planets are [3.7004316] and
# The True values are
# 4
# The predicted Values are [3.7004316] and
# The True values are
# Planet_Mass1    560.000000
# Planet_Mass2     60.000000
# Planet_Mass3    793.333333
# Name: 28553, dtype: float64
# The predicted prbability of the presence of planets are [3.967898] and
# The True values are
# 4
# The predicted Values are [3.967898] and
# The True values are
# Planet_Mass1    135.666667
# Planet_Mass2    289.000000
# Planet_Mass3    710.000000
# Name: 45989, dtype: float64
# The predicted prbability of the presence of planets are [1.0421406] and
# The True values are
# 1
# The predicted Values are [1.0421406] and
# The True values are
# Planet_Mass1    673.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 79822, dtype: float64
# The predicted prbability of the presence of planets are [1.2552704] and
# The True values are
# 1
# The predicted Values are [1.2552704] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 103577, dtype: float64
# The predicted prbability of the presence of planets are [1.1544544] and
# The True values are
# 1
# The predicted Values are [1.1544544] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 81707, dtype: float64
# The predicted prbability of the presence of planets are [0.96262974] and
# The True values are
# 1
# The predicted Values are [0.96262974] and
# The True values are
# Planet_Mass1    390.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 15875, dtype: float64
# The predicted prbability of the presence of planets are [3.0284443] and
# The True values are
# 3
# The predicted Values are [3.0284443] and
# The True values are
# Planet_Mass1    390.000000
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 98692, dtype: float64
# The predicted prbability of the presence of planets are [3.8094478] and
# The True values are
# 4
# The predicted Values are [3.8094478] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2    333.333333
# Planet_Mass3    653.333333
# Name: 50798, dtype: float64
# The predicted prbability of the presence of planets are [3.9748173] and
# The True values are
# 4
# The predicted Values are [3.9748173] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2    566.666667
# Planet_Mass3    876.666667
# Name: 21934, dtype: float64
# The predicted prbability of the presence of planets are [3.8754363] and
# The True values are
# 4
# The predicted Values are [3.8754363] and
# The True values are
# Planet_Mass1     986.666667
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 95939, dtype: float64
# The predicted prbability of the presence of planets are [3.6311126] and
# The True values are
# 3
# The predicted Values are [3.6311126] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 52574, dtype: float64
# The predicted prbability of the presence of planets are [3.8420484] and
# The True values are
# 4
# The predicted Values are [3.8420484] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 11431, dtype: float64
# The predicted prbability of the presence of planets are [1.8801737] and
# The True values are
# 2
# The predicted Values are [1.8801737] and
# The True values are
# Planet_Mass1    616.666667
# Planet_Mass2      0.000000
# Planet_Mass3    240.000000
# Name: 77062, dtype: float64
# The predicted prbability of the presence of planets are [3.5946188] and
# The True values are
# 4
# The predicted Values are [3.5946188] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2     60.000000
# Planet_Mass3     99.333333
# Name: 92384, dtype: float64
# The predicted prbability of the presence of planets are [1.195371] and
# The True values are
# 1
# The predicted Values are [1.195371] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 40748, dtype: float64
# The predicted prbability of the presence of planets are [3.6876957] and
# The True values are
# 4
# The predicted Values are [3.6876957] and
# The True values are
# Planet_Mass1     220.666667
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 99235, dtype: float64
# The predicted prbability of the presence of planets are [1.0198495] and
# The True values are
# 1
# The predicted Values are [1.0198495] and
# The True values are
# Planet_Mass1    333.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 19325, dtype: float64
# The predicted prbability of the presence of planets are [2.8620498] and
# The True values are
# 3
# The predicted Values are [2.8620498] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 76026, dtype: float64
# The predicted prbability of the presence of planets are [0.89964056] and
# The True values are
# 1
# The predicted Values are [0.89964056] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 17551, dtype: float64
# The predicted prbability of the presence of planets are [3.9706266] and
# The True values are
# 4
# The predicted Values are [3.9706266] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2     60.000000
# Planet_Mass3    350.000000
# Name: 49780, dtype: float64
# The predicted prbability of the presence of planets are [1.1220256] and
# The True values are
# 1
# The predicted Values are [1.1220256] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 104811, dtype: float64
# The predicted prbability of the presence of planets are [2.3751395] and
# The True values are
# 1
# The predicted Values are [2.3751395] and
# The True values are
# Planet_Mass1    390.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 101679, dtype: float64
# The predicted prbability of the presence of planets are [4.0296626] and
# The True values are
# 4
# The predicted Values are [4.0296626] and
# The True values are
# Planet_Mass1    760.000000
# Planet_Mass2    566.666667
# Planet_Mass3    736.666667
# Name: 84491, dtype: float64
# The predicted prbability of the presence of planets are [3.9909804] and
# The True values are
# 4
# The predicted Values are [3.9909804] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2    333.333333
# Planet_Mass3    240.000000
# Name: 34250, dtype: float64
# The predicted prbability of the presence of planets are [3.646961] and
# The True values are
# 4
# The predicted Values are [3.646961] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2     60.000000
# Planet_Mass3    293.333333
# Name: 71194, dtype: float64
# The predicted prbability of the presence of planets are [3.700367] and
# The True values are
# 4
# The predicted Values are [3.700367] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2     60.000000
# Planet_Mass3    210.000000
# Name: 50866, dtype: float64
# The predicted prbability of the presence of planets are [1.0551412] and
# The True values are
# 1
# The predicted Values are [1.0551412] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 17190, dtype: float64
# The predicted prbability of the presence of planets are [1.8723413] and
# The True values are
# 2
# The predicted Values are [1.8723413] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3    543.333333
# Name: 31338, dtype: float64
# The predicted prbability of the presence of planets are [3.6564863] and
# The True values are
# 4
# The predicted Values are [3.6564863] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 52663, dtype: float64
# The predicted prbability of the presence of planets are [1.7853079] and
# The True values are
# 1
# The predicted Values are [1.7853079] and
# The True values are
# Planet_Mass1    135.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 80258, dtype: float64
# The predicted prbability of the presence of planets are [0.9521335] and
# The True values are
# 1
# The predicted Values are [0.9521335] and
# The True values are
# Planet_Mass1    673.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 99884, dtype: float64
# The predicted prbability of the presence of planets are [1.0669719] and
# The True values are
# 1
# The predicted Values are [1.0669719] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 40410, dtype: float64
# The predicted prbability of the presence of planets are [3.9081342] and
# The True values are
# 4
# The predicted Values are [3.9081342] and
# The True values are
# Planet_Mass1     50.666667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 12229, dtype: float64
# The predicted prbability of the presence of planets are [1.858712] and
# The True values are
# 2
# The predicted Values are [1.858712] and
# The True values are
# Planet_Mass1    956.666667
# Planet_Mass2      0.000000
# Planet_Mass3    793.333333
# Name: 70362, dtype: float64
# The predicted prbability of the presence of planets are [3.9471142] and
# The True values are
# 4
# The predicted Values are [3.9471142] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2    566.666667
# Planet_Mass3    763.333333
# Name: 68016, dtype: float64
# The predicted prbability of the presence of planets are [1.1830295] and
# The True values are
# 1
# The predicted Values are [1.1830295] and
# The True values are
# Planet_Mass1    956.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 81151, dtype: float64
# The predicted prbability of the presence of planets are [0.98230714] and
# The True values are
# 1
# The predicted Values are [0.98230714] and
# The True values are
# Planet_Mass1    956.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 11265, dtype: float64
# The predicted prbability of the presence of planets are [4.159852] and
# The True values are
# 4
# The predicted Values are [4.159852] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 11449, dtype: float64
# The predicted prbability of the presence of planets are [1.243032] and
# The True values are
# 1
# The predicted Values are [1.243032] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 104377, dtype: float64
# The predicted prbability of the presence of planets are [1.3773304] and
# The True values are
# 1
# The predicted Values are [1.3773304] and
# The True values are
# Planet_Mass1    673.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 60330, dtype: float64
# The predicted prbability of the presence of planets are [1.2383902] and
# The True values are
# 1
# The predicted Values are [1.2383902] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 39289, dtype: float64
# The predicted prbability of the presence of planets are [3.82208] and
# The True values are
# 4
# The predicted Values are [3.82208] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2     65.666667
# Planet_Mass3    486.666667
# Name: 46388, dtype: float64
# The predicted prbability of the presence of planets are [4.095107] and
# The True values are
# 4
# The predicted Values are [4.095107] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2    566.666667
# Planet_Mass3    930.000000
# Name: 42062, dtype: float64
# The predicted prbability of the presence of planets are [3.9877374] and
# The True values are
# 4
# The predicted Values are [3.9877374] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2     60.000000
# Planet_Mass3    736.666667
# Name: 26686, dtype: float64
# The predicted prbability of the presence of planets are [2.1845202] and
# The True values are
# 2
# The predicted Values are [2.1845202] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2      0.000000
# Planet_Mass3    154.666667
# Name: 91441, dtype: float64
# The predicted prbability of the presence of planets are [3.781677] and
# The True values are
# 2
# The predicted Values are [3.781677] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2      0.000000
# Planet_Mass3    240.000000
# Name: 35964, dtype: float64
# The predicted prbability of the presence of planets are [3.8877108] and
# The True values are
# 4
# The predicted Values are [3.8877108] and
# The True values are
# Planet_Mass1    305.666667
# Planet_Mass2    333.333333
# Planet_Mass3    240.000000
# Name: 12077, dtype: float64
# The predicted prbability of the presence of planets are [2.6477396] and
# The True values are
# 4
# The predicted Values are [2.6477396] and
# The True values are
# Planet_Mass1    135.666667
# Planet_Mass2     60.000000
# Planet_Mass3     99.333333
# Name: 47603, dtype: float64
# The predicted prbability of the presence of planets are [3.5205257] and
# The True values are
# 4
# The predicted Values are [3.5205257] and
# The True values are
# Planet_Mass1    135.666667
# Planet_Mass2     60.000000
# Planet_Mass3     99.333333
# Name: 47667, dtype: float64
# The predicted prbability of the presence of planets are [1.9053903] and
# The True values are
# 2
# The predicted Values are [1.9053903] and
# The True values are
# Planet_Mass1    590.000000
# Planet_Mass2      0.000000
# Planet_Mass3    793.333333
# Name: 93571, dtype: float64
# The predicted prbability of the presence of planets are [3.921547] and
# The True values are
# 4
# The predicted Values are [3.921547] and
# The True values are
# Planet_Mass1     50.666667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 12174, dtype: float64
# The predicted prbability of the presence of planets are [3.900795] and
# The True values are
# 4
# The predicted Values are [3.900795] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2    736.666667
# Planet_Mass3    433.333333
# Name: 22916, dtype: float64
# The predicted prbability of the presence of planets are [3.7968438] and
# The True values are
# 4
# The predicted Values are [3.7968438] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2    233.000000
# Planet_Mass3    763.333333
# Name: 45354, dtype: float64
# The predicted prbability of the presence of planets are [3.930242] and
# The True values are
# 4
# The predicted Values are [3.930242] and
# The True values are
# Planet_Mass1     79.000000
# Planet_Mass2     93.666667
# Planet_Mass3    486.666667
# Name: 88043, dtype: float64
# The predicted prbability of the presence of planets are [3.9776242] and
# The True values are
# 4
# The predicted Values are [3.9776242] and
# The True values are
# Planet_Mass1    277.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 15365, dtype: float64
# The predicted prbability of the presence of planets are [1.0234202] and
# The True values are
# 1
# The predicted Values are [1.0234202] and
# The True values are
# Planet_Mass1    730.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 18627, dtype: float64
# The predicted prbability of the presence of planets are [1.3645135] and
# The True values are
# 1
# The predicted Values are [1.3645135] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 104563, dtype: float64
# The predicted prbability of the presence of planets are [1.2861488] and
# The True values are
# 1
# The predicted Values are [1.2861488] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 59594, dtype: float64
# The predicted prbability of the presence of planets are [2.0504682] and
# The True values are
# 1
# The predicted Values are [2.0504682] and
# The True values are
# Planet_Mass1    164.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 59073, dtype: float64
# The predicted prbability of the presence of planets are [4.1154103] and
# The True values are
# 4
# The predicted Values are [4.1154103] and
# The True values are
# Planet_Mass1     50.666667
# Planet_Mass2    513.333333
# Planet_Mass3     71.666667
# Name: 25174, dtype: float64
# The predicted prbability of the presence of planets are [3.9589365] and
# The True values are
# 4
# The predicted Values are [3.9589365] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2    333.333333
# Planet_Mass3    960.000000
# Name: 50156, dtype: float64
# The predicted prbability of the presence of planets are [1.2574] and
# The True values are
# 1
# The predicted Values are [1.2574] and
# The True values are
# Planet_Mass1    930.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 41619, dtype: float64
# The predicted prbability of the presence of planets are [3.952377] and
# The True values are
# 4
# The predicted Values are [3.952377] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2    483.333333
# Planet_Mass3     44.000000
# Name: 84419, dtype: float64
# The predicted prbability of the presence of planets are [1.191829] and
# The True values are
# 1
# The predicted Values are [1.191829] and
# The True values are
# Planet_Mass1    900.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 57806, dtype: float64
# The predicted prbability of the presence of planets are [2.8881915] and
# The True values are
# 3
# The predicted Values are [2.8881915] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2     60.000000
# Planet_Mass3      0.000000
# Name: 33888, dtype: float64
# The predicted prbability of the presence of planets are [1.019387] and
# The True values are
# 1
# The predicted Values are [1.019387] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 18364, dtype: float64
# The predicted prbability of the presence of planets are [3.942104] and
# The True values are
# 4
# The predicted Values are [3.942104] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2    333.333333
# Planet_Mass3    486.666667
# Name: 50452, dtype: float64
# The predicted prbability of the presence of planets are [3.8799856] and
# The True values are
# 4
# The predicted Values are [3.8799856] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 74524, dtype: float64
# The predicted prbability of the presence of planets are [3.9535081] and
# The True values are
# 4
# The predicted Values are [3.9535081] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2    373.333333
# Planet_Mass3    596.666667
# Name: 43166, dtype: float64
# The predicted prbability of the presence of planets are [4.0884085] and
# The True values are
# 4
# The predicted Values are [4.0884085] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2    149.333333
# Planet_Mass3    596.666667
# Name: 86898, dtype: float64
# The predicted prbability of the presence of planets are [1.0029594] and
# The True values are
# 1
# The predicted Values are [1.0029594] and
# The True values are
# Planet_Mass1    22.166667
# Planet_Mass2     0.000000
# Planet_Mass3     0.000000
# Name: 36985, dtype: float64
# The predicted prbability of the presence of planets are [0.97444606] and
# The True values are
# 1
# The predicted Values are [0.97444606] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 83469, dtype: float64
# The predicted prbability of the presence of planets are [1.0273662] and
# The True values are
# 1
# The predicted Values are [1.0273662] and
# The True values are
# Planet_Mass1    420.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 19767, dtype: float64
# The predicted prbability of the presence of planets are [3.9451118] and
# The True values are
# 4
# The predicted Values are [3.9451118] and
# The True values are
# Planet_Mass1      79.0
# Planet_Mass2      60.0
# Planet_Mass3    1000.0
# Name: 98993, dtype: float64
# The predicted prbability of the presence of planets are [1.8391494] and
# The True values are
# 2
# The predicted Values are [1.8391494] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2      0.000000
# Planet_Mass3    653.333333
# Name: 26779, dtype: float64
# The predicted prbability of the presence of planets are [3.9309595] and
# The True values are
# 4
# The predicted Values are [3.9309595] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2    820.000000
# Planet_Mass3    127.000000
# Name: 46570, dtype: float64
# The predicted prbability of the presence of planets are [1.8881726] and
# The True values are
# 2
# The predicted Values are [1.8881726] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2      0.000000
# Planet_Mass3    240.000000
# Name: 31735, dtype: float64
# The predicted prbability of the presence of planets are [3.2847693] and
# The True values are
# 4
# The predicted Values are [3.2847693] and
# The True values are
# Planet_Mass1    220.666667
# Planet_Mass2     60.000000
# Planet_Mass3    350.000000
# Name: 49767, dtype: float64
# The predicted prbability of the presence of planets are [1.9340695] and
# The True values are
# 2
# The predicted Values are [1.9340695] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2      0.000000
# Planet_Mass3    653.333333
# Name: 26826, dtype: float64
# The predicted prbability of the presence of planets are [3.918613] and
# The True values are
# 4
# The predicted Values are [3.918613] and
# The True values are
# Planet_Mass1    164.000000
# Planet_Mass2    333.333333
# Planet_Mass3    516.666667
# Name: 31129, dtype: float64
# The predicted prbability of the presence of planets are [2.4971664] and
# The True values are
# 3
# The predicted Values are [2.4971664] and
# The True values are
# Planet_Mass1    22.166667
# Planet_Mass2    60.000000
# Planet_Mass3     0.000000
# Name: 77699, dtype: float64
# The predicted prbability of the presence of planets are [3.9219956] and
# The True values are
# 4
# The predicted Values are [3.9219956] and
# The True values are
# Planet_Mass1     79.000000
# Planet_Mass2    763.333333
# Planet_Mass3    570.000000
# Name: 65979, dtype: float64
# The predicted prbability of the presence of planets are [1.2844338] and
# The True values are
# 1
# The predicted Values are [1.2844338] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 61950, dtype: float64
# The predicted prbability of the presence of planets are [4.1479464] and
# The True values are
# 3
# The predicted Values are [4.1479464] and
# The True values are
# Planet_Mass1    390.000000
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 98613, dtype: float64
# The predicted prbability of the presence of planets are [3.8096628] and
# The True values are
# 4
# The predicted Values are [3.8096628] and
# The True values are
# Planet_Mass1    616.666667
# Planet_Mass2    343.333333
# Planet_Mass3    460.000000
# Name: 65418, dtype: float64
# The predicted prbability of the presence of planets are [3.80814] and
# The True values are
# 4
# The predicted Values are [3.80814] and
# The True values are
# Planet_Mass1    816.666667
# Planet_Mass2    706.666667
# Planet_Mass3    930.000000
# Name: 85797, dtype: float64
# The predicted prbability of the presence of planets are [3.9774477] and
# The True values are
# 4
# The predicted Values are [3.9774477] and
# The True values are
# Planet_Mass1    446.666667
# Planet_Mass2     60.000000
# Planet_Mass3    680.000000
# Name: 48649, dtype: float64
# The predicted prbability of the presence of planets are [0.90451026] and
# The True values are
# 1
# The predicted Values are [0.90451026] and
# The True values are
# Planet_Mass1    277.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 58119, dtype: float64
# The predicted prbability of the presence of planets are [1.0318358] and
# The True values are
# 1
# The predicted Values are [1.0318358] and
# The True values are
# Planet_Mass1    277.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 19845, dtype: float64
# The predicted prbability of the presence of planets are [3.63565] and
# The True values are
# 4
# The predicted Values are [3.63565] and
# The True values are
# Planet_Mass1     50.666667
# Planet_Mass2    177.333333
# Planet_Mass3     71.666667
# Name: 43047, dtype: float64
# The predicted prbability of the presence of planets are [2.789568] and
# The True values are
# 3
# The predicted Values are [2.789568] and
# The True values are
# Planet_Mass1    420.0
# Planet_Mass2     60.0
# Planet_Mass3      0.0
# Name: 35510, dtype: float64
# The predicted prbability of the presence of planets are [1.1386544] and
# The True values are
# 1
# The predicted Values are [1.1386544] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 83210, dtype: float64
# The predicted prbability of the presence of planets are [3.7550752] and
# The True values are
# 3
# The predicted Values are [3.7550752] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2    333.333333
# Planet_Mass3      0.000000
# Name: 77479, dtype: float64
# The predicted prbability of the presence of planets are [0.9716321] and
# The True values are
# 1
# The predicted Values are [0.9716321] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 41301, dtype: float64
# The predicted prbability of the presence of planets are [3.9732656] and
# The True values are
# 4
# The predicted Values are [3.9732656] and
# The True values are
# Planet_Mass1    760.000000
# Planet_Mass2     60.000000
# Planet_Mass3    626.666667
# Name: 51388, dtype: float64
# The predicted prbability of the presence of planets are [0.95676464] and
# The True values are
# 1
# The predicted Values are [0.95676464] and
# The True values are
# Planet_Mass1    249.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 19402, dtype: float64
# The predicted prbability of the presence of planets are [1.0349287] and
# The True values are
# 1
# The predicted Values are [1.0349287] and
# The True values are
# Planet_Mass1    249.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 19484, dtype: float64
# The predicted prbability of the presence of planets are [1.1355563] and
# ...
# The True values are
# 2
# The predicted Values are [1.9495493] and
# The True values are
# Planet_Mass1    50.666667
# Planet_Mass2     0.000000
# Planet_Mass3    71.666667
# Name: 29133, dtype: float64
# The predicted prbability of the presence of planets are [1.1210575] and
# The True values are
# 1
# The predicted Values are [1.1210575] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 59804, dtype: float64
# The predicted prbability of the presence of planets are [3.994289] and
# The True values are
# 4
# The predicted Values are [3.994289] and
# The True values are
# Planet_Mass1    164.000000
# Planet_Mass2    956.666667
# Planet_Mass3    653.333333
# Name: 65806, dtype: float64
# The predicted prbability of the presence of planets are [2.2415926] and
# The True values are
# 1
# The predicted Values are [2.2415926] and
# The True values are
# Planet_Mass1    79.0
# Planet_Mass2     0.0
# Planet_Mass3     0.0
# Name: 83740, dtype: float64
# The predicted prbability of the presence of planets are [3.9773848] and
# The True values are
# 4
# The predicted Values are [3.9773848] and
# The True values are
# Planet_Mass1    616.666667
# Planet_Mass2    956.666667
# Planet_Mass3    238.000000
# Name: 21201, dtype: float64
# The predicted prbability of the presence of planets are [3.988918] and
# The True values are
# 4
# The predicted Values are [3.988918] and
# The True values are
# Planet_Mass1    873.333333
# Planet_Mass2    333.333333
# Planet_Mass3    182.333333
# Name: 90206, dtype: float64
# The predicted prbability of the presence of planets are [3.944895] and
# The True values are
# 4
# The predicted Values are [3.944895] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2    333.333333
# Planet_Mass3    820.000000
# Name: 49552, dtype: float64
# The predicted prbability of the presence of planets are [3.9290524] and
# The True values are
# 4
# The predicted Values are [3.9290524] and
# The True values are
# Planet_Mass1    164.000000
# Planet_Mass2    121.666667
# Planet_Mass3    763.333333
# Name: 24500, dtype: float64
# The predicted prbability of the presence of planets are [3.712835] and
# The True values are
# 4
# The predicted Values are [3.712835] and
# The True values are
# Planet_Mass1    930.000000
# Planet_Mass2    456.666667
# Planet_Mass3    210.000000
# Name: 86178, dtype: float64
# The predicted prbability of the presence of planets are [4.020516] and
# The True values are
# 4
# The predicted Values are [4.020516] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2    846.666667
# Planet_Mass3    543.333333
# Name: 63587, dtype: float64
# The predicted prbability of the presence of planets are [3.30404] and
# The True values are
# 2
# The predicted Values are [3.30404] and
# The True values are
# Planet_Mass1    249.0
# Planet_Mass2      0.0
# Planet_Mass3    960.0
# Name: 93002, dtype: float64
# The predicted prbability of the presence of planets are [3.9344528] and
# The True values are
# 4
# The predicted Values are [3.9344528] and
# The True values are
# Planet_Mass1    420.000000
# Planet_Mass2    956.666667
# Planet_Mass3    182.333333
# Name: 43357, dtype: float64
# The predicted prbability of the presence of planets are [4.045179] and
# The True values are
# 4
# The predicted Values are [4.045179] and
# The True values are
# Planet_Mass1    673.333333
# Planet_Mass2    333.333333
# Planet_Mass3    846.666667
# Name: 69523, dtype: float64
# The predicted prbability of the presence of planets are [1.7851888] and
# The True values are
# 2
# The predicted Values are [1.7851888] and
# The True values are
# Planet_Mass1    786.666667
# Planet_Mass2      0.000000
# Planet_Mass3     99.333333
# Name: 73242, dtype: float64
# The predicted prbability of the presence of planets are [3.9842637] and
# The True values are
# 4
# The predicted Values are [3.9842637] and
# The True values are
# Planet_Mass1     786.666667
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 31894, dtype: float64
# The predicted prbability of the presence of planets are [3.6616096] and
# The True values are
# 4
# The predicted Values are [3.6616096] and
# The True values are
# Planet_Mass1    900.000000
# Planet_Mass2    790.000000
# Planet_Mass3    596.666667
# Name: 23280, dtype: float64
# The predicted prbability of the presence of planets are [1.0463833] and
# The True values are
# 1
# The predicted Values are [1.0463833] and
# The True values are
# Planet_Mass1    646.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 104825, dtype: float64
# The predicted prbability of the presence of planets are [0.94780093] and
# The True values are
# 1
# The predicted Values are [0.94780093] and
# The True values are
# Planet_Mass1    79.0
# Planet_Mass2     0.0
# Planet_Mass3     0.0
# Name: 41443, dtype: float64
# The predicted prbability of the presence of planets are [1.0942922] and
# The True values are
# 4
# The predicted Values are [1.0942922] and
# The True values are
# Planet_Mass1    503.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 32303, dtype: float64
# The predicted prbability of the presence of planets are [1.8135251] and
# The True values are
# 2
# The predicted Values are [1.8135251] and
# The True values are
# Planet_Mass1    164.000000
# Planet_Mass2      0.000000
# Planet_Mass3    182.333333
# Name: 70982, dtype: float64
# The predicted prbability of the presence of planets are [3.8737042] and
# The True values are
# 4
# The predicted Values are [3.8737042] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2     60.000000
# Planet_Mass3    293.333333
# Name: 71146, dtype: float64
# The predicted prbability of the presence of planets are [3.8532064] and
# The True values are
# 4
# The predicted Values are [3.8532064] and
# The True values are
# Planet_Mass1     503.333333
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 57697, dtype: float64
# The predicted prbability of the presence of planets are [1.2041177] and
# The True values are
# 1
# The predicted Values are [1.2041177] and
# The True values are
# Planet_Mass1    956.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 37782, dtype: float64
# The predicted prbability of the presence of planets are [1.1267967] and
# The True values are
# 1
# The predicted Values are [1.1267967] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 58553, dtype: float64
# The predicted prbability of the presence of planets are [3.6803126] and
# The True values are
# 4
# The predicted Values are [3.6803126] and
# The True values are
# Planet_Mass1    363.333333
# Planet_Mass2    650.000000
# Planet_Mass3    403.333333
# Name: 45887, dtype: float64
# The predicted prbability of the presence of planets are [1.2581992] and
# The True values are
# 1
# The predicted Values are [1.2581992] and
# The True values are
# Planet_Mass1    986.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 100951, dtype: float64
# The predicted prbability of the presence of planets are [3.7754118] and
# The True values are
# 4
# The predicted Values are [3.7754118] and
# The True values are
# Planet_Mass1    533.333333
# Planet_Mass2    596.666667
# Planet_Mass3    127.000000
# Name: 89035, dtype: float64
# The predicted prbability of the presence of planets are [1.2057949] and
# The True values are
# 1
# The predicted Values are [1.2057949] and
# The True values are
# Planet_Mass1    305.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 83931, dtype: float64
# The predicted prbability of the presence of planets are [3.980336] and
# The True values are
# 4
# The predicted Values are [3.980336] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2     60.000000
# Planet_Mass3    736.666667
# Name: 26693, dtype: float64
# The predicted prbability of the presence of planets are [1.8613195] and
# The True values are
# 2
# The predicted Values are [1.8613195] and
# The True values are
# Planet_Mass1     50.666667
# Planet_Mass2      0.000000
# Planet_Mass3    433.333333
# Name: 91883, dtype: float64
# The predicted prbability of the presence of planets are [4.109684] and
# The True values are
# 4
# The predicted Values are [4.109684] and
# The True values are
# Planet_Mass1    192.333333
# Planet_Mass2    289.000000
# Planet_Mass3    960.000000
# Name: 87661, dtype: float64
# The predicted prbability of the presence of planets are [3.7075098] and
# The True values are
# 4
# The predicted Values are [3.7075098] and
# The True values are
# Planet_Mass1    590.0
# Planet_Mass2     60.0
# Planet_Mass3    240.0
# Name: 77816, dtype: float64
# The predicted prbability of the presence of planets are [4.1477685] and
# The True values are
# 4
# The predicted Values are [4.1477685] and
# The True values are
# Planet_Mass1    420.0
# Planet_Mass2    650.0
# Planet_Mass3    680.0
# Name: 64196, dtype: float64
# The predicted prbability of the presence of planets are [3.939919] and
# The True values are
# 4
# The predicted Values are [3.939919] and
# The True values are
# Planet_Mass1    277.333333
# Planet_Mass2     60.000000
# Planet_Mass3    763.333333
# Name: 49010, dtype: float64
# The predicted prbability of the presence of planets are [3.9595284] and
# The True values are
# 4
# The predicted Values are [3.9595284] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2    149.333333
# Planet_Mass3    403.333333
# Name: 64956, dtype: float64
# The predicted prbability of the presence of planets are [2.609227] and
# The True values are
# 3
# The predicted Values are [2.609227] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2     60.000000
# Planet_Mass3      0.000000
# Name: 34190, dtype: float64
# The predicted prbability of the presence of planets are [3.6431224] and
# The True values are
# 4
# The predicted Values are [3.6431224] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 52778, dtype: float64
# The predicted prbability of the presence of planets are [3.974136] and
# The True values are
# 4
# The predicted Values are [3.974136] and
# The True values are
# Planet_Mass1    930.000000
# Planet_Mass2    333.333333
# Planet_Mass3    240.000000
# Name: 55523, dtype: float64
# The predicted prbability of the presence of planets are [1.6949401] and
# The True values are
# 2
# The predicted Values are [1.6949401] and
# The True values are
# Planet_Mass1    363.333333
# Planet_Mass2      0.000000
# Planet_Mass3     44.000000
# Name: 49068, dtype: float64
# The predicted prbability of the presence of planets are [3.6689212] and
# The True values are
# 4
# The predicted Values are [3.6689212] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 57195, dtype: float64
# The predicted prbability of the presence of planets are [1.0219729] and
# The True values are
# 1
# The predicted Values are [1.0219729] and
# The True values are
# Planet_Mass1    590.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 19031, dtype: float64
# The predicted prbability of the presence of planets are [3.9632099] and
# The True values are
# 4
# The predicted Values are [3.9632099] and
# The True values are
# Planet_Mass1    760.000000
# Planet_Mass2     60.000000
# Planet_Mass3    626.666667
# Name: 51335, dtype: float64
# The predicted prbability of the presence of planets are [3.9975212] and
# The True values are
# 4
# The predicted Values are [3.9975212] and
# The True values are
# Planet_Mass1     533.333333
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 56001, dtype: float64
# The predicted prbability of the presence of planets are [0.99491024] and
# The True values are
# 1
# The predicted Values are [0.99491024] and
# The True values are
# Planet_Mass1    446.666667
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 39033, dtype: float64
# The predicted prbability of the presence of planets are [4.045389] and
# The True values are
# 4
# The predicted Values are [4.045389] and
# The True values are
# Planet_Mass1    305.666667
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 54468, dtype: float64
# The predicted prbability of the presence of planets are [3.746864] and
# The True values are
# 4
# The predicted Values are [3.746864] and
# The True values are
# Planet_Mass1     843.333333
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 94605, dtype: float64
# The predicted prbability of the presence of planets are [1.1823891] and
# The True values are
# 1
# The predicted Values are [1.1823891] and
# The True values are
# Planet_Mass1    843.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 60169, dtype: float64
# The predicted prbability of the presence of planets are [3.9285727] and
# The True values are
# 4
# The predicted Values are [3.9285727] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2     60.000000
# Planet_Mass3    240.000000
# Name: 53115, dtype: float64
# The predicted prbability of the presence of planets are [3.8986797] and
# The True values are
# 4
# The predicted Values are [3.8986797] and
# The True values are
# Planet_Mass1     956.666667
# Planet_Mass2      60.000000
# Planet_Mass3    1000.000000
# Name: 77967, dtype: float64
# The predicted prbability of the presence of planets are [2.4464889] and
# The True values are
# 4
# The predicted Values are [2.4464889] and
# The True values are
# Planet_Mass1     22.166667
# Planet_Mass2     60.000000
# Planet_Mass3    486.666667
# Name: 27963, dtype: float64
# The predicted prbability of the presence of planets are [0.9716321] and
# The True values are
# 1
# The predicted Values are [0.9716321] and
# The True values are
# Planet_Mass1    107.333333
# Planet_Mass2      0.000000
# Planet_Mass3      0.000000
# Name: 41301, dtype: float64
# The predicted prbability of the presence of planets are [3.8765173] and
# The True values are
# 4
# The predicted Values are [3.8765173] and
# The True values are
# Planet_Mass1    249.000000
# Planet_Mass2     60.000000
# Planet_Mass3    433.333333
# Name: 52295, dtype: float64
# The predicted prbability of the presence of planets are [1.1857845] and
# The True values are
# 1
# The predicted Values are [1.1857845] and
# The True values are
# Planet_Mass1    760.0
# Planet_Mass2      0.0
# Planet_Mass3      0.0
# Name: 56338, dtype: float64
# The predicted prbability of the presence of planets are [4.016995] and
# The True values are
# 4
# The predicted Values are [4.016995] and
# The True values are
# Planet_Mass1    476.666667
# Planet_Mass2    820.000000
# Planet_Mass3    127.000000
# Name: 46608, dtype: float64
# The predicted prbability of the presence of planets are [3.7655687] and
# The True values are
# 4
# The predicted Values are [3.7655687] and
# The True values are
# Planet_Mass1    703.333333
# Planet_Mass2    333.333333
# Planet_Mass3    736.666667
# Name: 72030, dtype: float64
# The predicted prbability of the presence of planets are [3.7658894] and
# The True values are
# 4
# The predicted Values are [3.7658894] and
# The True values are
# Planet_Mass1    363.333333
# Planet_Mass2    650.000000
# Planet_Mass3    960.000000
# Name: 23445, dtype: float64
# The predicted prbability of the presence of planets are [3.8211982] and
# The True values are
# 4
# The predicted Values are [3.8211982] and
# The True values are
# Planet_Mass1    900.000000
# Planet_Mass2    790.000000
# Planet_Mass3    596.666667
# Name: 23273, dtype: float64
# The predicted prbability of the presence of planets are [3.9596226] and
# The True values are
# 4
# The predicted Values are [3.9596226] and
# The True values are
# Planet_Mass1    730.000000
# Planet_Mass2    846.666667
# Planet_Mass3    626.666667
# Name: 87781, dtype: float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [79], line 6
#       4 for i in range(3151):
#       5     test_index = i # 550  #550 ##210#
# ----> 6     predictions.append(pred_CNN[test_index].item())
#       7     truth.append(test['Planet_Count'].iloc[test_index])
#       8     # plt.imshow(testImagesX[test_iclass_mode])
#
# IndexError: index 3150 is out of bounds for axis 0 with size 3150

# %%
###fc_mean_squared_error fc_accuracy dense_3_mean_squared_error dense_3_accuracy
hist =pd.DataFrame(CNN_history.history)
hist['epoch'] = hist.index = hist.index
hist
if NETWORK == "TL":
    plot_name = NETWORK+'_'+str( transfer_model.__name__)+'_'+str(X_res)
else:
    plot_name = NETWORK+'_'+str(X_res)
if  CLA == True and REG== False:
    cla_acc = CNN_history.history['mean_absolute_error']
    val_cla_acc = CNN_history.history['val_mean_absolute_error']
    cla_loss =CNN_history.history['loss']
    val_cla_loss = CNN_history.history['val_loss']
    
    plt.figure(figsize=(8, 8))
    # plt.subplot(2, 2, 1)
    plt.plot(hist['epoch'], cla_acc, label='cla-Training mean_absolute_error')
    plt.plot(hist['epoch'], val_cla_acc, label='cla-Validation mean_absolute_error')
    
    plt.legend(loc='upper right')
    plt.xlabel("epochs")
    plt.ylabel("mean_absolute_error")
    plt.title('Classification Training and Validation mean_absolute_error')
    plt.savefig('figures/'+plot_name+'_c.png')
    plt.show()
    
if REG == True and CLA == False:
    ## For Regression
    reg_mse = CNN_history.history['mean_squared_error']
    val_reg_mse =CNN_history.history['val_mean_squared_error']
    reg_loss =CNN_history.history['loss']
    val_reg_loss = CNN_history.history['val_loss']
    
    plt.figure(figsize=(8, 8))
    # plt.subplot(2, 2, 1)
    # plt.ylim(0,50000)
    plt.plot(hist['epoch'], reg_mse, label='reg-Training MSE')
    plt.plot(hist['epoch'], val_reg_mse, label='reg-Validation MSE')
    plt.legend(loc='upper right')
    plt.title('Regression Training and Validation MSE')
    plt.xlabel("epochs")
    plt.ylabel("MSE")
    plt.show()
    plt.savefig('figures/'+plot_name+'_r.png')

if REG == True and CLA == True:
    ## For classification
    cla_acc = CNN_history.history['cla_accuracy']
    val_cla_acc = CNN_history.history['val_cla_accuracy']
    cla_loss =CNN_history.history['cla_loss']
    val_cla_loss = CNN_history.history['val_cla_loss']

    ## For Regression
    reg_mse = CNN_history.history['reg_mean_squared_error']
    val_reg_mse =CNN_history.history['val_reg_mean_squared_error']
    reg_loss =CNN_history.history['reg_loss']
    val_reg_loss = CNN_history.history['val_reg_loss']
    
    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(hist['epoch'], cla_acc, label='cla-Training Accuracy')
    plt.plot(hist['epoch'], val_cla_acc, label='cla-Validation Accuracy')
    plt.legend(loc='lower right')
    plt.xlabel("epochs")
    plt.ylabels("accuracy")
    plt.title('Classification Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(hist['epoch'], reg_mse, label='reg-Training MSE')
    plt.plot(hist['epoch'], val_reg_mse, label='reg-Validation MSE')
    plt.legend(loc='upper right')
    plt.xlabel("epochs")
    plt.ylabel("MSE")
    plt.title('Regression Training and Validation MSE')
    plt.savefig('figures/'+plot_name+'_cr.png')

# %%
tp = pd.DataFrame(
    {'Predictions': predictions,
     'Truth': truth
    })
tp
# Out:
#       Predictions  Truth
# 0        3.645561      4
# 1        3.696403      4
# 2        1.756387      2
# 3        1.552720      1
# 4        3.961599      4
# ...           ...    ...
# 3145     4.016995      4
# 3146     3.765569      4
# 3147     3.765889      4
# 3148     3.821198      4
# 3149     3.959623      4
#
# [3150 rows x 2 columns]

# %%
np.mean(tp['Truth']-tp['Predictions'])
# Out:
# 0.022379185756047568

# %%
tp1 = tp.loc[tp['Truth'] == 1]
tp1
# Out:
#       Predictions  Truth
# 3        1.552720      1
# 5        1.185612      1
# 7        1.185681      1
# 11       1.278217      1
# 22       1.296362      1
# ...           ...    ...
# 3132     1.021973      1
# 3135     0.994910      1
# 3138     1.182389      1
# 3142     0.971632      1
# 3144     1.185784      1
#
# [914 rows x 2 columns]

# %%
np.mean(tp1['Truth']-tp1['Predictions'])
# Out:
# -0.203304715699127

# %%
tp2 = tp.loc[tp['Truth'] == 2]
tp2
# Out:
#       Predictions  Truth
# 2        1.756387      2
# 6        1.930135      2
# 28       1.869235      2
# 36       1.858174      2
# 44       1.919858      2
# ...           ...    ...
# 3102     3.304040      2
# 3105     1.785189      2
# 3111     1.813525      2
# 3121     1.861320      2
# 3130     1.694940      2
#
# [339 rows x 2 columns]

# %%
np.mean(tp2['Truth']-tp2['Predictions'])
# Out:
# -0.17792805633713712

# %%
tp3 = tp.loc[tp['Truth'] == 3]
tp3
# Out:
#       Predictions  Truth
# 15       3.757934      3
# 57       2.683708      3
# 69       3.861452      3
# 71       2.677377      3
# 76       3.631113      3
# ...           ...    ...
# 3019     2.391146      3
# 3020     2.477833      3
# 3027     3.544509      3
# 3061     3.125859      3
# 3127     2.609227      3
#
# [182 rows x 2 columns]

# %%
np.mean(tp3['Truth']-tp3['Predictions'])
# Out:
# 0.15243341536312313

# %%
tp4 = tp.loc[tp['Truth'] == 4]
tp4
# Out:
#       Predictions  Truth
# 0        3.645561      4
# 1        3.696403      4
# 4        3.961599      4
# 8        3.881082      4
# 9        4.274773      4
# ...           ...    ...
# 3145     4.016995      4
# 3146     3.765569      4
# 3147     3.765889      4
# 3148     3.821198      4
# 3149     3.959623      4
#
# [1715 rows x 2 columns]

# %%
np.mean(tp4['Truth']-tp4['Predictions'])
# Out:
# 0.1684487899607889
